# %% [markdown]
# # Import demultiplexed filtered reads

# %%
import pandas as pd
met = pd.read_csv('metadata.tsv', sep='\t', index_col='#SampleID')

# sort reads by sequencing run
for ri in set(met.Run_index):
  tmp = met.loc[met.Run_index == ri]['SeqRun'].tolist()[0]
  # !mkdir Data/Demux/$tmp
  # !mv Data/Demux/$ri/* Data/Demux/$tmp
  # !rm -r Data/Demux/$ri
# Out:
# mkdir: cannot create directory ‘Data/Demux/SeqRun_2’: File exists
# mkdir: cannot create directory ‘Data/Demux/SeqRun_2’: File exists
# mkdir: cannot create directory ‘Data/Demux/SeqRun_2’: File exists

# %%
import pandas as pd
met = pd.read_csv('metadata.tsv', sep='\t', index_col='#SampleID')

# import reads
for sr in set(met.SeqRun):
  demux = 'Data/Demux/%s_demux.qza'%sr
  
  # !qiime tools import \
    --type 'SampleData[PairedEndSequencesWithQuality]' \
    --input-path Data/Demux/$sr \
    --input-format CasavaOneEightSingleLanePerSampleDirFmt \
    --output-path $demux
# Out:
# Imported Data/Demux/SeqRun_2 as CasavaOneEightSingleLanePerSampleDirFmt to Data/Demux/SeqRun_2_demux.qza

# %%
for sr in set(met.SeqRun):
  demux = 'Data/Demux/%s_demux.qza'%sr
  deqzv = 'Data/Demux/%s_demux.qzv'%sr
  
  # !qiime demux summarize \
    --i-data $demux \
    --o-visualization $deqzv
# Out:
# Saved Visualization to: Data/Demux/SeqRun_2_demux.qzv

# %%
import pandas as pd
met = pd.read_csv('metadata.tsv', sep='\t', index_col='#SampleID')
adapter = met.LinkerPrimerSequence.tolist()[0]

# !mkdir Data/Cutadapt
for sr in set(met.SeqRun):
  demux = 'Data/Demux/%s_demux.qza'%sr
  cutad = 'Data/Cutadapt/%s_trim.qza'%sr
  cuqzv = 'Data/Cutadapt/%s_trim.qzv'%sr
  
  # !qiime cutadapt trim-paired \
    --i-demultiplexed-sequences $demux \
    --o-trimmed-sequences $cutad \
    --p-cores 10 \
    --p-anywhere-f $adapter \
    --p-error-rate 0.2 \
    --p-match-adapter-wildcards \
    --p-discard-untrimmed \
    --p-match-read-wildcards

  # Visualization
  # !qiime demux summarize \
      --i-data $cutad \
      --o-visualization $cuqzv
# Out:
# Saved SampleData[PairedEndSequencesWithQuality] to: Data/Cutadapt/SeqRun_2_trim.qza
# Saved Visualization to: Data/Cutadapt/SeqRun_2_trim.qzv

# %%
#import pandas as pd
#met = pd.read_csv('metadata.tsv', sep='\t', index_col='#SampleID')
#
#!mkdir Data/Joined
#for sr in set(met.SeqRun):
#  cutad = 'Data/Cutadapt/%s_trim.qza'%sr
#  joined = 'Data/Joined/%s_joined.qza'%sr
#  !qiime vsearch join-pairs \
#    --i-demultiplexed-seqs $cutad \
#    --p-threads 8 \
#    --p-maxdiffs 12 \
#    --o-joined-sequences $joined
# Out:
# Saved SampleData[JoinedSequencesWithQuality] to: Data/Joined/SeqRun_2_joined.qza

# %%
#import pandas as pd
#met = pd.read_csv('metadata.tsv', sep='\t', index_col='#SampleID')
#
#adapter = len(met.LinkerPrimerSequence.tolist()[0])
#!mkdir Data/Deblur
#for sr in set(met.SeqRun):
#  joined = 'Data/Joined/%s_joined.qza'%sr
#  table = 'Data/Deblur/%s_arc_table.qza'%sr
#  taqzv = 'Data/Deblur/%s_arc_table.qzv'%sr
#  repsq = 'Data/Deblur/%s_arc_rep-seqs.qza'%sr
#  reqzv = 'Data/Deblur/%s_arc_rep-seqs.qzv'%sr
#  stats = 'Data/Deblur/%s_arc_denoising-stats.qza'%sr
#  stqzv = 'Data/Deblur/%s_arc_denoising-stats.qzv'%sr
  
#  !qiime deblur denoise-16S \
#    --i-demultiplexed-seqs $joined \
#    --p-trim-length 300 \
#    --p-jobs-to-start 10 \
#    --o-table $table \
#    --o-representative-sequences $repsq \
#    --o-stats $stats#

#  !qiime feature-table tabulate-seqs \
#    --i-data $repsq \
#    --o-visualization $reqzv

#  !qiime feature-table summarize \
#    --i-table $table \
#    --o-visualization $taqzv \
#    --m-sample-metadata-file metadata.tsv
# Out:
# Saved FeatureTable[Frequency] to: Data/Deblur/SeqRun_2_bac_table.qza
# Saved FeatureData[Sequence] to: Data/Deblur/SeqRun_2_bac_rep-seqs.qza
# Saved DeblurStats to: Data/Deblur/SeqRun_2_bac_denoising-stats.qza
# Saved Visualization to: Data/Deblur/SeqRun_2_bac_rep-seqs.qzv
# Saved Visualization to: Data/Deblur/SeqRun_2_bac_table.qzv

# %% [markdown]
# # Dada2 denoising

# %%
import pandas as pd
met = pd.read_csv('metadata.tsv', sep='\t', index_col='#SampleID')

adapter = len(met.LinkerPrimerSequence.tolist()[0])
# !mkdir Data/Denoised
for sr in set(met.SeqRun):
  cutad = 'Data/Cutadapt/%s_trim.qza'%sr
  table = 'Data/Denoised/%s_arc_table.qza'%sr
  taqzv = 'Data/Denoised/%s_arc_table.qzv'%sr
  repsq = 'Data/Denoised/%s_arc_rep-seqs.qza'%sr
  reqzv = 'Data/Denoised/%s_arc_rep-seqs.qzv'%sr
  stats = 'Data/Denoised/%s_arc_denoising-stats.qza'%sr
  stqzv = 'Data/Denoised/%s_arc_denoising-stats.qzv'%sr
  
  # !qiime dada2 denoise-paired \
    --i-demultiplexed-seqs $cutad \
    --p-trunc-len-f 220 \
    --p-trunc-len-r 240 \
    --p-n-threads 10 \
    --o-table $table \
    --o-representative-sequences $repsq \
    --o-denoising-stats $stats

  # !qiime feature-table tabulate-seqs \
    --i-data $repsq \
    --o-visualization $reqzv

  # !qiime metadata tabulate \
    --m-input-file $stats \
    --o-visualization $stqzv

  # !qiime feature-table summarize \
    --i-table $table \
    --o-visualization $taqzv \
    --m-sample-metadata-file metadata.tsv
# Out:
# Saved FeatureTable[Frequency] to: Data/Denoised/SeqRun_2_arc_table.qza
# Saved FeatureData[Sequence] to: Data/Denoised/SeqRun_2_arc_rep-seqs.qza
# Saved SampleData[DADA2Stats] to: Data/Denoised/SeqRun_2_arc_denoising-stats.qza
# Saved Visualization to: Data/Denoised/SeqRun_2_arc_rep-seqs.qzv
# Saved Visualization to: Data/Denoised/SeqRun_2_arc_denoising-stats.qzv
# Saved Visualization to: Data/Denoised/SeqRun_2_arc_table.qzv

# %%
import pandas as pd
met = pd.read_csv('metadata.tsv', sep='\t', index_col='#SampleID')

adapter = len(met.LinkerPrimerSequence.tolist()[0])
# !mkdir Data/Denoised
for sr in set(met.SeqRun):
  demux = 'Data/Demux/%s_demux.qza'%sr
  table = 'Data/Denoised/%s_arc_table.qza'%sr
  taqzv = 'Data/Denoised/%s_arc_table.qzv'%sr
  repsq = 'Data/Denoised/%s_arc_rep-seqs.qza'%sr
  reqzv = 'Data/Denoised/%s_arc_rep-seqs.qzv'%sr
  stats = 'Data/Denoised/%s_arc_denoising-stats.qza'%sr
  stqzv = 'Data/Denoised/%s_arc_denoising-stats.qzv'%sr
  
  # !qiime dada2 denoise-paired \
    --i-demultiplexed-seqs $demux \
    --p-trim-left-f $adapter \
    --p-trunc-len-f 185 \
    --p-trunc-len-r 230 \
    --p-n-threads 10 \
    --o-table $table \
    --o-representative-sequences $repsq \
    --o-denoising-stats $stats

  # !qiime feature-table tabulate-seqs \
    --i-data $repsq \
    --o-visualization $reqzv

  # !qiime metadata tabulate \
    --m-input-file $stats \
    --o-visualization $stqzv

  # !qiime feature-table summarize \
    --i-table $table \
    --o-visualization $taqzv \
    --m-sample-metadata-file metadata.tsv
# Out:
# mkdir: cannot create directory ‘Data/Denoised’: File exists
# Saved FeatureTable[Frequency] to: Data/Denoised/SeqRun_2_arc_table.qza
# Saved FeatureData[Sequence] to: Data/Denoised/SeqRun_2_arc_rep-seqs.qza
# Saved SampleData[DADA2Stats] to: Data/Denoised/SeqRun_2_arc_denoising-stats.qza
# Saved Visualization to: Data/Denoised/SeqRun_2_arc_rep-seqs.qzv
# Saved Visualization to: Data/Denoised/SeqRun_2_arc_denoising-stats.qzv
# Saved Visualization to: Data/Denoised/SeqRun_2_arc_table.qzv

# %% [markdown]
# # Merge different runs

# %%
#!qiime feature-table merge \
#  --i-tables Data/Denoised/SeqRun_1_bac_table.qza Data/Denoised/SeqRun_2_bac_table.qza \
#  --o-merged-table Data/merged_table.qza

#!qiime feature-table merge-seqs \
#  --i-data Data/Denoised/SeqRun_1_bac_rep-seqs.qza Data/Denoised/SeqRun_2_bac_rep-seqs.qza \
#  --o-merged-data Data/merged_rep-seqs.qza

#!qiime feature-table summarize \
#  --i-table Data/merged_table.qza \
#  --o-visualization Data/merged_table.qzv \
#  --m-sample-metadata-file metadata.tsv
# Out:
# Saved FeatureTable[Frequency] to: Data/merged_table.qza

# %% [markdown]
# # Training feature classifier
# ### 138 Silva db ref-seqs and taxonomy were obtained from Qiime2 website and produced by rescript

# %%
# Extract reference reads
#!qiime feature-classifier extract-reads \
#  --i-sequences Classifier/silva-138-99-seqs.qza \
#  --p-f-primer AGAGTTTGATCCTGGCTCAG \
#  --p-r-primer TGCTGCCTCCCGTAGGAGT \
#  --p-min-length 280 \
#  --p-max-length 500 \
#  --o-reads Classifier/ref-seqs.qza
# Out:
# Usage: qiime feature-classifier extract-reads [OPTIONS]
#
#   Extract simulated amplicon reads from a reference database. Performs in-
#   silico PCR to extract simulated amplicons from reference sequences that
#   match the input primer sequences (within the mismatch threshold specified
#   by `identity`). Both primer sequences must be in the 5' -> 3' orientation.
#   Sequences that fail to match both primers will be excluded. Reads are
#   extracted, trimmed, and filtered in the following order: 1. reads are
#   extracted in specified orientation; 2. primers are removed; 3. reads
#   longer than `max_length` are removed; 4. reads are trimmed with
#   `trim_right`; 5. reads are truncated to `trunc_len`; 6. reads are trimmed
#   with `trim_left`; 7. reads shorter than `min_length` are removed.
#
# Inputs:
#   --i-sequences ARTIFACT FeatureData[Sequence]
#                                                                     [required]
# Parameters:
#   --p-f-primer TEXT       forward primer sequence (5' -> 3').       [required]
#   --p-r-primer TEXT       reverse primer sequence (5' -> 3'). Do not use
#                           reverse-complemented primer sequence.     [required]
#   --p-trim-right INTEGER  trim-right nucleotides are removed from the 3' end
#                           if trim-right is positive. Applied before trunc-len
#                           and trim-left.                          [default: 0]
#   --p-trunc-len INTEGER   read is cut to trunc-len if trunc-len is positive.
#                           Applied after trim-right but before trim-left.
#                                                                   [default: 0]
#   --p-trim-left INTEGER   trim-left nucleotides are removed from the 5' end
#                           if trim-left is positive. Applied after trim-right
#                           and trunc-len.                          [default: 0]
#   --p-identity NUMBER     minimum combined primer match identity threshold.
#                                                                 [default: 0.8]
#   --p-min-length INTEGER  Minimum amplicon length. Shorter amplicons are
#     Range(0, None)        discarded. Applied after trimming and truncation, so
#                           be aware that trimming may impact sequence
#                           retention. Set to zero to disable min length
#                           filtering.                             [default: 50]
#   --p-max-length INTEGER  Maximum amplicon length. Longer amplicons are
#     Range(0, None)        discarded. Applied before trimming and truncation,
#                           so plan accordingly. Set to zero (default) to
#                           disable max length filtering.           [default: 0]
#   --p-n-jobs INTEGER      Number of seperate processes to run.
#     Range(1, None)                                                [default: 1]
#   --p-batch-size VALUE Int % Range(1, None) | Str % Choices('auto')
#                           Number of sequences to process in a batch. The
#                           `auto` option is calculated from the number of
#                           sequences and number of jobs specified.
#                                                              [default: 'auto']
#   --p-read-orientation TEXT Choices('both', 'forward', 'reverse')
#                           Orientation of primers relative to the sequences:
#                           "forward" searches for primer hits in the forward
#                           direction, "reverse" searches reverse-complement,
#                           and "both" searches both directions.
#                                                              [default: 'both']
# Outputs:
#   --o-reads ARTIFACT FeatureData[Sequence]
#                                                                     [required]
# Miscellaneous:
#   --output-dir PATH       Output unspecified results to a directory
#   --verbose / --quiet     Display verbose output to stdout and/or stderr
#                           during execution of this action. Or silence output
#                           if execution is successful (silence is golden).
#   --examples              Show usage examples and exit.
#   --citations             Show citations and exit.
#   --help                  Show this message and exit.
#
#                   There were some problems with the command:
#  (1/2) Missing option '--p-f-primer'.
#  (2/2) Missing option '--p-r-primer'.

# %%
# Train classifier
# !qiime feature-classifier fit-classifier-naive-bayes \
  --i-reference-reads Classifier/silva-138-99-seqs.qza \
  --i-reference-taxonomy Classifier/silva-138-99-tax.qza \
  --o-classifier Classifier/full_silva_138_classifier.qza
# Out:
# Saved TaxonomicClassifier to: Classifier/V1-V2_silva_138_classifier.qza

# %% [markdown]
# # Taxonomy assignment

# %%
# !qiime feature-classifier classify-hybrid-vsearch-sklearn \
  --i-query Data/Denoised/SeqRun_2_arc_rep-seqs.qza \
  --i-reference-reads Classifier/silva-138-99-seqs.qza \
  --i-reference-taxonomy Classifier/silva-138-99-tax.qza \
  --i-classifier Classifier/full_silva_138_classifier.qza \
  --p-threads 1 \
  --p-no-prefilter \
  --o-classification Data/taxonomy_vsearch-sklearn.qza

# !qiime metadata tabulate \
  --m-input-file Data/taxonomy_vsearch-sklearn.qza \
  --o-visualization Data/taxonomy_vsearch-sklearn.qzv
# Out:
# Saved FeatureData[Taxonomy] to: Data/taxonomy_vsearch-sklearn.qza
# Saved Visualization to: Data/taxonomy_vsearch-sklearn.qzv

# %%
#!qiime feature-classifier classify-consensus-blast \
#  --i-query Data/merged_rep-seqs.qza \
#  --i-reference-reads Classifier/ref-seqs.qza \
#  --i-reference-taxonomy Classifier/silva-138-99-tax.qza \
#  --o-classification Data/taxonomy_blast.qza
# Out:
# Saved FeatureData[Taxonomy] to: Data/taxonomy_blast.qza

# %% [markdown]
# # Combo: Combining ASV hashes with last available taxa

# %%
# Install biopython
# !pip install biopython

# %%
import pandas as pd
from Bio import SeqIO

# declare Qiime2 generated artifacts here
table    = 'Data/Denoised/SeqRun_2_arc_table.qza' 
taxo     = 'Data/taxonomy_vsearch-sklearn.qza'
rep_seq  = 'Data/Denoised/SeqRun_2_arc_rep-seqs.qza'

# export rep-seqs.qza, table.qza and taxonomy.qza
# !mkdir Biom Taxa Rep-seqs #temp directories

# !qiime tools export \
  --input-path $table \
  --output-path Biom/

# !qiime tools export \
  --input-path $taxo \
  --output-path Taxa

# !qiime tools export \
  --input-path $rep_seq \
  --output-path Rep-seqs/

# convert .biom to .tsv
# !biom convert -i Biom/feature-table.biom -o Biom/feature-table.tsv --to-tsv 

# *****replacing hashes with combination of taxonomy and beginings of the hashes*****
# reading tables
taxa = pd.read_csv('Taxa/taxonomy.tsv', sep='\t')
biom = pd.read_csv('Biom/feature-table.tsv', sep='\t', skiprows=1)

#creating a new column with modified taxonomy
#I also shortened some annotations and deleted some symbols 
#that were crashing tree construction with modified files
taxa['Taxon'] = taxa.Taxon.replace(';__','').str.replace('[','').str.replace(']','').str.replace('.','')\
.str.replace('/','_').str.replace("'",'').str.replace(' ','_').str.replace('archaeon_enrichment','arc_enrich')\
.str.replace('uncultured_rumen','unc_rum').str.replace('uncultured_archaeon','unc_arc').str.replace('_archaeon','_arc')\
.str.replace('uncultured_compost','unc_comp').str.replace('uncultured_euryarchaeote','unc_euryarc')\
.str.replace('uncultured','unc').str.replace('unidentified','unid')

#dealing with uncultured taxa to provide additional information
taxa['Combo'] =  taxa['Taxon'].str.split("__").str[-1].str.split(";").str[-1]
for x in ['unc_euryarc','unc_rum','unid_methanogen','arc_enrich','unc_arc','unc_comp','unc']:
  taxa.loc[taxa['Combo'].str[:]==x,'Combo']=taxa['Taxon'].str.split("__").str[-2].str.split(';').str[0]+'_'+x
  
for n in range(3,6):
  taxa.loc[taxa.Combo.str[:]=='unc_unc_arc','Combo']=taxa.Taxon.str.split("__").str[-n].str.split(';').str[0]+'_unc_arc'
  taxa.loc[taxa.Combo.str[:]=='unc_unc_rum','Combo']=taxa.Taxon.str.split("__").str[-n].str.split(';').str[0]+'_unc_rum'
  taxa.loc[taxa.Combo.str[:]=='unc_unc','Combo']=taxa.Taxon.str.split("__").str[-n].str.split(';').str[0]+'_unc'
  
#add modified taxonomy information to feature hashes, separating them by '|'
biom['#OTU ID'] = taxa['Combo']+'|'+taxa['Feature ID']
taxa['Feature ID'] = biom['#OTU ID']
taxa = taxa[['Feature ID', 'Taxon', 'Confidence', 'Consensus', 'Method']]

### writing modified files
biom.to_csv('Biom/feature-table.tsv', sep='\t', index=False)
taxa.to_csv('Taxa/taxonomy.tsv', sep='\t', index=False)
fasta_hash  = r"Rep-seqs/dna-sequences.fasta"
fasta_combo = r"Rep-seqs/dna-sequences.fa"
hlist = biom['#OTU ID'].tolist()
with open(fasta_hash) as hashes, open(fasta_combo, 'w') as combo:
  for record in SeqIO.parse(fasta_hash, 'fasta'):
    for h in hlist:
      if str(record.id) in h:
        combo.write('>'+h+'\n'+str(record.seq)+'\n')

#some cleaning and renaming
# !rm $fasta_hash
# !mv $fasta_combo $fasta_hash
# Out:
# mkdir: cannot create directory ‘Biom’: File exists
# mkdir: cannot create directory ‘Taxa’: File exists
# mkdir: cannot create directory ‘Rep-seqs’: File exists
# Exported Data/Denoised/SeqRun_2_arc_table.qza as BIOMV210DirFmt to directory Biom/
# Exported Data/taxonomy_vsearch-sklearn.qza as TSVTaxonomyDirectoryFormat to directory Taxa
# Exported Data/Denoised/SeqRun_2_arc_rep-seqs.qza as DNASequencesDirectoryFormat to directory Rep-seqs/

# %%
#creating new rep-seqs.qza, table.qza and taxonomy.qza with modified hashes (added 'combo_' in the name)
# !biom convert -i Biom/feature-table.tsv -o Biom/feature-table.biom --table-type="OTU table" --to-hdf5

# !qiime tools import \
  --input-path Biom/feature-table.biom \
  --type 'FeatureTable[Frequency]' \
  --input-format BIOMV210Format \
  --output-path Data/combo_table.qza

# !qiime tools import \
  --type 'FeatureData[Taxonomy]' \
  --input-path Taxa/taxonomy.tsv \
  --output-path Data/combo_taxonomy.qza

# !qiime tools import \
  --input-path $fasta_hash \
  --type 'FeatureData[Sequence]' \
  --output-path Data/combo_rep-seqs.qza

# !rm -r Biom Taxa Rep-seqs #clean temp directories

# !qiime feature-table summarize \
  --i-table Data/combo_table.qza \
  --m-sample-metadata-file metadata.tsv \
  --o-visualization Data/combo_table.qzv
# Out:
# Imported Biom/feature-table.biom as BIOMV210Format to Data/combo_table.qza
# Imported Taxa/taxonomy.tsv as TSVTaxonomyDirectoryFormat to Data/combo_taxonomy.qza
# Imported Rep-seqs/dna-sequences.fasta as DNASequencesDirectoryFormat to Data/combo_rep-seqs.qza
# Saved Visualization to: Data/combo_table.qzv

# %% [markdown]
# # Generate a tree for phylogenetic diversity analysis

# %%
# !qiime phylogeny align-to-tree-mafft-fasttree \
  --i-sequences Data/combo_rep-seqs.qza \
  --p-n-threads 10 \
  --o-alignment Data/aligned-rep-seqs.qza \
  --o-masked-alignment Data/masked-aligned-rep-seqs.qza \
  --o-tree Data/unrooted-tree.qza \
  --o-rooted-tree Data/rooted-tree.qza
# Out:
# Saved FeatureData[AlignedSequence] to: Data/aligned-rep-seqs.qza
# Saved FeatureData[AlignedSequence] to: Data/masked-aligned-rep-seqs.qza
# Saved Phylogeny[Unrooted] to: Data/unrooted-tree.qza
# Saved Phylogeny[Rooted] to: Data/rooted-tree.qza

# %% [markdown]
# # Filtration to remove low abundant features

# %%
tabdir = 'Data/Divided_tables'

# !mkdir $tabdir
# !qiime feature-table filter-features \
  --i-table Data/combo_table.qza \
  --p-min-frequency 5 \
  --o-filtered-table $tabdir/full-table.qza

# !qiime taxa filter-table \
  --i-table $tabdir/full-table.qza \
  --i-taxonomy Data/combo_taxonomy.qza \
  --p-exclude mitochondria,chloroplast,d__Bacteria \
  --p-include p__ \
  --o-filtered-table $tabdir/full-table.qza

# !qiime feature-table filter-samples \
  --i-table $tabdir/full-table.qza \
  --p-min-features 5 \
  --p-min-frequency 10 \
  --o-filtered-table $tabdir/full-table.qza

# !qiime feature-table summarize \
  --i-table $tabdir/full-table.qza \
  --o-visualization $tabdir/full-table.qzv \
  --m-sample-metadata-file metadata.tsv
# Out:
# mkdir: cannot create directory ‘Data/Divided_tables’: File exists
# Saved FeatureTable[Frequency] to: Data/Divided_tables/full-table.qza
# Saved FeatureTable[Frequency] to: Data/Divided_tables/full-table.qza
# Saved FeatureTable[Frequency] to: Data/Divided_tables/full-table.qza
# Saved Visualization to: Data/Divided_tables/full-table.qzv

# %% [markdown]
# # Separating table by day and body site for the analysis

# %%
def filt_smpl(tabin,col,tabout):
  # !qiime feature-table filter-samples \
    --i-table $tabin \
    --m-metadata-file metadata.tsv \
    --p-where "$col" \
    --o-filtered-table $tabout

def filt_feat(tabin,minfrq,tabout):
  # !qiime feature-table filter-features \
    --i-table $tabin \
    --p-min-frequency $minfrq \
    --o-filtered-table $tabout
    
def tabqzv(tabin,tabout):
  # !qiime feature-table summarize \
    --i-table $tabin \
    --o-visualization $tabout \
    --m-sample-metadata-file metadata.tsv

# %%
# divide by days 
tabdir = 'Data/Divided_tables'

for t in ['d0-RSP_RF','d7-E_FL','d13-E_FL_SAM_FR', 'd7_d13-E_FL']:
  day = "[Day]='%s'" % t.split('-')[0]
  tab = tabdir+'/%s-table.qza' % t
  tav = tabdir+'/%s-table.qzv' % t
  if t == 'd7_d13-E_FL':
    day = "[Day] IN ('d7','d13') AND NOT [BS] IN ('SAM','FR')"
  filt_smpl(tabdir+'/full-table.qza',day,tab)
  filt_feat(tab,5,tab)
  tabqzv(tab,tav)
# Out:
# Saved FeatureTable[Frequency] to: Data/Divided_tables/d0-RSP_RF-table.qza
# Saved FeatureTable[Frequency] to: Data/Divided_tables/d0-RSP_RF-table.qza
# Saved Visualization to: Data/Divided_tables/d0-RSP_RF-table.qzv
# Saved FeatureTable[Frequency] to: Data/Divided_tables/d7-E_FL-table.qza
# Saved FeatureTable[Frequency] to: Data/Divided_tables/d7-E_FL-table.qza
# Saved Visualization to: Data/Divided_tables/d7-E_FL-table.qzv
# Saved FeatureTable[Frequency] to: Data/Divided_tables/d13-E_FL_SAM_FR-table.qza
# Saved FeatureTable[Frequency] to: Data/Divided_tables/d13-E_FL_SAM_FR-table.qza
# Saved Visualization to: Data/Divided_tables/d13-E_FL_SAM_FR-table.qzv
# Saved FeatureTable[Frequency] to: Data/Divided_tables/d7_d13-E_FL-table.qza
# Saved FeatureTable[Frequency] to: Data/Divided_tables/d7_d13-E_FL-table.qza
# Saved Visualization to: Data/Divided_tables/d7_d13-E_FL-table.qzv

# %% [markdown]
# ### List of all tables produced

# %%
tabdir = 'Data/Divided_tables'
tables = ['d0-RSP_RF','d7-E_FL','d13-E_FL_SAM_FR','d7_d13-E_FL','full']

# %% [markdown]
# # Taxabarplots

# %% [markdown]
# ### By samples

# %%
# !mkdir -p Results/Taxa_barplots/By_samples
tabdir = 'Data/Divided_tables'
tables = ['d0-RSP_RF','d7-E_FL','d13-E_FL_SAM_FR','d7_d13-E_FL','full']
for tab in tables:
  table = tabdir+'/%s-table.qza' % tab
  out = 'Results/Taxa_barplots/By_samples/%s-taxabarplot.qzv' % tab
  
  # !qiime taxa barplot \
    --i-table $table \
    --i-taxonomy Data/combo_taxonomy.qza \
    --m-metadata-file metadata.tsv \
    --o-visualization $out
# Out:
# Saved Visualization to: Results/Taxa_barplots/By_samples/d0-RSP_RF-taxabarplot.qzv
# Saved Visualization to: Results/Taxa_barplots/By_samples/d7-E_FL-taxabarplot.qzv
# Saved Visualization to: Results/Taxa_barplots/By_samples/d13-E_FL_SAM_FR-taxabarplot.qzv
# Saved Visualization to: Results/Taxa_barplots/By_samples/d7_d13-E_FL-taxabarplot.qzv
# Saved Visualization to: Results/Taxa_barplots/By_samples/full-taxabarplot.qzv

# %% [markdown]
# ### By groups

# %%
import pandas as pd

tables = ['d0-RSP_RF','d7-E_FL','d13-E_FL_SAM_FR','d7_d13-E_FL','full']
tabdir = 'Data/Divided_tables'
outres = 'Results/Taxa_barplots/By_groups'
outdat = 'Data/Grouped_tables'
met = pd.read_csv('metadata.tsv',sep='\t',index_col=0)
trash = ['BarcodeSequence','LinkerPrimerSequence','Run_index','Sample Name','Smpl_no','BodySite',\
         'Date of Sampling','Description','Description 2','SeqRun','Src_rstcRun','Day_num','rstc_run']
groups = [col for col in met.columns.tolist() if col not in trash]

for tab in tables:
  tabin = tabdir+'/%s-table.qza' % tab
  
  # !mkdir -p $outres $outdat
  for group in groups:
  #Collapse metadata
    meta = met.drop_duplicates(subset=group).copy()
    meta.index = meta[group]
    meta.index.name = '#SampleID'
    meta.to_csv(outdat+'/%s-%s-metadata.tsv'%(tab,group),sep='\t')
  #Variables    
    grouped = outdat + '/%s-%s-group_table.qza' % (tab,group)
    taxabar = outres + '/%s-%s-taxabarplot.qzv' % (tab,group)
    metadata= outdat + '/%s-%s-metadata.tsv'    % (tab,group)
    
    try:
    #Group tables    
      # !qiime feature-table group \
        --i-table $tabin \
        --p-axis 'sample' \
        --m-metadata-file metadata.tsv \
        --m-metadata-column $group \
        --p-mode 'mean-ceiling' \
        --o-grouped-table $grouped
    #Taxabarplots    
      # !qiime taxa barplot \
        --i-table $grouped \
        --i-taxonomy Data/combo_taxonomy.qza \
        --m-metadata-file $metadata \
        --o-visualization $taxabar
    except:
      print('Looks like there is no %s group in table %s' % (group, tabin))
# Out:
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d0-RSP_RF-BS-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d0-RSP_RF-BS-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d0-RSP_RF-Day-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d0-RSP_RF-Day-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d0-RSP_RF-Day_hour-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d0-RSP_RF-Day_hour-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d0-RSP_RF-Treatment-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d0-RSP_RF-Treatment-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d0-RSP_RF-Source-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d0-RSP_RF-Source-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d0-RSP_RF-BS_Day-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d0-RSP_RF-BS_Day-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d0-RSP_RF-BS_Dh-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d0-RSP_RF-BS_Dh-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d0-RSP_RF-BS_Trt-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d0-RSP_RF-BS_Trt-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d0-RSP_RF-BS_Src-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d0-RSP_RF-BS_Src-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d0-RSP_RF-BS_Day_Trt-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d0-RSP_RF-BS_Day_Trt-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d0-RSP_RF-BS_Day_Src-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d0-RSP_RF-BS_Day_Src-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d0-RSP_RF-BS_Dh_Trt-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d0-RSP_RF-BS_Dh_Trt-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d0-RSP_RF-BS_Dh_Src-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d0-RSP_RF-BS_Dh_Src-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d0-RSP_RF-BS_Trt_Src-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d0-RSP_RF-BS_Trt_Src-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d0-RSP_RF-BS_Day_Trt_Src-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d0-RSP_RF-BS_Day_Trt_Src-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d0-RSP_RF-BS_Dh_Trt_Src-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d0-RSP_RF-BS_Dh_Trt_Src-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d7-E_FL-BS-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d7-E_FL-BS-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d7-E_FL-Day-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d7-E_FL-Day-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d7-E_FL-Day_hour-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d7-E_FL-Day_hour-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d7-E_FL-Treatment-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d7-E_FL-Treatment-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d7-E_FL-Source-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d7-E_FL-Source-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d7-E_FL-BS_Day-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d7-E_FL-BS_Day-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d7-E_FL-BS_Dh-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d7-E_FL-BS_Dh-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d7-E_FL-BS_Trt-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d7-E_FL-BS_Trt-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d7-E_FL-BS_Src-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d7-E_FL-BS_Src-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d7-E_FL-BS_Day_Trt-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d7-E_FL-BS_Day_Trt-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d7-E_FL-BS_Day_Src-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d7-E_FL-BS_Day_Src-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d7-E_FL-BS_Dh_Trt-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d7-E_FL-BS_Dh_Trt-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d7-E_FL-BS_Dh_Src-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d7-E_FL-BS_Dh_Src-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d7-E_FL-BS_Trt_Src-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d7-E_FL-BS_Trt_Src-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d7-E_FL-BS_Day_Trt_Src-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d7-E_FL-BS_Day_Trt_Src-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d7-E_FL-BS_Dh_Trt_Src-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d7-E_FL-BS_Dh_Trt_Src-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d13-E_FL_SAM_FR-BS-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d13-E_FL_SAM_FR-BS-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d13-E_FL_SAM_FR-Day-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d13-E_FL_SAM_FR-Day-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d13-E_FL_SAM_FR-Day_hour-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d13-E_FL_SAM_FR-Day_hour-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d13-E_FL_SAM_FR-Treatment-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d13-E_FL_SAM_FR-Treatment-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d13-E_FL_SAM_FR-Source-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d13-E_FL_SAM_FR-Source-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d13-E_FL_SAM_FR-BS_Day-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d13-E_FL_SAM_FR-BS_Day-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d13-E_FL_SAM_FR-BS_Dh-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d13-E_FL_SAM_FR-BS_Dh-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d13-E_FL_SAM_FR-BS_Trt-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d13-E_FL_SAM_FR-BS_Trt-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d13-E_FL_SAM_FR-BS_Src-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d13-E_FL_SAM_FR-BS_Src-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d13-E_FL_SAM_FR-BS_Day_Trt-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d13-E_FL_SAM_FR-BS_Day_Trt-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d13-E_FL_SAM_FR-BS_Day_Src-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d13-E_FL_SAM_FR-BS_Day_Src-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d13-E_FL_SAM_FR-BS_Dh_Trt-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d13-E_FL_SAM_FR-BS_Dh_Trt-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d13-E_FL_SAM_FR-BS_Dh_Src-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d13-E_FL_SAM_FR-BS_Dh_Src-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d13-E_FL_SAM_FR-BS_Trt_Src-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d13-E_FL_SAM_FR-BS_Trt_Src-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d13-E_FL_SAM_FR-BS_Day_Trt_Src-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d13-E_FL_SAM_FR-BS_Day_Trt_Src-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d13-E_FL_SAM_FR-BS_Dh_Trt_Src-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d13-E_FL_SAM_FR-BS_Dh_Trt_Src-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d7_d13-E_FL-BS-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d7_d13-E_FL-BS-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d7_d13-E_FL-Day-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d7_d13-E_FL-Day-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d7_d13-E_FL-Day_hour-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d7_d13-E_FL-Day_hour-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d7_d13-E_FL-Treatment-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d7_d13-E_FL-Treatment-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d7_d13-E_FL-Source-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d7_d13-E_FL-Source-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d7_d13-E_FL-BS_Day-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d7_d13-E_FL-BS_Day-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d7_d13-E_FL-BS_Dh-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d7_d13-E_FL-BS_Dh-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d7_d13-E_FL-BS_Trt-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d7_d13-E_FL-BS_Trt-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d7_d13-E_FL-BS_Src-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d7_d13-E_FL-BS_Src-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d7_d13-E_FL-BS_Day_Trt-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d7_d13-E_FL-BS_Day_Trt-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d7_d13-E_FL-BS_Day_Src-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d7_d13-E_FL-BS_Day_Src-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d7_d13-E_FL-BS_Dh_Trt-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d7_d13-E_FL-BS_Dh_Trt-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d7_d13-E_FL-BS_Dh_Src-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d7_d13-E_FL-BS_Dh_Src-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d7_d13-E_FL-BS_Trt_Src-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d7_d13-E_FL-BS_Trt_Src-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d7_d13-E_FL-BS_Day_Trt_Src-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d7_d13-E_FL-BS_Day_Trt_Src-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/d7_d13-E_FL-BS_Dh_Trt_Src-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/d7_d13-E_FL-BS_Dh_Trt_Src-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/full-BS-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/full-BS-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/full-Day-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/full-Day-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/full-Day_hour-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/full-Day_hour-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/full-Treatment-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/full-Treatment-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/full-Source-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/full-Source-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/full-BS_Day-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/full-BS_Day-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/full-BS_Dh-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/full-BS_Dh-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/full-BS_Trt-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/full-BS_Trt-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/full-BS_Src-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/full-BS_Src-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/full-BS_Day_Trt-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/full-BS_Day_Trt-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/full-BS_Day_Src-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/full-BS_Day_Src-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/full-BS_Dh_Trt-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/full-BS_Dh_Trt-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/full-BS_Dh_Src-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/full-BS_Dh_Src-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/full-BS_Trt_Src-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/full-BS_Trt_Src-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/full-BS_Day_Trt_Src-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/full-BS_Day_Trt_Src-taxabarplot.qzv
# Saved FeatureTable[Frequency] to: Data/Grouped_tables/full-BS_Dh_Trt_Src-group_table.qza
# Saved Visualization to: Results/Taxa_barplots/By_groups/full-BS_Dh_Trt_Src-taxabarplot.qzv

# %% [markdown]
# # Alpha and beta diversity analysis

# %% [markdown]
# ### Alpha rarefaction plotting

# %%
# !qiime diversity alpha-rarefaction \
  --i-table Data/Divided_tables/full-table.qza \
  --i-phylogeny Data/rooted-tree.qza \
  --p-max-depth 30000 \
  --m-metadata-file metadata.tsv \
  --o-visualization Results/Alpha_rarefaction.qzv
# Out:
# Saved Visualization to: Results/Alpha_rarefaction.qzv

# %% [markdown]
# ### Core-metrics-phylogenetic: Core diversity metrics (phylogenetic and non-phylogenetic)

# %%
# !qiime diversity core-metrics-phylogenetic \
  --i-phylogeny Data/rooted-tree.qza \
  --i-table Data/Divided_tables/full-table.qza \
  --p-sampling-depth 4455 \
  --m-metadata-file metadata.tsv \
  --p-n-jobs-or-threads 'auto' \
  --output-dir Results/Core-metrics
# Out:
# Saved FeatureTable[Frequency] to: Results/Core-metrics/rarefied_table.qza
# Saved SampleData[AlphaDiversity] to: Results/Core-metrics/faith_pd_vector.qza
# Saved SampleData[AlphaDiversity] to: Results/Core-metrics/observed_features_vector.qza
# Saved SampleData[AlphaDiversity] to: Results/Core-metrics/shannon_vector.qza
# Saved SampleData[AlphaDiversity] to: Results/Core-metrics/evenness_vector.qza
# Saved DistanceMatrix to: Results/Core-metrics/unweighted_unifrac_distance_matrix.qza
# Saved DistanceMatrix to: Results/Core-metrics/weighted_unifrac_distance_matrix.qza
# Saved DistanceMatrix to: Results/Core-metrics/jaccard_distance_matrix.qza
# Saved DistanceMatrix to: Results/Core-metrics/bray_curtis_distance_matrix.qza
# Saved PCoAResults to: Results/Core-metrics/unweighted_unifrac_pcoa_results.qza
# Saved PCoAResults to: Results/Core-metrics/weighted_unifrac_pcoa_results.qza
# Saved PCoAResults to: Results/Core-metrics/jaccard_pcoa_results.qza
# Saved PCoAResults to: Results/Core-metrics/bray_curtis_pcoa_results.qza
# Saved Visualization to: Results/Core-metrics/unweighted_unifrac_emperor.qzv
# Saved Visualization to: Results/Core-metrics/weighted_unifrac_emperor.qzv
# Saved Visualization to: Results/Core-metrics/jaccard_emperor.qzv
# Saved Visualization to: Results/Core-metrics/bray_curtis_emperor.qzv

# %% [markdown]
# ### Principal Coordinate Analysis Biplot

# %%
table = 'Data/Divided_tables/full-table.qza'
reltab = 'Data/Relative_tables/full-relative_table.qza'
  
  # Converting feature table [Frequency] to [Relative frequency]
# !mkdir Data/Relative_tables
# !qiime feature-table relative-frequency \
  --i-table Data/Divided_tables/full-table.qza \
  --o-relative-frequency-table $reltab

for artifact in ['unweighted_unifrac', 'weighted_unifrac', 'jaccard', 'bray_curtis']:
  pcoa  = 'Results/Core-metrics/%s_pcoa_results.qza' % artifact
  bidir = 'Results/Biplots/Biplots_full'
  biplot= bidir+'/%s_biplot.qza' % artifact
  bi_qzv= bidir+'/%s_biplot.qzv' % artifact

  # !mkdir -p $bidir
    
  # pcoa-biplot: Principal Coordinate Analysis Biplot     
  # !qiime diversity pcoa-biplot \
    --i-pcoa $pcoa \
    --i-features $reltab \
    --o-biplot $biplot

  # !qiime emperor biplot \
    --i-biplot $biplot \
    --m-sample-metadata-file metadata.tsv \
    --p-ignore-missing-samples \
    --p-number-of-features 5 \
    --o-visualization $bi_qzv
# Out:
# mkdir: cannot create directory ‘Data/Relative_tables’: File exists
# Saved FeatureTable[RelativeFrequency] to: Data/Relative_tables/full-relative_table.qza
# Saved PCoAResults % Properties('biplot') to: Results/Biplots/Biplots_full/unweighted_unifrac_biplot.qza
# Saved Visualization to: Results/Biplots/Biplots_full/unweighted_unifrac_biplot.qzv
# Saved PCoAResults % Properties('biplot') to: Results/Biplots/Biplots_full/weighted_unifrac_biplot.qza
# Saved Visualization to: Results/Biplots/Biplots_full/weighted_unifrac_biplot.qzv
# Saved PCoAResults % Properties('biplot') to: Results/Biplots/Biplots_full/jaccard_biplot.qza
# Saved Visualization to: Results/Biplots/Biplots_full/jaccard_biplot.qzv
# Saved PCoAResults % Properties('biplot') to: Results/Biplots/Biplots_full/bray_curtis_biplot.qza
# Saved Visualization to: Results/Biplots/Biplots_full/bray_curtis_biplot.qzv

# %%
### Filtering beta diversity distances

# %% [markdown]
# ### Beta diversity comparisons

# %%
import pandas as pd

tabdir = 'Data/Divided_tables'
tables = ['d0-RSP_RF','d7-E_FL','d13-E_FL_SAM_FR','d7_d13-E_FL','full']

meta = pd.read_csv('metadata.tsv',sep='\t',index_col=0)
trash = ['BarcodeSequence','LinkerPrimerSequence','Run_index','Sample Name','Smpl_no',\
         'Date of Sampling','Description','Description 2','SeqRun','Src_rstcRun','Day_num']
groups = [col for col in meta.columns.tolist() if col not in trash]

for tab in tables:
  for beta in ['unweighted_unifrac', 'weighted_unifrac', 'jaccard', 'bray_curtis']:
    outdir  = 'Results/Beta_comparisons/Beta_compar_%s'% tab
    distance= 'Results/Core-metrics/Core_%s/%s_distance_matrix.qza' % (tab,beta)
    
    # !mkdir -p $outdir
    
    for column in groups:
      bgs_qzv = outdir+'/%s_%s_beta-group-sign-pairwise.qzv' % (column, beta)
   
      # !qiime diversity beta-group-significance \
        --i-distance-matrix $distance \
        --m-metadata-file metadata.tsv \
        --m-metadata-column $column \
        --p-pairwise \
        --o-visualization $bgs_qzv
# Out:
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BodySite_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/rstc_run_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Plugin error from diversity:
#
#   All values in the grouping vector are the same. This method cannot operate on a grouping vector with only a single group of objects (e.g., there are no 'between' distances because there is only a single group).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-vh0e01dn.log
# Plugin error from diversity:
#
#   All values in the grouping vector are the same. This method cannot operate on a grouping vector with only a single group of objects (e.g., there are no 'between' distances because there is only a single group).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-bj699yz6.log
# Plugin error from diversity:
#
#   All values in the grouping vector are the same. This method cannot operate on a grouping vector with only a single group of objects (e.g., there are no 'between' distances because there is only a single group).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-6vgmk4ir.log
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/Source_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_Day_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_Dh_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_Trt_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_Src_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_Day_Trt_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_Day_Src_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_Dh_Trt_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_Dh_Src_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_Trt_Src_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_Day_Trt_Src_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_Dh_Trt_Src_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BodySite_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/rstc_run_weighted_unifrac_beta-group-sign-pairwise.qzv
# Plugin error from diversity:
#
#   All values in the grouping vector are the same. This method cannot operate on a grouping vector with only a single group of objects (e.g., there are no 'between' distances because there is only a single group).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-dsbqoqpv.log
# Plugin error from diversity:
#
#   All values in the grouping vector are the same. This method cannot operate on a grouping vector with only a single group of objects (e.g., there are no 'between' distances because there is only a single group).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-pnag9olv.log
# Plugin error from diversity:
#
#   All values in the grouping vector are the same. This method cannot operate on a grouping vector with only a single group of objects (e.g., there are no 'between' distances because there is only a single group).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-18fq0v0a.log
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/Source_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_Day_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_Dh_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_Trt_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_Src_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_Day_Trt_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_Day_Src_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_Dh_Trt_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_Dh_Src_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_Trt_Src_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_Day_Trt_Src_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_Dh_Trt_Src_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BodySite_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/rstc_run_jaccard_beta-group-sign-pairwise.qzv
# Plugin error from diversity:
#
#   All values in the grouping vector are the same. This method cannot operate on a grouping vector with only a single group of objects (e.g., there are no 'between' distances because there is only a single group).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-948f40w9.log
# Plugin error from diversity:
#
#   All values in the grouping vector are the same. This method cannot operate on a grouping vector with only a single group of objects (e.g., there are no 'between' distances because there is only a single group).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-nr2lukj5.log
# Plugin error from diversity:
#
#   All values in the grouping vector are the same. This method cannot operate on a grouping vector with only a single group of objects (e.g., there are no 'between' distances because there is only a single group).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-2atemmsw.log
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/Source_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_Day_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_Dh_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_Trt_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_Src_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_Day_Trt_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_Day_Src_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_Dh_Trt_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_Dh_Src_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_Trt_Src_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_Day_Trt_Src_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_Dh_Trt_Src_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BodySite_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/rstc_run_bray_curtis_beta-group-sign-pairwise.qzv
# Plugin error from diversity:
#
#   All values in the grouping vector are the same. This method cannot operate on a grouping vector with only a single group of objects (e.g., there are no 'between' distances because there is only a single group).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-sqp8053z.log
# Plugin error from diversity:
#
#   All values in the grouping vector are the same. This method cannot operate on a grouping vector with only a single group of objects (e.g., there are no 'between' distances because there is only a single group).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-d4n__xij.log
# Plugin error from diversity:
#
#   All values in the grouping vector are the same. This method cannot operate on a grouping vector with only a single group of objects (e.g., there are no 'between' distances because there is only a single group).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-h78v6db4.log
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/Source_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_Day_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_Dh_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_Trt_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_Src_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_Day_Trt_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_Day_Src_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_Dh_Trt_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_Dh_Src_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_Trt_Src_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_Day_Trt_Src_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d0-RSP_RF/BS_Dh_Trt_Src_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BodySite_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/rstc_run_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Plugin error from diversity:
#
#   All values in the grouping vector are the same. This method cannot operate on a grouping vector with only a single group of objects (e.g., there are no 'between' distances because there is only a single group).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-o5yph2gc.log
# Plugin error from diversity:
#
#   All values in the grouping vector are the same. This method cannot operate on a grouping vector with only a single group of objects (e.g., there are no 'between' distances because there is only a single group).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-ro8w5oix.log
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/Treatment_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/Source_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_Day_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_Dh_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_Trt_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_Src_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_Day_Trt_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_Day_Src_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_Dh_Trt_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_Dh_Src_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_Trt_Src_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_Day_Trt_Src_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_Dh_Trt_Src_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BodySite_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/rstc_run_weighted_unifrac_beta-group-sign-pairwise.qzv
# Plugin error from diversity:
#
#   All values in the grouping vector are the same. This method cannot operate on a grouping vector with only a single group of objects (e.g., there are no 'between' distances because there is only a single group).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-flpqt56n.log
# Plugin error from diversity:
#
#   All values in the grouping vector are the same. This method cannot operate on a grouping vector with only a single group of objects (e.g., there are no 'between' distances because there is only a single group).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-51rl6huq.log
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/Treatment_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/Source_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_Day_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_Dh_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_Trt_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_Src_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_Day_Trt_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_Day_Src_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_Dh_Trt_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_Dh_Src_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_Trt_Src_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_Day_Trt_Src_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_Dh_Trt_Src_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BodySite_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/rstc_run_jaccard_beta-group-sign-pairwise.qzv
# Plugin error from diversity:
#
#   All values in the grouping vector are the same. This method cannot operate on a grouping vector with only a single group of objects (e.g., there are no 'between' distances because there is only a single group).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-t2v6c2sn.log
# Plugin error from diversity:
#
#   All values in the grouping vector are the same. This method cannot operate on a grouping vector with only a single group of objects (e.g., there are no 'between' distances because there is only a single group).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-smj6aovm.log
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/Treatment_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/Source_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_Day_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_Dh_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_Trt_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_Src_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_Day_Trt_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_Day_Src_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_Dh_Trt_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_Dh_Src_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_Trt_Src_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_Day_Trt_Src_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_Dh_Trt_Src_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BodySite_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/rstc_run_bray_curtis_beta-group-sign-pairwise.qzv
# Plugin error from diversity:
#
#   All values in the grouping vector are the same. This method cannot operate on a grouping vector with only a single group of objects (e.g., there are no 'between' distances because there is only a single group).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-5e4dopib.log
# Plugin error from diversity:
#
#   All values in the grouping vector are the same. This method cannot operate on a grouping vector with only a single group of objects (e.g., there are no 'between' distances because there is only a single group).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-1awa2j8_.log
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/Treatment_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/Source_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_Day_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_Dh_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_Trt_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_Src_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_Day_Trt_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_Day_Src_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_Dh_Trt_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_Dh_Src_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_Trt_Src_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_Day_Trt_Src_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7-E_FL/BS_Dh_Trt_Src_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/BodySite_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/BS_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/rstc_run_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Plugin error from diversity:
#
#   All values in the grouping vector are the same. This method cannot operate on a grouping vector with only a single group of objects (e.g., there are no 'between' distances because there is only a single group).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-9dnt7gdg.log
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/Day_hour_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/Treatment_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/Source_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/BS_Day_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/BS_Dh_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/BS_Trt_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/BS_Src_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/BS_Day_Trt_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/BS_Day_Src_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/BS_Dh_Trt_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/BS_Dh_Src_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Plugin error from diversity:
#
#   All values in the grouping vector are unique. This method cannot operate on a grouping vector with only unique values (e.g., there are no 'within' distances because each group of objects contains only a single object).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-emiqmj9j.log
# Plugin error from diversity:
#
#   All values in the grouping vector are unique. This method cannot operate on a grouping vector with only unique values (e.g., there are no 'within' distances because each group of objects contains only a single object).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-z4zjisgc.log
# Plugin error from diversity:
#
#   All values in the grouping vector are unique. This method cannot operate on a grouping vector with only unique values (e.g., there are no 'within' distances because each group of objects contains only a single object).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-xg7m0cee.log
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/BodySite_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/BS_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/rstc_run_weighted_unifrac_beta-group-sign-pairwise.qzv
# Plugin error from diversity:
#
#   All values in the grouping vector are the same. This method cannot operate on a grouping vector with only a single group of objects (e.g., there are no 'between' distances because there is only a single group).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-l9kuzwto.log
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/Day_hour_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/Treatment_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/Source_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/BS_Day_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/BS_Dh_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/BS_Trt_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/BS_Src_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/BS_Day_Trt_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/BS_Day_Src_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/BS_Dh_Trt_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/BS_Dh_Src_weighted_unifrac_beta-group-sign-pairwise.qzv
# Plugin error from diversity:
#
#   All values in the grouping vector are unique. This method cannot operate on a grouping vector with only unique values (e.g., there are no 'within' distances because each group of objects contains only a single object).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-ppuuuhki.log
# Plugin error from diversity:
#
#   All values in the grouping vector are unique. This method cannot operate on a grouping vector with only unique values (e.g., there are no 'within' distances because each group of objects contains only a single object).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-u31r2dla.log
# Plugin error from diversity:
#
#   All values in the grouping vector are unique. This method cannot operate on a grouping vector with only unique values (e.g., there are no 'within' distances because each group of objects contains only a single object).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-s4mciho8.log
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/BodySite_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/BS_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/rstc_run_jaccard_beta-group-sign-pairwise.qzv
# Plugin error from diversity:
#
#   All values in the grouping vector are the same. This method cannot operate on a grouping vector with only a single group of objects (e.g., there are no 'between' distances because there is only a single group).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-k3eev55v.log
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/Day_hour_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/Treatment_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/Source_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/BS_Day_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/BS_Dh_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/BS_Trt_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/BS_Src_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/BS_Day_Trt_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/BS_Day_Src_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/BS_Dh_Trt_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/BS_Dh_Src_jaccard_beta-group-sign-pairwise.qzv
# Plugin error from diversity:
#
#   All values in the grouping vector are unique. This method cannot operate on a grouping vector with only unique values (e.g., there are no 'within' distances because each group of objects contains only a single object).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-hsm4fuij.log
# Plugin error from diversity:
#
#   All values in the grouping vector are unique. This method cannot operate on a grouping vector with only unique values (e.g., there are no 'within' distances because each group of objects contains only a single object).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-3yh6rbcq.log
# Plugin error from diversity:
#
#   All values in the grouping vector are unique. This method cannot operate on a grouping vector with only unique values (e.g., there are no 'within' distances because each group of objects contains only a single object).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-y36ybsht.log
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/BodySite_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/BS_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/rstc_run_bray_curtis_beta-group-sign-pairwise.qzv
# Plugin error from diversity:
#
#   All values in the grouping vector are the same. This method cannot operate on a grouping vector with only a single group of objects (e.g., there are no 'between' distances because there is only a single group).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-35zqx4r1.log
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/Day_hour_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/Treatment_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/Source_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/BS_Day_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/BS_Dh_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/BS_Trt_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/BS_Src_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/BS_Day_Trt_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/BS_Day_Src_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/BS_Dh_Trt_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d13-E_FL_SAM_FR/BS_Dh_Src_bray_curtis_beta-group-sign-pairwise.qzv
# Plugin error from diversity:
#
#   All values in the grouping vector are unique. This method cannot operate on a grouping vector with only unique values (e.g., there are no 'within' distances because each group of objects contains only a single object).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-n_svjufr.log
# Plugin error from diversity:
#
#   All values in the grouping vector are unique. This method cannot operate on a grouping vector with only unique values (e.g., there are no 'within' distances because each group of objects contains only a single object).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-hwc3qkjb.log
# Plugin error from diversity:
#
#   All values in the grouping vector are unique. This method cannot operate on a grouping vector with only unique values (e.g., there are no 'within' distances because each group of objects contains only a single object).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-16rrvvsr.log
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BodySite_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BS_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/rstc_run_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/Day_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Plugin error from diversity:
#
#   All values in the grouping vector are the same. This method cannot operate on a grouping vector with only a single group of objects (e.g., there are no 'between' distances because there is only a single group).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-fy1ahjpy.log
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/Treatment_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/Source_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BS_Day_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BS_Dh_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BS_Trt_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BS_Src_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BS_Day_Trt_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BS_Day_Src_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BS_Dh_Trt_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BS_Dh_Src_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BS_Trt_Src_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Plugin error from diversity:
#
#   All values in the grouping vector are unique. This method cannot operate on a grouping vector with only unique values (e.g., there are no 'within' distances because each group of objects contains only a single object).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-13i19e02.log
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BS_Dh_Trt_Src_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BodySite_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BS_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/rstc_run_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/Day_weighted_unifrac_beta-group-sign-pairwise.qzv
# Plugin error from diversity:
#
#   All values in the grouping vector are the same. This method cannot operate on a grouping vector with only a single group of objects (e.g., there are no 'between' distances because there is only a single group).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-5scyz9lh.log
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/Treatment_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/Source_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BS_Day_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BS_Dh_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BS_Trt_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BS_Src_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BS_Day_Trt_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BS_Day_Src_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BS_Dh_Trt_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BS_Dh_Src_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BS_Trt_Src_weighted_unifrac_beta-group-sign-pairwise.qzv
# Plugin error from diversity:
#
#   All values in the grouping vector are unique. This method cannot operate on a grouping vector with only unique values (e.g., there are no 'within' distances because each group of objects contains only a single object).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-uaxnpv6z.log
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BS_Dh_Trt_Src_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BodySite_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BS_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/rstc_run_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/Day_jaccard_beta-group-sign-pairwise.qzv
# Plugin error from diversity:
#
#   All values in the grouping vector are the same. This method cannot operate on a grouping vector with only a single group of objects (e.g., there are no 'between' distances because there is only a single group).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-rmiou51m.log
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/Treatment_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/Source_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BS_Day_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BS_Dh_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BS_Trt_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BS_Src_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BS_Day_Trt_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BS_Day_Src_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BS_Dh_Trt_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BS_Dh_Src_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BS_Trt_Src_jaccard_beta-group-sign-pairwise.qzv
# Plugin error from diversity:
#
#   All values in the grouping vector are unique. This method cannot operate on a grouping vector with only unique values (e.g., there are no 'within' distances because each group of objects contains only a single object).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-0gub5ih2.log
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BS_Dh_Trt_Src_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BodySite_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BS_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/rstc_run_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/Day_bray_curtis_beta-group-sign-pairwise.qzv
# Plugin error from diversity:
#
#   All values in the grouping vector are the same. This method cannot operate on a grouping vector with only a single group of objects (e.g., there are no 'between' distances because there is only a single group).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-bu6n7gfh.log
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/Treatment_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/Source_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BS_Day_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BS_Dh_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BS_Trt_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BS_Src_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BS_Day_Trt_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BS_Day_Src_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BS_Dh_Trt_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BS_Dh_Src_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BS_Trt_Src_bray_curtis_beta-group-sign-pairwise.qzv
# Plugin error from diversity:
#
#   All values in the grouping vector are unique. This method cannot operate on a grouping vector with only unique values (e.g., there are no 'within' distances because each group of objects contains only a single object).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-1ijg78cl.log
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_d7_d13-E_FL/BS_Dh_Trt_Src_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/BodySite_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/BS_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/rstc_run_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/Day_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/Day_hour_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/Treatment_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/Source_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/BS_Day_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/BS_Dh_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/BS_Trt_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/BS_Src_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/BS_Day_Trt_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/BS_Day_Src_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/BS_Dh_Trt_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/BS_Dh_Src_unweighted_unifrac_beta-group-sign-pairwise.qzv
# Plugin error from diversity:
#
#   All values in the grouping vector are unique. This method cannot operate on a grouping vector with only unique values (e.g., there are no 'within' distances because each group of objects contains only a single object).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-lrpkmmcd.log
# Plugin error from diversity:
#
#   All values in the grouping vector are unique. This method cannot operate on a grouping vector with only unique values (e.g., there are no 'within' distances because each group of objects contains only a single object).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-79fg_gmg.log
# Plugin error from diversity:
#
#   All values in the grouping vector are unique. This method cannot operate on a grouping vector with only unique values (e.g., there are no 'within' distances because each group of objects contains only a single object).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-hfkj4o5n.log
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/BodySite_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/BS_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/rstc_run_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/Day_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/Day_hour_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/Treatment_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/Source_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/BS_Day_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/BS_Dh_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/BS_Trt_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/BS_Src_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/BS_Day_Trt_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/BS_Day_Src_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/BS_Dh_Trt_weighted_unifrac_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/BS_Dh_Src_weighted_unifrac_beta-group-sign-pairwise.qzv
# Plugin error from diversity:
#
#   All values in the grouping vector are unique. This method cannot operate on a grouping vector with only unique values (e.g., there are no 'within' distances because each group of objects contains only a single object).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-l0h802xy.log
# Plugin error from diversity:
#
#   All values in the grouping vector are unique. This method cannot operate on a grouping vector with only unique values (e.g., there are no 'within' distances because each group of objects contains only a single object).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-p_xhkwb_.log
# Plugin error from diversity:
#
#   All values in the grouping vector are unique. This method cannot operate on a grouping vector with only unique values (e.g., there are no 'within' distances because each group of objects contains only a single object).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-pf3zmgbk.log
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/BodySite_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/BS_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/rstc_run_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/Day_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/Day_hour_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/Treatment_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/Source_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/BS_Day_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/BS_Dh_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/BS_Trt_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/BS_Src_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/BS_Day_Trt_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/BS_Day_Src_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/BS_Dh_Trt_jaccard_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/BS_Dh_Src_jaccard_beta-group-sign-pairwise.qzv
# Plugin error from diversity:
#
#   All values in the grouping vector are unique. This method cannot operate on a grouping vector with only unique values (e.g., there are no 'within' distances because each group of objects contains only a single object).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-yef3cggr.log
# Plugin error from diversity:
#
#   All values in the grouping vector are unique. This method cannot operate on a grouping vector with only unique values (e.g., there are no 'within' distances because each group of objects contains only a single object).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-wdmny5d5.log
# Plugin error from diversity:
#
#   All values in the grouping vector are unique. This method cannot operate on a grouping vector with only unique values (e.g., there are no 'within' distances because each group of objects contains only a single object).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-7dql9isl.log
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/BodySite_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/BS_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/rstc_run_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/Day_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/Day_hour_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/Treatment_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/Source_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/BS_Day_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/BS_Dh_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/BS_Trt_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/BS_Src_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/BS_Day_Trt_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/BS_Day_Src_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/BS_Dh_Trt_bray_curtis_beta-group-sign-pairwise.qzv
# Saved Visualization to: Results/Beta_comparisons/Beta_compar_full/BS_Dh_Src_bray_curtis_beta-group-sign-pairwise.qzv
# Plugin error from diversity:
#
#   All values in the grouping vector are unique. This method cannot operate on a grouping vector with only unique values (e.g., there are no 'within' distances because each group of objects contains only a single object).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-6oqxhdj4.log
# Plugin error from diversity:
#
#   All values in the grouping vector are unique. This method cannot operate on a grouping vector with only unique values (e.g., there are no 'within' distances because each group of objects contains only a single object).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-_2w0hdqp.log
# Plugin error from diversity:
#
#   All values in the grouping vector are unique. This method cannot operate on a grouping vector with only unique values (e.g., there are no 'within' distances because each group of objects contains only a single object).
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-pi2etx2r.log

# %% [markdown]
# ### Adonis

# %%
import pandas as pd

tabdir = 'Data/Divided_tables'
tables = ['d7-E_FL','d13-E_FL_SAM_FR','d7_d13-E_FL','full']

meta = pd.read_csv('metadata.tsv',sep='\t',index_col=0)
trash = ['BarcodeSequence','LinkerPrimerSequence','Run_index','Sample Name','Smpl_no',\
         'Date of Sampling','Description','Description 2','SeqRun','Src_rstcRun','Day_num']
groups = [col for col in meta.columns.tolist() if col not in trash]
formula = 'BS*Treatment*Source'

for tab in tables:
  if tab == 'd13-E_FL_SAM_FR':
    formula = 'BS*Treatment*Source*Day_hour'
  if tab == 'd7_d13-E_FL':
    formula = 'BS*Treatment*Source*Day'
  for beta in ['unweighted_unifrac', 'weighted_unifrac', 'jaccard', 'bray_curtis']:
    outdir  = 'Results/Adonis/Adonis_%s'% tab
    distance= 'Results/Core-metrics/Core_%s/%s_distance_matrix.qza' % (tab,beta)
    
    # !mkdir -p $outdir
    adonis = outdir+'/%s_adonis.qzv' % beta

    # !qiime diversity adonis \
      --i-distance-matrix $distance \
      --m-metadata-file metadata.tsv \
      --p-formula "$formula" \
      --p-n-jobs 10 \
      --o-visualization $adonis
# Out:
# Plugin error from diversity:
#
#   Command '['run_adonis.R', '/tmp/tmpz27137f5/dm.tsv', '/tmp/tmpz27137f5/md.tsv', 'BS*Treatment*Source', '999', '10', '/tmp/qiime2-temp-m8ud9d0h/adonis.tsv']' returned non-zero exit status 1.
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-syli5gkw.log
# Plugin error from diversity:
#
#   Command '['run_adonis.R', '/tmp/tmps0bn9jit/dm.tsv', '/tmp/tmps0bn9jit/md.tsv', 'BS*Treatment*Source', '999', '10', '/tmp/qiime2-temp-51a29kho/adonis.tsv']' returned non-zero exit status 1.
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-uuxc8ub4.log
# Plugin error from diversity:
#
#   Command '['run_adonis.R', '/tmp/tmpc1dvfqo0/dm.tsv', '/tmp/tmpc1dvfqo0/md.tsv', 'BS*Treatment*Source', '999', '10', '/tmp/qiime2-temp-klu7gjh4/adonis.tsv']' returned non-zero exit status 1.
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-wx1my7nw.log
# Plugin error from diversity:
#
#   Command '['run_adonis.R', '/tmp/tmpqhp36x3o/dm.tsv', '/tmp/tmpqhp36x3o/md.tsv', 'BS*Treatment*Source', '999', '10', '/tmp/qiime2-temp-f50zkk5q/adonis.tsv']' returned non-zero exit status 1.
#
# Debug info has been saved to /tmp/qiime2-q2cli-err-il_o5wm4.log
# Saved Visualization to: Results/Adonis/Adonis_d7-E_FL/unweighted_unifrac_adonis.qzv
# Saved Visualization to: Results/Adonis/Adonis_d7-E_FL/weighted_unifrac_adonis.qzv
# Saved Visualization to: Results/Adonis/Adonis_d7-E_FL/jaccard_adonis.qzv
# Saved Visualization to: Results/Adonis/Adonis_d7-E_FL/bray_curtis_adonis.qzv
# Saved Visualization to: Results/Adonis/Adonis_d13-E_FL_SAM_FR/unweighted_unifrac_adonis.qzv
# Saved Visualization to: Results/Adonis/Adonis_d13-E_FL_SAM_FR/weighted_unifrac_adonis.qzv
# Saved Visualization to: Results/Adonis/Adonis_d13-E_FL_SAM_FR/jaccard_adonis.qzv
# Saved Visualization to: Results/Adonis/Adonis_d13-E_FL_SAM_FR/bray_curtis_adonis.qzv
# Saved Visualization to: Results/Adonis/Adonis_d7_d13-E_FL/unweighted_unifrac_adonis.qzv
# Saved Visualization to: Results/Adonis/Adonis_d7_d13-E_FL/weighted_unifrac_adonis.qzv
# Saved Visualization to: Results/Adonis/Adonis_d7_d13-E_FL/jaccard_adonis.qzv
# Saved Visualization to: Results/Adonis/Adonis_d7_d13-E_FL/bray_curtis_adonis.qzv
# Saved Visualization to: Results/Adonis/Adonis_full/unweighted_unifrac_adonis.qzv
# Saved Visualization to: Results/Adonis/Adonis_full/weighted_unifrac_adonis.qzv
# Saved Visualization to: Results/Adonis/Adonis_full/jaccard_adonis.qzv
# Saved Visualization to: Results/Adonis/Adonis_full/bray_curtis_adonis.qzv

# %% [markdown]
# # ANCOM

# %%
# !mkdir Results/ANCOM
def Ancom(column, ancom):
  ctable = 'Results/ANCOM/ctable.qza'
  # !qiime composition add-pseudocount \
    --i-table Results/ANCOM/table.qza \
    --o-composition-table $ctable
  # !qiime composition ancom \
    --i-table $ctable \
    --m-metadata-file metadata.tsv \
    --m-metadata-column $column \
    --o-visualization $ancom
  # !rm $ctable
    
def Ancol(lev, column, ancol):
  ctable = 'Results/ANCOM/ctable.qza'
  ltable = 'Results/ANCOM/ltable.qza'
  # !qiime taxa collapse \
    --i-table Results/ANCOM/table.qza \
    --i-taxonomy Data/combo_taxonomy.qza \
    --p-level $lev \
    --o-collapsed-table $ltable
  # !qiime composition add-pseudocount \
    --i-table $ltable \
    --o-composition-table $ctable
  # !qiime composition ancom \
    --i-table $ctable \
    --m-metadata-file metadata.tsv \
    --m-metadata-column $column \
    --o-visualization $ancol
  # !rm $ctable $ltable 
  
def filter_table(df):
  df.index.names = ['SampleID']
  df.to_csv('Results/ANCOM/table.tsv',sep='\t')
  # !qiime feature-table filter-samples \
    --i-table Data/Divided_tables/full-table.qza \
    --m-metadata-file Results/ANCOM/table.tsv \
    --o-filtered-table Results/ANCOM/table.qza
  # !rm Results/ANCOM/table.tsv
# Out:
# mkdir: cannot create directory ‘Results/ANCOM’: File exists

# %%
import pandas as pd
from os import path

met = pd.read_csv('metadata.tsv',sep='\t',index_col=0)

cols = ['BS_Trt','BS_Src','BS_Dh']
days = ['d7','d13']
bodysites = ['E','FL','SAM','FR']
for day in days:
  for bs in bodysites:
    if day=='d7' and bs in ['SAM','FR']:
      continue
    dftab = met.loc[(met.Day==day)&(met.BS==bs)].copy()
    filter_table(dftab)
    for col in cols:
      if col=='BS_Dh' and bs!='FR':
        continue
        
      ancom = 'Results/ANCOM/%s_%s_%s_ancom.qzv'%(day,bs,col)
      Ancom(col,ancom)
      for lev in [6,7]:
        ancol = 'Results/ANCOM/%s_%s_%s_ancom_%s.qzv'%(day,bs,col,lev)
        Ancol(lev,col,ancol)
    # !rm Results/ANCOM/table.qza
# Out:
# Saved FeatureTable[Frequency] to: Results/ANCOM/table.qza
# Saved FeatureTable[Composition] to: Results/ANCOM/ctable.qza
# Saved Visualization to: Results/ANCOM/d7_E_BS_Trt_ancom.qzv
# Saved FeatureTable[Frequency] to: Results/ANCOM/ltable.qza
# Saved FeatureTable[Composition] to: Results/ANCOM/ctable.qza
# Saved Visualization to: Results/ANCOM/d7_E_BS_Trt_ancom_6.qzv
# Saved FeatureTable[Frequency] to: Results/ANCOM/ltable.qza
# Saved FeatureTable[Composition] to: Results/ANCOM/ctable.qza
# Saved Visualization to: Results/ANCOM/d7_E_BS_Trt_ancom_7.qzv
# Saved FeatureTable[Composition] to: Results/ANCOM/ctable.qza
# Saved Visualization to: Results/ANCOM/d7_E_BS_Src_ancom.qzv
# Saved FeatureTable[Frequency] to: Results/ANCOM/ltable.qza
# Saved FeatureTable[Composition] to: Results/ANCOM/ctable.qza
# Saved Visualization to: Results/ANCOM/d7_E_BS_Src_ancom_6.qzv
# Saved FeatureTable[Frequency] to: Results/ANCOM/ltable.qza
# Saved FeatureTable[Composition] to: Results/ANCOM/ctable.qza
# Saved Visualization to: Results/ANCOM/d7_E_BS_Src_ancom_7.qzv
# Saved FeatureTable[Frequency] to: Results/ANCOM/table.qza
# Saved FeatureTable[Composition] to: Results/ANCOM/ctable.qza
# Saved Visualization to: Results/ANCOM/d7_FL_BS_Trt_ancom.qzv
# Saved FeatureTable[Frequency] to: Results/ANCOM/ltable.qza
# Saved FeatureTable[Composition] to: Results/ANCOM/ctable.qza
# Saved Visualization to: Results/ANCOM/d7_FL_BS_Trt_ancom_6.qzv
# Saved FeatureTable[Frequency] to: Results/ANCOM/ltable.qza
# Saved FeatureTable[Composition] to: Results/ANCOM/ctable.qza
# Saved Visualization to: Results/ANCOM/d7_FL_BS_Trt_ancom_7.qzv
# Saved FeatureTable[Composition] to: Results/ANCOM/ctable.qza
# Saved Visualization to: Results/ANCOM/d7_FL_BS_Src_ancom.qzv
# Saved FeatureTable[Frequency] to: Results/ANCOM/ltable.qza
# Saved FeatureTable[Composition] to: Results/ANCOM/ctable.qza
# Saved Visualization to: Results/ANCOM/d7_FL_BS_Src_ancom_6.qzv
# Saved FeatureTable[Frequency] to: Results/ANCOM/ltable.qza
# Saved FeatureTable[Composition] to: Results/ANCOM/ctable.qza
# Saved Visualization to: Results/ANCOM/d7_FL_BS_Src_ancom_7.qzv
# Saved FeatureTable[Frequency] to: Results/ANCOM/table.qza
# Saved FeatureTable[Composition] to: Results/ANCOM/ctable.qza
# Saved Visualization to: Results/ANCOM/d13_E_BS_Trt_ancom.qzv
# Saved FeatureTable[Frequency] to: Results/ANCOM/ltable.qza
# Saved FeatureTable[Composition] to: Results/ANCOM/ctable.qza
# Saved Visualization to: Results/ANCOM/d13_E_BS_Trt_ancom_6.qzv
# Saved FeatureTable[Frequency] to: Results/ANCOM/ltable.qza
# Saved FeatureTable[Composition] to: Results/ANCOM/ctable.qza
# Saved Visualization to: Results/ANCOM/d13_E_BS_Trt_ancom_7.qzv
# Saved FeatureTable[Composition] to: Results/ANCOM/ctable.qza
# Saved Visualization to: Results/ANCOM/d13_E_BS_Src_ancom.qzv
# Saved FeatureTable[Frequency] to: Results/ANCOM/ltable.qza
# Saved FeatureTable[Composition] to: Results/ANCOM/ctable.qza
# Saved Visualization to: Results/ANCOM/d13_E_BS_Src_ancom_6.qzv
# Saved FeatureTable[Frequency] to: Results/ANCOM/ltable.qza
# Saved FeatureTable[Composition] to: Results/ANCOM/ctable.qza
# Saved Visualization to: Results/ANCOM/d13_E_BS_Src_ancom_7.qzv
# Saved FeatureTable[Frequency] to: Results/ANCOM/table.qza
# Saved FeatureTable[Composition] to: Results/ANCOM/ctable.qza
# Saved Visualization to: Results/ANCOM/d13_FL_BS_Trt_ancom.qzv
# Saved FeatureTable[Frequency] to: Results/ANCOM/ltable.qza
# Saved FeatureTable[Composition] to: Results/ANCOM/ctable.qza
# Saved Visualization to: Results/ANCOM/d13_FL_BS_Trt_ancom_6.qzv
# Saved FeatureTable[Frequency] to: Results/ANCOM/ltable.qza
# Saved FeatureTable[Composition] to: Results/ANCOM/ctable.qza
# Saved Visualization to: Results/ANCOM/d13_FL_BS_Trt_ancom_7.qzv
# Saved FeatureTable[Composition] to: Results/ANCOM/ctable.qza
# Saved Visualization to: Results/ANCOM/d13_FL_BS_Src_ancom.qzv
# Saved FeatureTable[Frequency] to: Results/ANCOM/ltable.qza
# Saved FeatureTable[Composition] to: Results/ANCOM/ctable.qza
# Saved Visualization to: Results/ANCOM/d13_FL_BS_Src_ancom_6.qzv
# Saved FeatureTable[Frequency] to: Results/ANCOM/ltable.qza
# Saved FeatureTable[Composition] to: Results/ANCOM/ctable.qza
# Saved Visualization to: Results/ANCOM/d13_FL_BS_Src_ancom_7.qzv
# Saved FeatureTable[Frequency] to: Results/ANCOM/table.qza
# Saved FeatureTable[Composition] to: Results/ANCOM/ctable.qza
# Saved Visualization to: Results/ANCOM/d13_SAM_BS_Trt_ancom.qzv
# Saved FeatureTable[Frequency] to: Results/ANCOM/ltable.qza
# Saved FeatureTable[Composition] to: Results/ANCOM/ctable.qza
# Saved Visualization to: Results/ANCOM/d13_SAM_BS_Trt_ancom_6.qzv
# Saved FeatureTable[Frequency] to: Results/ANCOM/ltable.qza
# Saved FeatureTable[Composition] to: Results/ANCOM/ctable.qza
# Saved Visualization to: Results/ANCOM/d13_SAM_BS_Trt_ancom_7.qzv
# Saved FeatureTable[Composition] to: Results/ANCOM/ctable.qza
# Saved Visualization to: Results/ANCOM/d13_SAM_BS_Src_ancom.qzv
# Saved FeatureTable[Frequency] to: Results/ANCOM/ltable.qza
# Saved FeatureTable[Composition] to: Results/ANCOM/ctable.qza
# Saved Visualization to: Results/ANCOM/d13_SAM_BS_Src_ancom_6.qzv
# Saved FeatureTable[Frequency] to: Results/ANCOM/ltable.qza
# Saved FeatureTable[Composition] to: Results/ANCOM/ctable.qza
# Saved Visualization to: Results/ANCOM/d13_SAM_BS_Src_ancom_7.qzv
# Saved FeatureTable[Frequency] to: Results/ANCOM/table.qza
# Saved FeatureTable[Composition] to: Results/ANCOM/ctable.qza
# Saved Visualization to: Results/ANCOM/d13_FR_BS_Trt_ancom.qzv
# Saved FeatureTable[Frequency] to: Results/ANCOM/ltable.qza
# Saved FeatureTable[Composition] to: Results/ANCOM/ctable.qza
# Saved Visualization to: Results/ANCOM/d13_FR_BS_Trt_ancom_6.qzv
# Saved FeatureTable[Frequency] to: Results/ANCOM/ltable.qza
# Saved FeatureTable[Composition] to: Results/ANCOM/ctable.qza
# Saved Visualization to: Results/ANCOM/d13_FR_BS_Trt_ancom_7.qzv
# Saved FeatureTable[Composition] to: Results/ANCOM/ctable.qza
# Saved Visualization to: Results/ANCOM/d13_FR_BS_Src_ancom.qzv
# Saved FeatureTable[Frequency] to: Results/ANCOM/ltable.qza
# Saved FeatureTable[Composition] to: Results/ANCOM/ctable.qza
# Saved Visualization to: Results/ANCOM/d13_FR_BS_Src_ancom_6.qzv
# Saved FeatureTable[Frequency] to: Results/ANCOM/ltable.qza
# Saved FeatureTable[Composition] to: Results/ANCOM/ctable.qza
# Saved Visualization to: Results/ANCOM/d13_FR_BS_Src_ancom_7.qzv
# Saved FeatureTable[Composition] to: Results/ANCOM/ctable.qza
# Saved Visualization to: Results/ANCOM/d13_FR_BS_Dh_ancom.qzv
# Saved FeatureTable[Frequency] to: Results/ANCOM/ltable.qza
# Saved FeatureTable[Composition] to: Results/ANCOM/ctable.qza
# Saved Visualization to: Results/ANCOM/d13_FR_BS_Dh_ancom_6.qzv
# Saved FeatureTable[Frequency] to: Results/ANCOM/ltable.qza
# Saved FeatureTable[Composition] to: Results/ANCOM/ctable.qza
# Saved Visualization to: Results/ANCOM/d13_FR_BS_Dh_ancom_7.qzv

# %% [markdown]
# # Longitudinal analysis

# %% [markdown]
# ### Pairwise-differences and distances

# %%
import pandas as pd

def df_matrix(beta,met):
  matr = beta[beta.index.isin(met.index)].copy()
  matr = matr[met.index]
  matr.sort_index(inplace=True)
  matr = matr.reindex(sorted(matr.columns),axis=1)
  return matr

def first_diff(metric,col,diff):
  # !qiime longitudinal pairwise-differences \
    --m-metadata-file Results/First_differences/alpha.tsv \
    --p-metric $metric \
    --p-group-column $col \
    --p-state-column Day \
    --p-state-1 d7 \
    --p-state-2 d13 \
    --p-individual-id-column IID \
    --p-replicate-handling random \
    --o-visualization $diff
  
def first_dist(dista,col,distv):
  # !qiime longitudinal pairwise-distances \
    --i-distance-matrix $dista \
    --m-metadata-file Results/First_differences/alpha.tsv \
    --p-group-column $col \
    --p-state-column Day \
    --p-state-1 d7 \
    --p-state-2 d13 \
    --p-individual-id-column IID \
    --p-replicate-handling random \
    --o-visualization $distv
  
def distance_matrix(matr,div,col,dista):
  matr.to_csv('Results/First_distances/matrix.tsv',sep='\t')
  matr = 'Results/First_distances/matrix.tsv'
      
  # !qiime tools import \
    --input-path $matr \
    --output-path $dista \
    --type DistanceMatrix
  # !rm $matr

def beta_div(qza):  
  a = !unzip $qza
  digest = a[1].split('/')[0].replace('  inflating: ','')
  inf = digest + '/data/distance-matrix.tsv'
  data = pd.read_csv(inf, sep='\t',index_col=0)
  # !rm -r $digest
  return data

# %%
diversity = {'observed_features':'Observed ASVs',
             'shannon_entropy':'Shannon\'s entropy',
             'faith_pd':'Faith\'s PD',
             'pielou_evenness':'Pielou\'s evenness'}
cols = ['BS_Trt','BS_Src']

df = pd.read_csv('Results/Core-metrics/alpha.tsv',sep='\t',index_col='#SampleID')
alpha = df.loc[(df.Day!='d0')&(df.BS!='SAM')&(df.BS!='FR')].copy()
alpha['IID'] = ''
for group in set(alpha.BS_Day_Trt_Src):
  temp = alpha.loc[alpha.BS_Day_Trt_Src==group].copy()
  for i,index in enumerate(temp.index):
    alpha.loc[index,'IID'] = temp.loc[index,'BS_Trt_Src']+'_'+str(i)
      
# !mkdir Results/First_differences
alpha.to_csv('Results/First_differences/alpha.tsv',sep='\t')
for div in diversity:
  for col in cols:
    diff = 'Results/First_differences/%s_%s_first-diff.qzv'%(div,col)
    first_diff(div,col,diff)
# Out:
# mkdir: cannot create directory ‘Results/First_differences’: File exists
# Saved Visualization to: Results/First_differences/observed_features_BS_Trt_first-diff.qzv
# Saved Visualization to: Results/First_differences/observed_features_BS_Src_first-diff.qzv
# Saved Visualization to: Results/First_differences/shannon_entropy_BS_Trt_first-diff.qzv
# Saved Visualization to: Results/First_differences/shannon_entropy_BS_Src_first-diff.qzv
# Saved Visualization to: Results/First_differences/faith_pd_BS_Trt_first-diff.qzv
# Saved Visualization to: Results/First_differences/faith_pd_BS_Src_first-diff.qzv
# Saved Visualization to: Results/First_differences/pielou_evenness_BS_Trt_first-diff.qzv
# Saved Visualization to: Results/First_differences/pielou_evenness_BS_Src_first-diff.qzv

# %%
diversity = {'unweighted_unifrac':'Unweighted UniFrac',
             'weighted_unifrac':'Weighted UniFrac',
             'jaccard':'Jaccard',
             'bray_curtis':'Bray-Curtis'}
cols = ['BS_Trt','BS_Src']
df = pd.read_csv('Results/Core-metrics/alpha.tsv',sep='\t',index_col='#SampleID')
met = df.loc[(df.Day!='d0')&(df.BS!='SAM')&(df.BS!='FR')].copy()
# !mkdir Results/First_distances
for div in diversity:
  beta = beta_div('Results/Core-metrics/%s_distance_matrix.qza'%div)
  for col in cols:
    distv = 'Results/First_distances/%s_%s_first-dist.qzv'%(div,col)
    dista = 'Results/First_distances/%s_%s_distances.qza'%(div,col)
    matr = df_matrix(beta,met)
    distance_matrix(matr,div,col,dista)
    first_dist(dista,col,distv)
# Out:
# mkdir: cannot create directory ‘Results/First_distances’: File exists
# Imported Results/First_distances/matrix.tsv as DistanceMatrixDirectoryFormat to Results/First_distances/unweighted_unifrac_BS_Trt_distances.qza
# Saved Visualization to: Results/First_distances/unweighted_unifrac_BS_Trt_first-dist.qzv
# Imported Results/First_distances/matrix.tsv as DistanceMatrixDirectoryFormat to Results/First_distances/unweighted_unifrac_BS_Src_distances.qza
# Saved Visualization to: Results/First_distances/unweighted_unifrac_BS_Src_first-dist.qzv
# Imported Results/First_distances/matrix.tsv as DistanceMatrixDirectoryFormat to Results/First_distances/weighted_unifrac_BS_Trt_distances.qza
# Saved Visualization to: Results/First_distances/weighted_unifrac_BS_Trt_first-dist.qzv
# Imported Results/First_distances/matrix.tsv as DistanceMatrixDirectoryFormat to Results/First_distances/weighted_unifrac_BS_Src_distances.qza
# Saved Visualization to: Results/First_distances/weighted_unifrac_BS_Src_first-dist.qzv
# Imported Results/First_distances/matrix.tsv as DistanceMatrixDirectoryFormat to Results/First_distances/jaccard_BS_Trt_distances.qza
# Saved Visualization to: Results/First_distances/jaccard_BS_Trt_first-dist.qzv
# Imported Results/First_distances/matrix.tsv as DistanceMatrixDirectoryFormat to Results/First_distances/jaccard_BS_Src_distances.qza
# Saved Visualization to: Results/First_distances/jaccard_BS_Src_first-dist.qzv
# Imported Results/First_distances/matrix.tsv as DistanceMatrixDirectoryFormat to Results/First_distances/bray_curtis_BS_Trt_distances.qza
# Saved Visualization to: Results/First_distances/bray_curtis_BS_Trt_first-dist.qzv
# Imported Results/First_distances/matrix.tsv as DistanceMatrixDirectoryFormat to Results/First_distances/bray_curtis_BS_Src_distances.qza
# Saved Visualization to: Results/First_distances/bray_curtis_BS_Src_first-dist.qzv
