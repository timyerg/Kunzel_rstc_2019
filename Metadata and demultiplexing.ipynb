# %% [markdown]
# # Create a metadata file

# %%
import pandas as pd

ind = pd.read_csv('RSTC_2019_run_index_barcode - All.tsv', sep='\t') # runs and indexes
bac = pd.read_csv('RSTC_2019_run_index_barcode - Bac.tsv', sep='\t') # bacterial samples
bac.rename(columns={'Sample No.': 'Smpl_no'}, inplace=True)
arc = pd.read_csv('RSTC_2019_run_index_barcode - Arc.tsv', sep='\t') # archaea samples
arc.rename(columns={'Sample No.': 'Smpl_no'}, inplace=True)
met = pd.DataFrame()                                                 # metadata

for ri in set(ind.Run_index): #add bacteria and archeae samples to metadata
  tmp_ind = ind.loc[(ind.Run_index==ri)&(ind.Domain=='bac')].copy()  # bacteria
  tmp = pd.merge(tmp_ind, bac, how='inner', on='Smpl_no')
  met = pd.concat([met, tmp], ignore_index=True)
  tmp_ind = ind.loc[(ind.Run_index==ri)&(ind.Domain=='arc')].copy()  # archaea
  tmp = pd.merge(tmp_ind, arc, how='inner', on='Smpl_no')
  met = pd.concat([met, tmp], ignore_index=True)

met.rename(columns={'Mothur name':'#SampleID'}, inplace=True)        # rename sample id
met.set_index('#SampleID', inplace=True)

# add sequencing run information as separate column
#met = pd.read_csv('metadata.tsv', sep='\t', index_col='#SampleID')
met['SeqRun'] = ''
for ri in set(met.Run_index):
  for index, row in met.loc[met.Run_index==ri].copy().iterrows():
    met.loc[index,'SeqRun'] = 'SeqRun_' + ri[1]
    
met.to_csv('metadata.tsv', sep='\t')                                 # save a metadata file

# %% [markdown]
# # Prepare reads for import

# %%
met = pd.read_csv('metadata.tsv', sep='\t', index_col='#SampleID')
for ri in set(met.Run_index):
  path = 'raw_data/LH_diet_2_%s' % (ri)
  # !rm $path/MD5.txt                          # remove unecessary files
  # !mv $path/*_1.fq.gz $path/forward.fastq.gz # rename forward read for import
  # !mv $path/*_2.fq.gz $path/reverse.fastq.gz # rename reverse read for import

# %% [markdown]
# # Import raw reads

# %%
import pandas as pd
met = pd.read_csv('metadata.tsv', sep='\t', index_col='#SampleID')

from qiime2 import Artifact
# !mkdir -p Data/Imported_reads
for ri in set(met.Run_index):
  path = 'raw_data/LH_diet_2_%s' % ri
  artf = Artifact.import_data('MultiplexedPairedEndBarcodeInSequence', path)
  artf.save('Data/Imported_reads/%s_multiplexed.qza' % ri)

# %% [markdown]
# # Demultiplex

# %%
import pandas as pd
met = pd.read_csv('metadata.tsv', sep='\t', index_col='#SampleID')
# !mkdir -p Data/Demuliplexed
for ri in set(met.Run_index):
  if ri != 'r2_i4': continue
  metadata = met.loc[met.Run_index == ri]              # select by run and index
  metadata.to_csv('metadata_%s.tsv'%ri, sep='\t')      # save a temp metadata file
  temp_met = 'metadata_%s.tsv'%ri                      # path to temp metadata
  path  = 'Data/Imported_reads/%s_multiplexed.qza'%ri  # path to the multiplexed reads
  demux = 'Data/Demuliplexed/%s-demux.qza'%ri          # demulptiplexed reads
  untrm = 'Data/Demuliplexed/%s-untrm.qza'%ri          # untrimmed reads
  
  # !qiime cutadapt demux-paired \
    --i-seqs $path \
    --m-forward-barcodes-file $temp_met \
    --m-forward-barcodes-column BarcodeSequence \
    --o-per-sample-sequences $demux \
    --o-untrimmed-sequences $untrm \
    --p-error-rate 0.1 \
    --p-mixed-orientation
  # !rm $temp_met
# Out:
# Saved SampleData[PairedEndSequencesWithQuality] to: Data/Demuliplexed/r2_i4-demux.qza
# Saved MultiplexedPairedEndBarcodeInSequence to: Data/Demuliplexed/r2_i4-untrm.qza

# %%
import pandas as pd
from Bio import SeqIO
met = pd.read_csv('metadata.tsv', sep='\t', index_col='#SampleID')
# !mkdir -p Data/Demuliplexed
for ri in set(met.Run_index):
  if ri != 'r2_i4': continue
  subdir = 'Data/Demuliplexed/cutadapt_'+ri
  # !mkdir $subdir
  meta = met.loc[met.Run_index == ri].copy()
  f = 'raw_data/LH_diet_2_%s/forward.fastq.gz'%ri
  r = 'raw_data/LH_diet_2_%s/reverse.fastq.gz'%ri
  fasta = 'Data/fasta.fa'
  with open(fasta,'w') as fa:
    for ind in meta.index:
      bc = meta.loc[ind,'BarcodeSequence']
      fa.write('>'+ind+'_'+bc+'\n'+bc+'\n')
  fout = subdir + '/{name}_L001_R1_001.fastq.gz'
  rout = subdir + '/{name}_L001_R2_001.fastq.gz'
  # !cutadapt -e 1 -a file:$fasta -o $fout -p $rout $f $r
  # !rm $fasta
# Out:
# mkdir: cannot create directory ‘Data/Demuliplexed/cutadapt_r2_i4’: File exists
# This is cutadapt 3.2 with Python 3.6.13
# Command line parameters: -e 1 -a file:Data/fasta.fa -o Data/Demuliplexed/cutadapt_r2_i4/{name}_L001_R1_001.fastq.gz -p Data/Demuliplexed/cutadapt_r2_i4/{name}_L001_R2_001.fastq.gz raw_data/LH_diet_2_r2_i4/forward.fastq.gz raw_data/LH_diet_2_r2_i4/reverse.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [8<----------] 00:07:12     1,768,732 reads  @    244.4 µs/read;   0.25 M reads/minute
# Finished in 432.38 s (244 us/read; 0.25 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:          1,768,732
#   Read 1 with adapter:               1,768,729 (100.0%)
#   Read 2 with adapter:                       0 (0.0%)
# Pairs written (passing filters):     1,768,732 (100.0%)
#
# Total basepairs processed:   884,366,000 bp
#   Read 1:   442,183,000 bp
#   Read 2:   442,183,000 bp
# Total written (filtered):    588,767,088 bp (66.6%)
#   Read 1:   146,584,088 bp
#   Read 2:   442,183,000 bp
#
# === First read: Adapter B2069_GCCAGC ===
#
# Sequence: GCCAGC; Type: regular 3'; Length: 6; Trimmed: 679695 times
#
# No. of allowed errors:
# 1-5 bp: 0; 6 bp: 1
#
# Bases preceding removed adapters:
#   A: 0.7%
#   C: 0.1%
#   G: 0.5%
#   T: 94.6%
#   none/other: 4.2%
# WARNING:
#     The adapter is preceded by "T" extremely often.
#     The provided adapter sequence could be incomplete at its 5' end.
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 6	1	431.8	1	1
# 7	10	431.8	1	10
# 8	5	431.8	1	5
# 9	2	431.8	1	2
# 10	3	431.8	1	3
# 11	4	431.8	1	4
# 12	3	431.8	1	3
# 13	5	431.8	1	5
# 14	11	431.8	1	11
# 15	5	431.8	1	5
# 16	34	431.8	1	33 1
# 17	6	431.8	1	6
# 18	2	431.8	1	2
# 19	3	431.8	1	3
# 20	4682	431.8	1	4681 1
# 21	93	431.8	1	93
# 22	4	431.8	1	4
# 23	2	431.8	1	2
# 24	658	431.8	1	658
# 25	22	431.8	1	21 1
# 26	1	431.8	1	1
# 27	6	431.8	1	6
# 28	416	431.8	1	416
# 29	13	431.8	1	13
# 30	2	431.8	1	2
# 31	2	431.8	1	2
# 32	7	431.8	1	7
# 33	6	431.8	1	6
# 34	5	431.8	1	5
# 35	2	431.8	1	2
# 36	5	431.8	1	5
# 37	1	431.8	1	0 1
# 38	3	431.8	1	3
# 40	4	431.8	1	4
# 41	1	431.8	1	1
# 42	5	431.8	1	5
# 43	6	431.8	1	5 1
# 44	4	431.8	1	4
# 45	3	431.8	1	3
# 46	1	431.8	1	1
# 47	3	431.8	1	3
# 49	1	431.8	1	1
# 50	5	431.8	1	5
# 51	116	431.8	1	116
# 52	4	431.8	1	4
# 53	5	431.8	1	5
# 54	1	431.8	1	1
# 55	1	431.8	1	1
# 56	3	431.8	1	3
# 57	1	431.8	1	1
# 58	8	431.8	1	8
# 59	2	431.8	1	2
# 60	6	431.8	1	6
# 61	1	431.8	1	1
# 62	3	431.8	1	3
# 63	4	431.8	1	3 1
# 64	3	431.8	1	3
# 65	6	431.8	1	5 1
# 67	82	431.8	1	81 1
# 68	388	431.8	1	387 1
# 69	49	431.8	1	49
# 70	6	431.8	1	6
# 71	10	431.8	1	10
# 72	54	431.8	1	54
# 73	939	431.8	1	939
# 74	480	431.8	1	479 1
# 75	9879	431.8	1	9879
# 76	90	431.8	1	90
# 77	6605	431.8	1	6605
# 78	1808	431.8	1	1808
# 79	30	431.8	1	30
# 80	842	431.8	1	842
# 81	21	431.8	1	21
# 82	4	431.8	1	4
# 83	1	431.8	1	1
# 84	6	431.8	1	6
# 85	12	431.8	1	12
# 86	26	431.8	1	26
# 87	16	431.8	1	16
# 88	66	431.8	1	66
# 89	24	431.8	1	19 5
# 90	70	431.8	1	70
# 91	202	431.8	1	202
# 92	204	431.8	1	204
# 93	415	431.8	1	415
# 94	23	431.8	1	23
# 95	156	431.8	1	156
# 96	5069	431.8	1	5069
# 97	466	431.8	1	466
# 98	5220	431.8	1	5220
# 99	1404	431.8	1	1404
# 100	25	431.8	1	25
# 101	43	431.8	1	42 1
# 102	43	431.8	1	43
# 103	105	431.8	1	105
# 104	4	431.8	1	4
# 105	21	431.8	1	21
# 106	21686	431.8	1	21686
# 107	255	431.8	1	255
# 108	215	431.8	1	214 1
# 109	7	431.8	1	7
# 110	11	431.8	1	11
# 111	7	431.8	1	7
# 112	21	431.8	1	21
# 113	132	431.8	1	132
# 114	21	431.8	1	21
# 115	11463	431.8	1	11462 1
# 116	360074	431.8	1	360070 4
# 117	4111	431.8	1	4109 2
# 118	289	431.8	1	289
# 119	255	431.8	1	255
# 120	186077	431.8	1	186076 1
# 121	1774	431.8	1	1774
# 122	311	431.8	1	311
# 123	51	431.8	1	51
# 124	37	431.8	1	36 1
# 125	31	431.8	1	30 1
# 126	7	431.8	1	7
# 127	7	431.8	1	6 1
# 128	8	431.8	1	8
# 129	9	431.8	1	9
# 130	255	431.8	1	255
# 131	10	431.8	1	9 1
# 132	5	431.8	1	4 1
# 133	4	431.8	1	4
# 134	12	431.8	1	12
# 135	10	431.8	1	9 1
# 136	8	431.8	1	8
# 137	9	431.8	1	9
# 138	12	431.8	1	12
# 139	1243	431.8	1	1243
# 140	20	431.8	1	20
# 141	7	431.8	1	6 1
# 142	38	431.8	1	38
# 143	4	431.8	1	4
# 145	3	431.8	1	3
# 146	1	431.8	1	1
# 147	5	431.8	1	5
# 148	11	431.8	1	11
# 149	1	431.8	1	1
# 150	2	431.8	1	2
# 151	3	431.8	1	3
# 153	1	431.8	1	1
# 155	4	431.8	1	4
# 156	1	431.8	1	1
# 157	1	431.8	1	1
# 158	3	431.8	1	3
# 159	1	431.8	1	1
# 161	557	431.8	1	557
# 162	5	431.8	1	5
# 163	11	431.8	1	11
# 165	921	431.8	1	921
# 166	16	431.8	1	14 2
# 167	3	431.8	1	2 1
# 168	3	431.8	1	3
# 169	20	431.8	1	20
# 170	1335	431.8	1	1335
# 171	34	431.8	1	34
# 172	10	431.8	1	10
# 173	1	431.8	1	1
# 174	5	431.8	1	5
# 175	6	431.8	1	5 1
# 176	2	431.8	1	2
# 177	2	431.8	1	2
# 178	3	431.8	1	3
# 179	3	431.8	1	3
# 180	36	431.8	1	36
# 181	5	431.8	1	5
# 182	54	431.8	1	54
# 183	21	431.8	1	21
# 184	1	431.8	1	1
# 185	32	431.8	1	31 1
# 186	2	431.8	1	2
# 187	4	431.8	1	4
# 188	1	431.8	1	1
# 189	15	431.8	1	15
# 190	7	431.8	1	7
# 191	3	431.8	1	2 1
# 193	41	431.8	1	40 1
# 194	33	431.8	1	32 1
# 195	1	431.8	1	1
# 196	3	431.8	1	3
# 197	22	431.8	1	22
# 198	3	431.8	1	3
# 199	1	431.8	1	1
# 200	5	431.8	1	5
# 201	1	431.8	1	1
# 202	120	431.8	1	120
# 203	2	431.8	1	2
# 204	3	431.8	1	2 1
# 205	4	431.8	1	3 1
# 206	34	431.8	1	34
# 208	154	431.8	1	154
# 209	6	431.8	1	6
# 210	1	431.8	1	1
# 211	2	431.8	1	2
# 212	3	431.8	1	3
# 213	1	431.8	1	1
# 214	60	431.8	1	59 1
# 215	14	431.8	1	13 1
# 216	7	431.8	1	7
# 217	2	431.8	1	2
# 218	2	431.8	1	2
# 219	6	431.8	1	6
# 220	5	431.8	1	5
# 221	1	431.8	1	1
# 222	2	431.8	1	2
# 224	11	431.8	1	11
# 225	29	431.8	1	24 5
# 226	6	431.8	1	6
# 227	3	431.8	1	3
# 228	1	431.8	1	1
# 229	1	431.8	1	1
# 235	1	431.8	1	1
# 238	2	431.8	1	1 1
# 239	1	431.8	1	1
# 240	225	431.8	1	224 1
# 241	11	431.8	1	11
# 242	822	431.8	1	815 7
# 243	18	431.8	1	18
# 244	14	431.8	1	14
# 245	9	431.8	1	9
# 246	16702	431.8	1	16700 2
# 247	92	431.8	1	68 24
# 248	22	431.8	1	8 14
# 249	44	431.8	1	41 3
# 250	28362	431.8	1	28361 1
#
#
# === First read: Adapter B2070_GCGACT ===
#
# Sequence: GCGACT; Type: regular 3'; Length: 6; Trimmed: 49986 times
#
# No. of allowed errors:
# 1-5 bp: 0; 6 bp: 1
#
# Bases preceding removed adapters:
#   A: 1.0%
#   C: 10.5%
#   G: 27.2%
#   T: 1.1%
#   none/other: 60.3%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 6	12	431.8	1	12
# 7	147	431.8	1	147
# 8	27	431.8	1	27
# 9	148	431.8	1	148
# 10	20	431.8	1	20
# 11	9	431.8	1	9
# 12	510	431.8	1	509 1
# 13	602	431.8	1	602
# 14	14	431.8	1	13 1
# 15	9	431.8	1	9
# 16	8	431.8	1	8
# 17	71	431.8	1	71
# 18	2	431.8	1	2
# 19	6	431.8	1	6
# 20	6	431.8	1	6
# 21	21	431.8	1	21
# 22	2	431.8	1	2
# 23	9	431.8	1	9
# 24	4	431.8	1	1 3
# 26	97	431.8	1	97
# 27	8411	431.8	1	8409 2
# 28	3774	431.8	1	3771 3
# 29	39	431.8	1	39
# 30	9	431.8	1	9
# 31	2	431.8	1	2
# 32	3	431.8	1	3
# 33	25	431.8	1	25
# 34	206	431.8	1	206
# 35	7	431.8	1	7
# 36	1	431.8	1	1
# 37	2	431.8	1	2
# 38	3	431.8	1	3
# 39	2	431.8	1	2
# 40	3	431.8	1	2 1
# 41	3	431.8	1	1 2
# 42	2	431.8	1	2
# 43	1	431.8	1	1
# 45	4	431.8	1	4
# 46	1	431.8	1	1
# 48	7	431.8	1	7
# 49	1	431.8	1	1
# 50	1	431.8	1	1
# 51	2	431.8	1	2
# 52	1	431.8	1	1
# 55	1	431.8	1	1
# 56	5	431.8	1	5
# 57	4	431.8	1	4
# 58	2	431.8	1	1 1
# 59	1	431.8	1	1
# 60	8	431.8	1	6 2
# 61	1	431.8	1	1
# 62	2	431.8	1	1 1
# 63	2	431.8	1	2
# 64	2	431.8	1	2
# 65	2	431.8	1	2
# 66	2	431.8	1	1 1
# 67	3	431.8	1	3
# 68	1	431.8	1	1
# 69	5	431.8	1	5
# 70	2	431.8	1	2
# 71	1	431.8	1	1
# 72	3	431.8	1	0 3
# 73	5	431.8	1	5
# 75	6	431.8	1	6
# 76	3830	431.8	1	3830
# 77	38	431.8	1	38
# 78	5	431.8	1	5
# 79	1	431.8	1	1
# 80	4	431.8	1	4
# 81	4	431.8	1	3 1
# 82	2	431.8	1	2
# 83	2	431.8	1	2
# 84	1	431.8	1	1
# 85	8	431.8	1	8
# 86	12	431.8	1	12
# 87	4	431.8	1	4
# 88	8	431.8	1	8
# 89	2	431.8	1	2
# 90	3	431.8	1	3
# 91	4	431.8	1	4
# 92	1	431.8	1	0 1
# 93	1	431.8	1	1
# 94	2	431.8	1	2
# 95	4	431.8	1	4
# 96	8	431.8	1	8
# 98	5	431.8	1	5
# 99	20	431.8	1	19 1
# 100	2	431.8	1	2
# 101	1	431.8	1	1
# 102	1	431.8	1	1
# 103	1	431.8	1	1
# 104	269	431.8	1	269
# 105	6	431.8	1	6
# 106	9	431.8	1	9
# 107	1	431.8	1	1
# 108	2	431.8	1	2
# 109	2	431.8	1	2
# 110	2	431.8	1	1 1
# 111	71	431.8	1	63 8
# 112	160	431.8	1	158 2
# 113	10	431.8	1	7 3
# 114	2	431.8	1	1 1
# 115	1	431.8	1	0 1
# 119	1	431.8	1	1
# 120	7	431.8	1	2 5
# 121	6	431.8	1	1 5
# 122	1	431.8	1	0 1
# 123	5	431.8	1	5
# 124	4	431.8	1	3 1
# 125	3	431.8	1	3
# 126	3	431.8	1	3
# 128	4	431.8	1	3 1
# 129	2	431.8	1	2
# 130	3	431.8	1	3
# 131	18	431.8	1	18
# 134	19	431.8	1	17 2
# 135	2	431.8	1	2
# 136	2	431.8	1	1 1
# 137	98	431.8	1	97 1
# 138	16	431.8	1	14 2
# 140	6	431.8	1	6
# 141	8	431.8	1	8
# 142	11	431.8	1	11
# 143	4	431.8	1	4
# 144	4	431.8	1	4
# 145	2	431.8	1	2
# 147	1	431.8	1	1
# 149	1	431.8	1	1
# 150	5	431.8	1	5
# 151	3	431.8	1	3
# 152	1	431.8	1	1
# 154	3	431.8	1	3
# 155	3	431.8	1	3
# 156	7	431.8	1	7
# 157	25	431.8	1	25
# 158	1	431.8	1	1
# 159	2	431.8	1	2
# 160	1	431.8	1	1
# 163	3	431.8	1	3
# 164	13	431.8	1	13
# 165	3	431.8	1	3
# 166	2	431.8	1	2
# 167	12	431.8	1	12
# 169	2	431.8	1	2
# 170	3	431.8	1	3
# 171	1	431.8	1	1
# 172	2	431.8	1	1 1
# 173	8	431.8	1	7 1
# 174	2	431.8	1	2
# 175	20	431.8	1	20
# 176	1	431.8	1	1
# 177	1	431.8	1	0 1
# 178	1	431.8	1	1
# 179	9	431.8	1	9
# 183	11	431.8	1	10 1
# 184	1	431.8	1	1
# 185	1	431.8	1	1
# 186	1	431.8	1	0 1
# 189	1	431.8	1	1
# 191	1	431.8	1	1
# 192	2	431.8	1	2
# 194	2	431.8	1	2
# 195	1	431.8	1	1
# 196	3	431.8	1	0 3
# 197	3	431.8	1	3
# 198	1	431.8	1	1
# 200	1	431.8	1	1
# 201	1	431.8	1	1
# 202	2	431.8	1	2
# 203	2	431.8	1	2
# 204	1	431.8	1	1
# 205	24	431.8	1	24
# 206	7	431.8	1	7
# 210	11	431.8	1	11
# 213	1	431.8	1	1
# 216	1	431.8	1	1
# 222	36	431.8	1	34 2
# 223	1	431.8	1	1
# 225	248	431.8	1	248
# 226	1	431.8	1	1
# 231	297	431.8	1	283 14
# 232	6	431.8	1	3 3
# 233	2	431.8	1	2
# 235	1	431.8	1	1
# 236	1	431.8	1	0 1
# 245	2	431.8	1	1 1
# 247	3	431.8	1	0 3
# 249	8	431.8	1	8
# 250	30135	431.8	1	30135
#
#
# === First read: Adapter B2071_GCTCAT ===
#
# Sequence: GCTCAT; Type: regular 3'; Length: 6; Trimmed: 40201 times
#
# No. of allowed errors:
# 1-5 bp: 0; 6 bp: 1
#
# Bases preceding removed adapters:
#   A: 1.7%
#   C: 25.5%
#   G: 1.7%
#   T: 0.9%
#   none/other: 70.1%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 6	25	431.8	1	25
# 7	3	431.8	1	3
# 8	2	431.8	1	2
# 9	2	431.8	1	2
# 10	3	431.8	1	3
# 11	85	431.8	1	85
# 12	15	431.8	1	15
# 13	7	431.8	1	7
# 14	2	431.8	1	2
# 15	3	431.8	1	3
# 16	58	431.8	1	58
# 17	64	431.8	1	64
# 18	6	431.8	1	6
# 19	47	431.8	1	46 1
# 20	5	431.8	1	5
# 21	3	431.8	1	3
# 22	19	431.8	1	18 1
# 23	2	431.8	1	0 2
# 24	31	431.8	1	30 1
# 25	1	431.8	1	1
# 26	3	431.8	1	2 1
# 27	3	431.8	1	3
# 28	12	431.8	1	12
# 29	4	431.8	1	4
# 30	2	431.8	1	2
# 31	3	431.8	1	3
# 32	3	431.8	1	3
# 33	3	431.8	1	3
# 34	5	431.8	1	5
# 35	4	431.8	1	4
# 36	34	431.8	1	34
# 37	4	431.8	1	4
# 38	2	431.8	1	1 1
# 39	6	431.8	1	6
# 40	2	431.8	1	2
# 41	10	431.8	1	9 1
# 44	3	431.8	1	3
# 45	72	431.8	1	72
# 46	3	431.8	1	3
# 47	6	431.8	1	6
# 48	1	431.8	1	1
# 50	2	431.8	1	2
# 52	7	431.8	1	7
# 53	10	431.8	1	9 1
# 54	6	431.8	1	6
# 55	4	431.8	1	4
# 56	42	431.8	1	42
# 57	6	431.8	1	5 1
# 58	24	431.8	1	24
# 59	1	431.8	1	1
# 60	5	431.8	1	5
# 61	4	431.8	1	4
# 62	1	431.8	1	1
# 63	38	431.8	1	37 1
# 64	14	431.8	1	14
# 65	19	431.8	1	19
# 67	4	431.8	1	4
# 68	1	431.8	1	1
# 69	116	431.8	1	116
# 70	65	431.8	1	65
# 71	13	431.8	1	13
# 72	3	431.8	1	3
# 73	2	431.8	1	2
# 75	1	431.8	1	1
# 76	1	431.8	1	1
# 78	3	431.8	1	3
# 79	5	431.8	1	5
# 80	5	431.8	1	4 1
# 81	6	431.8	1	5 1
# 82	9	431.8	1	9
# 83	16	431.8	1	16
# 84	7	431.8	1	7
# 85	2	431.8	1	2
# 86	5	431.8	1	5
# 87	7	431.8	1	6 1
# 88	12	431.8	1	12
# 89	8	431.8	1	8
# 90	1	431.8	1	1
# 91	2	431.8	1	2
# 92	3	431.8	1	3
# 95	3	431.8	1	3
# 96	2	431.8	1	1 1
# 97	8	431.8	1	8
# 98	6	431.8	1	6
# 99	3	431.8	1	3
# 100	3	431.8	1	3
# 101	14	431.8	1	14
# 102	2	431.8	1	1 1
# 103	2	431.8	1	2
# 104	4	431.8	1	4
# 105	1	431.8	1	1
# 106	3	431.8	1	3
# 107	4	431.8	1	2 2
# 108	2	431.8	1	2
# 109	2	431.8	1	2
# 110	6	431.8	1	6
# 112	6	431.8	1	6
# 113	11	431.8	1	11
# 114	9691	431.8	1	9691
# 115	90	431.8	1	90
# 116	9	431.8	1	9
# 117	5	431.8	1	5
# 118	4	431.8	1	4
# 119	4	431.8	1	4
# 120	2	431.8	1	2
# 121	3	431.8	1	3
# 122	25	431.8	1	25
# 123	1	431.8	1	1
# 124	4	431.8	1	4
# 126	2	431.8	1	2
# 127	5	431.8	1	5
# 128	13	431.8	1	3 10
# 129	118	431.8	1	115 3
# 130	16	431.8	1	16
# 131	2	431.8	1	1 1
# 132	2	431.8	1	2
# 134	3	431.8	1	2 1
# 136	8	431.8	1	8
# 137	4	431.8	1	1 3
# 138	1	431.8	1	1
# 139	2	431.8	1	2
# 141	96	431.8	1	95 1
# 142	3	431.8	1	3
# 143	4	431.8	1	4
# 144	2	431.8	1	2
# 145	2	431.8	1	2
# 146	2	431.8	1	1 1
# 148	5	431.8	1	5
# 149	2	431.8	1	2
# 150	1	431.8	1	0 1
# 152	2	431.8	1	2
# 154	1	431.8	1	1
# 157	2	431.8	1	2
# 158	1	431.8	1	1
# 159	4	431.8	1	4
# 160	1	431.8	1	1
# 163	14	431.8	1	14
# 164	1	431.8	1	1
# 165	1	431.8	1	1
# 166	1	431.8	1	1
# 167	7	431.8	1	7
# 169	3	431.8	1	3
# 170	8	431.8	1	8
# 171	8	431.8	1	7 1
# 172	2	431.8	1	2
# 173	8	431.8	1	8
# 174	1	431.8	1	1
# 176	2	431.8	1	2
# 177	175	431.8	1	175
# 178	6	431.8	1	6
# 179	9	431.8	1	9
# 181	11	431.8	1	11
# 182	2	431.8	1	2
# 183	10	431.8	1	10
# 185	1	431.8	1	1
# 187	1	431.8	1	1
# 189	4	431.8	1	4
# 190	1	431.8	1	0 1
# 193	1	431.8	1	1
# 194	2	431.8	1	2
# 198	3	431.8	1	2 1
# 200	1	431.8	1	1
# 201	216	431.8	1	216
# 202	9	431.8	1	8 1
# 203	2	431.8	1	2
# 205	9	431.8	1	9
# 206	1	431.8	1	1
# 208	2	431.8	1	2
# 209	1	431.8	1	1
# 210	1	431.8	1	0 1
# 212	1	431.8	1	1
# 213	2	431.8	1	2
# 214	1	431.8	1	1
# 215	1	431.8	1	1
# 216	12	431.8	1	12
# 217	3	431.8	1	3
# 218	1	431.8	1	1
# 221	5	431.8	1	2 3
# 222	4	431.8	1	0 4
# 223	1	431.8	1	0 1
# 224	2	431.8	1	2
# 226	2	431.8	1	2
# 228	140	431.8	1	139 1
# 229	1	431.8	1	1
# 230	2	431.8	1	2
# 233	2	431.8	1	2
# 235	2	431.8	1	1 1
# 240	4	431.8	1	1 3
# 242	7	431.8	1	7
# 247	8	431.8	1	2 6
# 248	1	431.8	1	0 1
# 249	7	431.8	1	7
# 250	28196	431.8	1	28196
#
#
# === First read: Adapter B2072_GGCCAA ===
#
# Sequence: GGCCAA; Type: regular 3'; Length: 6; Trimmed: 31873 times
#
# No. of allowed errors:
# 1-5 bp: 0; 6 bp: 1
#
# Bases preceding removed adapters:
#   A: 3.4%
#   C: 3.2%
#   G: 2.8%
#   T: 1.3%
#   none/other: 89.4%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 8	12	431.8	1	11 1
# 10	1	431.8	1	1
# 13	1	431.8	1	1
# 14	1	431.8	1	1
# 15	3	431.8	1	3
# 16	72	431.8	1	72
# 17	155	431.8	1	152 3
# 18	11	431.8	1	11
# 19	3	431.8	1	3
# 20	1	431.8	1	1
# 21	9	431.8	1	8 1
# 22	3	431.8	1	3
# 23	1	431.8	1	1
# 24	2	431.8	1	2
# 25	47	431.8	1	47
# 26	10	431.8	1	10
# 27	2	431.8	1	2
# 28	1	431.8	1	1
# 29	6	431.8	1	6
# 30	7	431.8	1	7
# 31	2	431.8	1	2
# 32	325	431.8	1	325
# 33	10	431.8	1	10
# 34	50	431.8	1	50
# 35	15	431.8	1	15
# 36	5	431.8	1	5
# 38	27	431.8	1	27
# 39	7	431.8	1	7
# 40	4	431.8	1	4
# 41	1	431.8	1	1
# 42	1	431.8	1	1
# 43	1	431.8	1	1
# 44	1	431.8	1	1
# 45	1	431.8	1	1
# 48	1	431.8	1	1
# 49	349	431.8	1	349
# 50	10	431.8	1	10
# 51	7	431.8	1	7
# 52	22	431.8	1	22
# 53	4	431.8	1	4
# 54	2	431.8	1	2
# 55	3	431.8	1	3
# 56	1	431.8	1	1
# 57	1	431.8	1	1
# 61	8	431.8	1	8
# 62	3	431.8	1	3
# 63	2	431.8	1	2
# 64	3	431.8	1	3
# 66	79	431.8	1	71 8
# 67	8	431.8	1	8
# 68	1	431.8	1	1
# 69	1	431.8	1	1
# 70	3	431.8	1	3
# 71	3	431.8	1	3
# 72	5	431.8	1	5
# 73	1	431.8	1	1
# 74	1	431.8	1	1
# 75	2	431.8	1	2
# 77	1	431.8	1	1
# 78	1	431.8	1	1
# 79	4	431.8	1	3 1
# 81	4	431.8	1	4
# 82	1	431.8	1	1
# 83	1	431.8	1	1
# 84	1	431.8	1	0 1
# 85	3	431.8	1	3
# 86	3	431.8	1	3
# 87	2	431.8	1	2
# 88	1	431.8	1	1
# 90	25	431.8	1	25
# 91	3	431.8	1	3
# 92	6	431.8	1	6
# 93	7	431.8	1	7
# 94	1	431.8	1	1
# 95	3	431.8	1	3
# 100	9	431.8	1	9
# 101	5	431.8	1	5
# 102	1	431.8	1	1
# 103	2	431.8	1	2
# 104	8	431.8	1	8
# 105	5	431.8	1	5
# 106	1	431.8	1	1
# 107	4	431.8	1	4
# 108	2	431.8	1	2
# 109	4	431.8	1	4
# 110	1	431.8	1	1
# 112	1	431.8	1	1
# 113	2	431.8	1	2
# 114	2	431.8	1	2
# 115	2	431.8	1	2
# 118	1	431.8	1	0 1
# 119	1	431.8	1	1
# 121	1	431.8	1	1
# 122	3	431.8	1	3
# 123	1	431.8	1	1
# 125	4	431.8	1	4
# 128	10	431.8	1	10
# 129	29	431.8	1	28 1
# 130	1	431.8	1	1
# 133	28	431.8	1	27 1
# 134	1	431.8	1	1
# 135	7	431.8	1	7
# 136	3	431.8	1	3
# 137	2	431.8	1	2
# 138	15	431.8	1	12 3
# 139	2	431.8	1	1 1
# 140	1	431.8	1	1
# 141	10	431.8	1	1 9
# 142	116	431.8	1	13 103
# 143	21	431.8	1	3 18
# 144	4	431.8	1	3 1
# 145	1	431.8	1	0 1
# 146	1	431.8	1	1
# 148	11	431.8	1	8 3
# 149	1	431.8	1	1
# 152	1	431.8	1	1
# 153	1	431.8	1	0 1
# 155	1	431.8	1	1
# 157	35	431.8	1	35
# 158	86	431.8	1	86
# 159	220	431.8	1	220
# 160	5	431.8	1	5
# 161	1	431.8	1	1
# 163	6	431.8	1	6
# 164	1	431.8	1	1
# 165	1	431.8	1	1
# 166	4	431.8	1	4
# 167	375	431.8	1	375
# 168	8	431.8	1	7 1
# 169	5	431.8	1	4 1
# 170	1	431.8	1	1
# 171	203	431.8	1	203
# 172	1	431.8	1	1
# 173	3	431.8	1	3
# 174	3	431.8	1	2 1
# 176	87	431.8	1	87
# 177	9	431.8	1	9
# 178	1	431.8	1	1
# 179	3	431.8	1	3
# 180	2	431.8	1	2
# 183	1	431.8	1	1
# 184	2	431.8	1	2
# 186	1	431.8	1	0 1
# 187	3	431.8	1	3
# 189	1	431.8	1	1
# 190	1	431.8	1	1
# 191	4	431.8	1	4
# 192	2	431.8	1	1 1
# 193	6	431.8	1	5 1
# 197	1	431.8	1	1
# 198	2	431.8	1	2
# 200	3	431.8	1	3
# 202	1	431.8	1	1
# 203	2	431.8	1	2
# 204	1	431.8	1	0 1
# 205	14	431.8	1	14
# 206	1	431.8	1	1
# 208	2	431.8	1	1 1
# 209	1	431.8	1	0 1
# 210	1	431.8	1	1
# 213	1	431.8	1	1
# 214	63	431.8	1	62 1
# 215	4	431.8	1	2 2
# 216	2	431.8	1	2
# 217	2	431.8	1	2
# 218	276	431.8	1	276
# 219	3	431.8	1	3
# 222	2	431.8	1	2
# 223	8	431.8	1	8
# 226	2	431.8	1	2
# 228	1	431.8	1	1
# 234	1	431.8	1	0 1
# 246	5	431.8	1	5
# 247	162	431.8	1	162
# 248	23	431.8	1	23
# 249	1	431.8	1	1
# 250	28495	431.8	1	28495
#
#
# === First read: Adapter B2073_GGCTTC ===
#
# Sequence: GGCTTC; Type: regular 3'; Length: 6; Trimmed: 67749 times
#
# No. of allowed errors:
# 1-5 bp: 0; 6 bp: 1
#
# Bases preceding removed adapters:
#   A: 6.5%
#   C: 48.2%
#   G: 7.1%
#   T: 2.4%
#   none/other: 35.7%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 6	2	431.8	1	2
# 7	2	431.8	1	2
# 8	45	431.8	1	45
# 9	13	431.8	1	13
# 10	6196	431.8	1	6196
# 11	153	431.8	1	153
# 12	75	431.8	1	75
# 13	17	431.8	1	17
# 14	9	431.8	1	8 1
# 15	6	431.8	1	6
# 16	185	431.8	1	185
# 17	6	431.8	1	6
# 18	2	431.8	1	2
# 19	9	431.8	1	9
# 21	32	431.8	1	32
# 22	2	431.8	1	2
# 23	12	431.8	1	12
# 24	3405	431.8	1	3393 12
# 25	448	431.8	1	171 277
# 26	144	431.8	1	90 54
# 27	21	431.8	1	12 9
# 28	22	431.8	1	19 3
# 29	7	431.8	1	1 6
# 30	5	431.8	1	3 2
# 31	8	431.8	1	6 2
# 32	256	431.8	1	256
# 33	26	431.8	1	26
# 34	20	431.8	1	19 1
# 35	10	431.8	1	10
# 36	3	431.8	1	3
# 37	11	431.8	1	11
# 38	3	431.8	1	3
# 39	1	431.8	1	1
# 40	89	431.8	1	89
# 41	28	431.8	1	28
# 42	3	431.8	1	3
# 43	3	431.8	1	3
# 44	9	431.8	1	9
# 45	1	431.8	1	1
# 46	6	431.8	1	5 1
# 47	7	431.8	1	7
# 48	2	431.8	1	2
# 50	21	431.8	1	4 17
# 51	145	431.8	1	143 2
# 52	6	431.8	1	6
# 53	6	431.8	1	6
# 54	2	431.8	1	2
# 55	175	431.8	1	175
# 56	5	431.8	1	3 2
# 57	4	431.8	1	4
# 58	4	431.8	1	4
# 59	2	431.8	1	2
# 60	7	431.8	1	7
# 61	12	431.8	1	12
# 62	6	431.8	1	6
# 63	3	431.8	1	3
# 64	3	431.8	1	3
# 65	4	431.8	1	4
# 66	84	431.8	1	84
# 67	11	431.8	1	10 1
# 68	14	431.8	1	14
# 69	2	431.8	1	2
# 70	12	431.8	1	11 1
# 71	1	431.8	1	1
# 73	3	431.8	1	3
# 75	2	431.8	1	2
# 76	8	431.8	1	8
# 77	2	431.8	1	2
# 79	17	431.8	1	17
# 80	9	431.8	1	8 1
# 81	3	431.8	1	3
# 82	1	431.8	1	1
# 84	12	431.8	1	12
# 85	8	431.8	1	7 1
# 86	30	431.8	1	30
# 87	1	431.8	1	1
# 88	5	431.8	1	5
# 89	13	431.8	1	11 2
# 90	3	431.8	1	3
# 91	5	431.8	1	5
# 92	2	431.8	1	2
# 93	3	431.8	1	3
# 94	2	431.8	1	2
# 96	15	431.8	1	15
# 97	3605	431.8	1	3605
# 98	94	431.8	1	94
# 99	7	431.8	1	7
# 100	5	431.8	1	5
# 101	1	431.8	1	1
# 102	2	431.8	1	2
# 103	5	431.8	1	5
# 104	16	431.8	1	14 2
# 105	2	431.8	1	1 1
# 106	2	431.8	1	2
# 107	1	431.8	1	1
# 108	3	431.8	1	1 2
# 109	29	431.8	1	28 1
# 110	11	431.8	1	11
# 111	2	431.8	1	2
# 112	595	431.8	1	595
# 113	261	431.8	1	261
# 114	4	431.8	1	4
# 115	1	431.8	1	1
# 116	2	431.8	1	2
# 118	1	431.8	1	1
# 119	1	431.8	1	1
# 121	3	431.8	1	3
# 122	3	431.8	1	3
# 123	12	431.8	1	12
# 124	3090	431.8	1	3090
# 125	31	431.8	1	31
# 126	15	431.8	1	15
# 127	4	431.8	1	4
# 128	59	431.8	1	59
# 129	14	431.8	1	5 9
# 130	6	431.8	1	6
# 131	4	431.8	1	4
# 132	10	431.8	1	9 1
# 133	5	431.8	1	5
# 134	65	431.8	1	65
# 135	19803	431.8	1	19803
# 136	846	431.8	1	846
# 137	76	431.8	1	76
# 138	40	431.8	1	40
# 139	11	431.8	1	10 1
# 140	6	431.8	1	6
# 141	2	431.8	1	2
# 142	51	431.8	1	49 2
# 143	22	431.8	1	22
# 144	2	431.8	1	1 1
# 145	1	431.8	1	1
# 146	2	431.8	1	2
# 147	3	431.8	1	3
# 148	1	431.8	1	1
# 150	467	431.8	1	467
# 151	24	431.8	1	24
# 152	4	431.8	1	4
# 153	4	431.8	1	4
# 154	5	431.8	1	5
# 155	3	431.8	1	3
# 156	4	431.8	1	4
# 157	40	431.8	1	40
# 159	6	431.8	1	6
# 160	3	431.8	1	3
# 161	8	431.8	1	8
# 162	4	431.8	1	4
# 163	170	431.8	1	170
# 164	141	431.8	1	141
# 165	316	431.8	1	316
# 166	14	431.8	1	14
# 167	2	431.8	1	2
# 168	6	431.8	1	6
# 169	2	431.8	1	0 2
# 170	11	431.8	1	11
# 171	139	431.8	1	136 3
# 172	21	431.8	1	14 7
# 173	96	431.8	1	94 2
# 174	579	431.8	1	579
# 175	15	431.8	1	15
# 176	11	431.8	1	11
# 177	2	431.8	1	2
# 178	2	431.8	1	2
# 179	1	431.8	1	1
# 180	7	431.8	1	7
# 181	1	431.8	1	1
# 182	2	431.8	1	2
# 183	46	431.8	1	46
# 184	14	431.8	1	14
# 186	7	431.8	1	7
# 188	1	431.8	1	1
# 189	1	431.8	1	1
# 190	3	431.8	1	3
# 191	5	431.8	1	5
# 192	6	431.8	1	6
# 199	1	431.8	1	1
# 200	1	431.8	1	1
# 201	10	431.8	1	10
# 202	3	431.8	1	3
# 203	3	431.8	1	3
# 204	1	431.8	1	1
# 205	3	431.8	1	3
# 206	1	431.8	1	1
# 209	10	431.8	1	2 8
# 210	4	431.8	1	4
# 211	1	431.8	1	1
# 212	2	431.8	1	2
# 213	2	431.8	1	2
# 214	36	431.8	1	36
# 215	2	431.8	1	0 2
# 217	1	431.8	1	1
# 218	4	431.8	1	4
# 219	1	431.8	1	1
# 220	8	431.8	1	8
# 221	1	431.8	1	1
# 222	4	431.8	1	1 3
# 223	278	431.8	1	94 184
# 224	128	431.8	1	91 37
# 225	8	431.8	1	1 7
# 226	6	431.8	1	2 4
# 227	3	431.8	1	0 3
# 228	2	431.8	1	1 1
# 229	6	431.8	1	4 2
# 236	1	431.8	1	1
# 241	2	431.8	1	2
# 249	2	431.8	1	2
# 250	24207	431.8	1	24203 4
#
#
# === First read: Adapter B2074_GGTACC ===
#
# Sequence: GGTACC; Type: regular 3'; Length: 6; Trimmed: 31227 times
#
# No. of allowed errors:
# 1-5 bp: 0; 6 bp: 1
#
# Bases preceding removed adapters:
#   A: 15.3%
#   C: 5.8%
#   G: 1.0%
#   T: 0.3%
#   none/other: 77.5%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 7	2	431.8	1	2
# 8	1	431.8	1	1
# 9	58	431.8	1	58
# 10	2	431.8	1	2
# 11	1	431.8	1	1
# 12	1	431.8	1	1
# 13	15	431.8	1	15
# 14	4	431.8	1	4
# 15	2	431.8	1	2
# 18	1	431.8	1	1
# 19	2	431.8	1	1 1
# 21	2	431.8	1	2
# 22	1	431.8	1	1
# 23	4	431.8	1	4
# 24	9	431.8	1	9
# 25	1	431.8	1	1
# 27	1	431.8	1	1
# 28	1	431.8	1	1
# 29	2	431.8	1	2
# 32	5	431.8	1	5
# 34	11	431.8	1	11
# 37	9	431.8	1	9
# 38	1	431.8	1	1
# 39	2	431.8	1	2
# 40	4	431.8	1	4
# 43	3	431.8	1	3
# 44	12	431.8	1	11 1
# 45	3	431.8	1	3
# 46	10	431.8	1	10
# 47	16	431.8	1	16
# 48	1313	431.8	1	1313
# 49	50	431.8	1	50
# 50	6	431.8	1	6
# 52	4	431.8	1	4
# 53	3	431.8	1	3
# 57	1	431.8	1	1
# 58	6	431.8	1	6
# 60	88	431.8	1	88
# 61	3	431.8	1	3
# 62	1	431.8	1	1
# 67	1	431.8	1	1
# 69	1	431.8	1	1
# 70	1	431.8	1	1
# 71	1	431.8	1	1
# 74	2	431.8	1	2
# 75	1	431.8	1	1
# 76	1	431.8	1	1
# 77	1	431.8	1	1
# 78	7	431.8	1	7
# 79	1	431.8	1	1
# 82	1	431.8	1	1
# 83	22	431.8	1	22
# 85	4	431.8	1	3 1
# 87	3	431.8	1	1 2
# 89	1	431.8	1	0 1
# 90	27	431.8	1	27
# 91	1	431.8	1	1
# 93	1	431.8	1	1
# 94	1	431.8	1	1
# 95	4	431.8	1	4
# 96	2	431.8	1	1 1
# 98	8	431.8	1	8
# 99	1	431.8	1	1
# 100	2	431.8	1	2
# 101	7	431.8	1	7
# 102	2	431.8	1	2
# 103	1	431.8	1	1
# 104	28	431.8	1	28
# 105	2	431.8	1	2
# 106	4	431.8	1	4
# 107	2	431.8	1	2
# 109	1	431.8	1	1
# 110	4	431.8	1	3 1
# 111	1	431.8	1	1
# 112	4	431.8	1	4
# 113	4	431.8	1	4
# 114	1	431.8	1	0 1
# 117	1	431.8	1	0 1
# 118	2	431.8	1	2
# 119	67	431.8	1	66 1
# 120	6	431.8	1	6
# 121	5	431.8	1	5
# 123	27	431.8	1	26 1
# 124	1	431.8	1	1
# 125	19	431.8	1	18 1
# 126	45	431.8	1	45
# 127	9	431.8	1	9
# 129	53	431.8	1	53
# 130	4	431.8	1	4
# 131	28	431.8	1	28
# 132	8	431.8	1	8
# 133	3	431.8	1	2 1
# 136	1	431.8	1	1
# 139	1	431.8	1	1
# 140	3	431.8	1	2 1
# 141	2	431.8	1	1 1
# 142	27	431.8	1	4 23
# 143	2	431.8	1	1 1
# 147	2	431.8	1	2
# 148	4495	431.8	1	4495
# 149	52	431.8	1	52
# 150	3	431.8	1	3
# 151	4	431.8	1	4
# 152	1	431.8	1	1
# 153	1	431.8	1	1
# 156	2	431.8	1	2
# 158	1	431.8	1	1
# 159	1	431.8	1	1
# 163	4	431.8	1	4
# 164	1	431.8	1	1
# 165	6	431.8	1	6
# 166	2	431.8	1	2
# 168	2	431.8	1	2
# 170	3	431.8	1	3
# 171	135	431.8	1	135
# 172	2	431.8	1	2
# 175	1	431.8	1	1
# 177	2	431.8	1	2
# 180	8	431.8	1	8
# 182	14	431.8	1	14
# 183	6	431.8	1	6
# 184	5	431.8	1	5
# 187	1	431.8	1	1
# 191	1	431.8	1	1
# 192	1	431.8	1	1
# 194	1	431.8	1	1
# 195	6	431.8	1	1 5
# 198	4	431.8	1	3 1
# 201	1	431.8	1	1
# 202	1	431.8	1	1
# 203	69	431.8	1	69
# 204	7	431.8	1	7
# 205	1	431.8	1	1
# 208	1	431.8	1	0 1
# 209	1	431.8	1	0 1
# 210	5	431.8	1	5
# 211	1	431.8	1	1
# 212	1	431.8	1	0 1
# 213	3	431.8	1	2 1
# 215	1	431.8	1	1
# 217	1	431.8	1	1
# 218	7	431.8	1	7
# 219	1	431.8	1	1
# 220	8	431.8	1	8
# 222	2	431.8	1	2
# 224	1	431.8	1	1
# 225	1	431.8	1	1
# 226	1	431.8	1	0 1
# 229	4	431.8	1	4
# 233	1	431.8	1	1
# 234	1	431.8	1	0 1
# 250	24209	431.8	1	24209
#
#
# === First read: Adapter B2075_GTAATC ===
#
# Sequence: GTAATC; Type: regular 3'; Length: 6; Trimmed: 29819 times
#
# No. of allowed errors:
# 1-5 bp: 0; 6 bp: 1
#
# Bases preceding removed adapters:
#   A: 1.4%
#   C: 11.8%
#   G: 5.5%
#   T: 2.8%
#   none/other: 78.5%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 7	6	431.8	1	6
# 8	3	431.8	1	3
# 9	4	431.8	1	4
# 10	91	431.8	1	91
# 11	12	431.8	1	12
# 12	16	431.8	1	16
# 13	4	431.8	1	4
# 15	1	431.8	1	1
# 16	6	431.8	1	6
# 17	395	431.8	1	395
# 18	18	431.8	1	18
# 19	4	431.8	1	4
# 20	10	431.8	1	10
# 21	4	431.8	1	4
# 22	8	431.8	1	8
# 23	3	431.8	1	3
# 24	2	431.8	1	2
# 25	2	431.8	1	1 1
# 27	32	431.8	1	32
# 28	5	431.8	1	4 1
# 29	2	431.8	1	2
# 30	2	431.8	1	2
# 31	25	431.8	1	25
# 32	5	431.8	1	5
# 33	1	431.8	1	1
# 34	4	431.8	1	4
# 35	7	431.8	1	7
# 36	2	431.8	1	2
# 37	3	431.8	1	3
# 38	4	431.8	1	4
# 40	9	431.8	1	9
# 41	4	431.8	1	4
# 42	2	431.8	1	2
# 43	2	431.8	1	2
# 44	2	431.8	1	2
# 45	3	431.8	1	3
# 46	2	431.8	1	2
# 47	2	431.8	1	2
# 48	3	431.8	1	3
# 49	1	431.8	1	1
# 51	2	431.8	1	2
# 52	4	431.8	1	4
# 54	5	431.8	1	5
# 55	9	431.8	1	9
# 56	201	431.8	1	201
# 57	48	431.8	1	48
# 58	2	431.8	1	2
# 59	4	431.8	1	4
# 60	3	431.8	1	3
# 61	3	431.8	1	3
# 62	6	431.8	1	6
# 63	3	431.8	1	3
# 64	43	431.8	1	43
# 65	20	431.8	1	20
# 66	5	431.8	1	5
# 67	5	431.8	1	4 1
# 68	2	431.8	1	2
# 69	10	431.8	1	10
# 70	3	431.8	1	3
# 71	2	431.8	1	2
# 72	6	431.8	1	6
# 73	2	431.8	1	2
# 74	1	431.8	1	1
# 75	1	431.8	1	1
# 76	3	431.8	1	3
# 78	2	431.8	1	2
# 79	1	431.8	1	1
# 80	2	431.8	1	2
# 81	1	431.8	1	1
# 82	5	431.8	1	4 1
# 83	4	431.8	1	3 1
# 84	5	431.8	1	4 1
# 85	8	431.8	1	4 4
# 86	16	431.8	1	16
# 87	2	431.8	1	2
# 88	1	431.8	1	1
# 89	2	431.8	1	1 1
# 90	3	431.8	1	3
# 91	1061	431.8	1	1061
# 92	11	431.8	1	11
# 93	1	431.8	1	1
# 94	37	431.8	1	37
# 95	10	431.8	1	10
# 96	2	431.8	1	2
# 97	143	431.8	1	143
# 98	3	431.8	1	3
# 99	3	431.8	1	3
# 100	11	431.8	1	11
# 101	34	431.8	1	34
# 102	4	431.8	1	3 1
# 103	7	431.8	1	7
# 104	287	431.8	1	287
# 105	12	431.8	1	11 1
# 106	1	431.8	1	1
# 107	8	431.8	1	7 1
# 108	1	431.8	1	1
# 110	1	431.8	1	1
# 111	1	431.8	1	1
# 112	57	431.8	1	57
# 113	1	431.8	1	0 1
# 114	1	431.8	1	1
# 115	1	431.8	1	1
# 116	2	431.8	1	2
# 117	1	431.8	1	1
# 118	3	431.8	1	3
# 119	44	431.8	1	43 1
# 120	2	431.8	1	2
# 122	2	431.8	1	2
# 123	8	431.8	1	7 1
# 124	124	431.8	1	122 2
# 125	7	431.8	1	7
# 126	2	431.8	1	2
# 127	1	431.8	1	1
# 128	10	431.8	1	10
# 129	3	431.8	1	3
# 130	6	431.8	1	6
# 132	48	431.8	1	48
# 133	17	431.8	1	15 2
# 134	14	431.8	1	12 2
# 135	545	431.8	1	543 2
# 136	14	431.8	1	14
# 137	7	431.8	1	7
# 138	45	431.8	1	45
# 139	6	431.8	1	6
# 140	2	431.8	1	2
# 141	8	431.8	1	6 2
# 142	1621	431.8	1	1607 14
# 143	35	431.8	1	32 3
# 144	2	431.8	1	2
# 145	5	431.8	1	5
# 146	3	431.8	1	3
# 147	1	431.8	1	0 1
# 148	3	431.8	1	3
# 149	4	431.8	1	3 1
# 150	4	431.8	1	4
# 152	247	431.8	1	247
# 153	10	431.8	1	10
# 154	9	431.8	1	8 1
# 155	2	431.8	1	2
# 156	9	431.8	1	9
# 157	35	431.8	1	34 1
# 158	2	431.8	1	0 2
# 159	1	431.8	1	1
# 162	12	431.8	1	12
# 163	7	431.8	1	7
# 164	1	431.8	1	1
# 165	13	431.8	1	11 2
# 166	3	431.8	1	3
# 167	1	431.8	1	1
# 168	6	431.8	1	4 2
# 169	10	431.8	1	9 1
# 170	2	431.8	1	2
# 171	4	431.8	1	4
# 172	4	431.8	1	4
# 173	7	431.8	1	6 1
# 174	4	431.8	1	4
# 176	2	431.8	1	2
# 177	61	431.8	1	61
# 178	1	431.8	1	1
# 179	2	431.8	1	2
# 180	2	431.8	1	2
# 181	1	431.8	1	1
# 182	3	431.8	1	3
# 183	4	431.8	1	4
# 184	1	431.8	1	1
# 185	3	431.8	1	3
# 186	1	431.8	1	1
# 187	1	431.8	1	0 1
# 188	7	431.8	1	6 1
# 190	2	431.8	1	2
# 191	1	431.8	1	1
# 192	1	431.8	1	0 1
# 194	54	431.8	1	54
# 195	1	431.8	1	1
# 197	5	431.8	1	4 1
# 198	2	431.8	1	2
# 199	2	431.8	1	2
# 200	3	431.8	1	3
# 201	28	431.8	1	28
# 202	2	431.8	1	2
# 204	1	431.8	1	1
# 205	1	431.8	1	1
# 206	2	431.8	1	2
# 207	2	431.8	1	2
# 208	119	431.8	1	119
# 209	7	431.8	1	6 1
# 211	3	431.8	1	3
# 212	2	431.8	1	2
# 213	6	431.8	1	6
# 215	2	431.8	1	2
# 218	2	431.8	1	2
# 219	1	431.8	1	1
# 220	3	431.8	1	3
# 221	7	431.8	1	7
# 222	3	431.8	1	3
# 223	8	431.8	1	8
# 224	1	431.8	1	1
# 225	1	431.8	1	0 1
# 226	1	431.8	1	1
# 227	5	431.8	1	0 5
# 228	150	431.8	1	97 53
# 229	6	431.8	1	2 4
# 231	1	431.8	1	0 1
# 234	1	431.8	1	0 1
# 240	2	431.8	1	2
# 241	1	431.8	1	1
# 242	1	431.8	1	1
# 246	1	431.8	1	0 1
# 249	39	431.8	1	39
# 250	23408	431.8	1	23403 5
#
#
# === First read: Adapter B2076_GTACGT ===
#
# Sequence: GTACGT; Type: regular 3'; Length: 6; Trimmed: 27935 times
#
# No. of allowed errors:
# 1-5 bp: 0; 6 bp: 1
#
# Bases preceding removed adapters:
#   A: 6.7%
#   C: 0.9%
#   G: 2.8%
#   T: 0.4%
#   none/other: 89.3%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 6	2	431.8	1	2
# 7	1	431.8	1	1
# 8	1	431.8	1	1
# 10	1	431.8	1	1
# 12	2	431.8	1	2
# 13	4	431.8	1	4
# 14	5	431.8	1	5
# 15	1	431.8	1	1
# 16	11	431.8	1	11
# 17	6	431.8	1	6
# 18	5	431.8	1	4 1
# 19	1	431.8	1	1
# 20	1	431.8	1	1
# 21	2	431.8	1	1 1
# 22	3	431.8	1	3
# 23	1	431.8	1	1
# 24	1	431.8	1	1
# 25	1	431.8	1	1
# 27	3	431.8	1	3
# 28	4	431.8	1	3 1
# 30	1	431.8	1	1
# 32	1	431.8	1	1
# 34	1	431.8	1	1
# 38	1	431.8	1	1
# 43	1	431.8	1	1
# 45	17	431.8	1	17
# 48	1	431.8	1	1
# 51	2	431.8	1	2
# 52	1	431.8	1	1
# 54	1	431.8	1	1
# 55	4	431.8	1	4
# 56	116	431.8	1	116
# 57	3	431.8	1	3
# 60	61	431.8	1	61
# 62	1	431.8	1	1
# 63	1	431.8	1	1
# 64	5	431.8	1	5
# 67	1	431.8	1	1
# 70	1	431.8	1	1
# 72	1	431.8	1	1
# 73	1	431.8	1	1
# 75	1	431.8	1	1
# 76	1	431.8	1	1
# 77	1	431.8	1	1
# 78	2	431.8	1	2
# 79	1	431.8	1	1
# 84	3	431.8	1	3
# 85	2	431.8	1	2
# 86	3	431.8	1	3
# 87	1	431.8	1	1
# 88	2	431.8	1	2
# 89	3	431.8	1	3
# 91	83	431.8	1	83
# 92	3	431.8	1	1 2
# 93	1	431.8	1	1
# 95	1	431.8	1	1
# 97	1	431.8	1	1
# 98	4	431.8	1	4
# 99	1	431.8	1	1
# 100	9	431.8	1	9
# 101	1	431.8	1	1
# 102	94	431.8	1	94
# 103	85	431.8	1	85
# 104	1	431.8	1	1
# 105	1	431.8	1	1
# 110	4	431.8	1	4
# 111	1	431.8	1	1
# 112	1	431.8	1	1
# 113	7	431.8	1	7
# 115	1	431.8	1	1
# 117	2	431.8	1	2
# 118	42	431.8	1	42
# 119	5	431.8	1	5
# 120	2	431.8	1	2
# 121	2	431.8	1	2
# 124	9	431.8	1	8 1
# 125	3	431.8	1	3
# 127	6	431.8	1	6
# 128	3	431.8	1	3
# 129	1	431.8	1	1
# 130	12	431.8	1	12
# 131	3	431.8	1	3
# 132	1	431.8	1	1
# 133	6	431.8	1	6
# 134	1	431.8	1	0 1
# 136	1	431.8	1	1
# 139	11	431.8	1	11
# 140	1	431.8	1	1
# 142	1	431.8	1	1
# 147	2	431.8	1	0 2
# 148	7	431.8	1	7
# 149	3	431.8	1	3
# 150	1	431.8	1	1
# 151	1	431.8	1	1
# 155	2	431.8	1	1 1
# 157	2	431.8	1	2
# 161	4	431.8	1	4
# 163	1	431.8	1	1
# 165	17	431.8	1	17
# 166	2	431.8	1	2
# 167	1	431.8	1	1
# 168	1	431.8	1	1
# 169	1	431.8	1	1
# 170	24	431.8	1	24
# 171	3	431.8	1	3
# 172	1	431.8	1	1
# 174	1	431.8	1	1
# 177	2	431.8	1	2
# 180	7	431.8	1	7
# 181	2013	431.8	1	2013
# 182	20	431.8	1	20
# 183	3	431.8	1	3
# 186	8	431.8	1	8
# 187	4	431.8	1	4
# 188	3	431.8	1	2 1
# 190	1	431.8	1	1
# 192	1	431.8	1	1
# 193	1	431.8	1	1
# 196	25	431.8	1	25
# 200	1	431.8	1	0 1
# 202	2	431.8	1	0 2
# 205	5	431.8	1	5
# 209	2	431.8	1	2
# 210	1	431.8	1	1
# 212	1	431.8	1	1
# 213	2	431.8	1	2
# 215	13	431.8	1	13
# 216	1	431.8	1	1
# 218	1	431.8	1	1
# 221	26	431.8	1	25 1
# 224	1	431.8	1	1
# 225	31	431.8	1	31
# 246	12	431.8	1	12
# 247	4	431.8	1	0 4
# 248	9	431.8	1	0 9
# 249	3	431.8	1	2 1
# 250	24949	431.8	1	24949
#
#
# === First read: Adapter A1000_TCGCAT ===
#
# Sequence: TCGCAT; Type: regular 3'; Length: 6; Trimmed: 16633 times
#
# No. of allowed errors:
# 1-5 bp: 0; 6 bp: 1
#
# Bases preceding removed adapters:
#   A: 5.4%
#   C: 1.3%
#   G: 1.4%
#   T: 2.4%
#   none/other: 89.5%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 6	1	431.8	1	1
# 8	3	431.8	1	3
# 9	1	431.8	1	1
# 10	2	431.8	1	2
# 11	3	431.8	1	3
# 13	3	431.8	1	3
# 14	1	431.8	1	1
# 15	1	431.8	1	1
# 16	8	431.8	1	8
# 17	9	431.8	1	9
# 18	5	431.8	1	5
# 19	12	431.8	1	12
# 20	1	431.8	1	0 1
# 22	4	431.8	1	4
# 23	4	431.8	1	4
# 25	1	431.8	1	1
# 26	2	431.8	1	2
# 27	3	431.8	1	3
# 28	3	431.8	1	3
# 31	1	431.8	1	1
# 32	2	431.8	1	2
# 33	2	431.8	1	2
# 34	15	431.8	1	15
# 35	12	431.8	1	12
# 36	2	431.8	1	2
# 37	2	431.8	1	2
# 38	39	431.8	1	39
# 39	15	431.8	1	15
# 40	6	431.8	1	5 1
# 41	1	431.8	1	1
# 42	4	431.8	1	3 1
# 43	17	431.8	1	17
# 44	47	431.8	1	46 1
# 45	141	431.8	1	141
# 46	102	431.8	1	102
# 47	28	431.8	1	28
# 48	6	431.8	1	6
# 49	5	431.8	1	5
# 53	5	431.8	1	5
# 54	34	431.8	1	34
# 55	10	431.8	1	10
# 56	13	431.8	1	13
# 57	7	431.8	1	7
# 58	296	431.8	1	296
# 59	104	431.8	1	104
# 60	27	431.8	1	27
# 61	97	431.8	1	97
# 62	31	431.8	1	31
# 63	6	431.8	1	5 1
# 64	14	431.8	1	14
# 65	1	431.8	1	1
# 66	3	431.8	1	2 1
# 67	3	431.8	1	3
# 70	1	431.8	1	1
# 71	1	431.8	1	1
# 72	4	431.8	1	4
# 73	2	431.8	1	2
# 78	1	431.8	1	1
# 79	2	431.8	1	2
# 80	1	431.8	1	1
# 81	1	431.8	1	1
# 82	7	431.8	1	7
# 83	4	431.8	1	4
# 84	8	431.8	1	8
# 85	1	431.8	1	1
# 87	23	431.8	1	23
# 90	107	431.8	1	107
# 91	1	431.8	1	1
# 92	3	431.8	1	3
# 93	4	431.8	1	3 1
# 98	2	431.8	1	2
# 99	4	431.8	1	4
# 100	1	431.8	1	1
# 101	2	431.8	1	2
# 103	5	431.8	1	5
# 104	1	431.8	1	1
# 106	6	431.8	1	5 1
# 107	3	431.8	1	3
# 109	12	431.8	1	12
# 110	1	431.8	1	1
# 112	1	431.8	1	1
# 114	1	431.8	1	1
# 115	1	431.8	1	1
# 116	2	431.8	1	1 1
# 117	1	431.8	1	1
# 121	1	431.8	1	1
# 122	49	431.8	1	49
# 125	1	431.8	1	1
# 126	4	431.8	1	4
# 127	5	431.8	1	5
# 128	18	431.8	1	18
# 130	2	431.8	1	2
# 131	7	431.8	1	0 7
# 132	3	431.8	1	2 1
# 134	5	431.8	1	4 1
# 136	1	431.8	1	1
# 137	1	431.8	1	1
# 139	12	431.8	1	11 1
# 140	13	431.8	1	13
# 142	1	431.8	1	1
# 143	36	431.8	1	36
# 144	16	431.8	1	12 4
# 145	3	431.8	1	3
# 146	3	431.8	1	2 1
# 147	1	431.8	1	1
# 148	2	431.8	1	1 1
# 150	2	431.8	1	2
# 153	1	431.8	1	1
# 154	2	431.8	1	1 1
# 159	1	431.8	1	0 1
# 164	1	431.8	1	1
# 165	10	431.8	1	10
# 166	2	431.8	1	1 1
# 167	2	431.8	1	2
# 168	1	431.8	1	1
# 169	6	431.8	1	6
# 170	1	431.8	1	1
# 171	1	431.8	1	1
# 173	2	431.8	1	2
# 176	1	431.8	1	1
# 178	2	431.8	1	2
# 179	4	431.8	1	4
# 180	2	431.8	1	2
# 181	1	431.8	1	1
# 183	2	431.8	1	2
# 184	2	431.8	1	1 1
# 185	3	431.8	1	1 2
# 187	1	431.8	1	1
# 188	1	431.8	1	1
# 189	1	431.8	1	1
# 192	1	431.8	1	1
# 193	1	431.8	1	1
# 195	10	431.8	1	10
# 196	17	431.8	1	17
# 197	1	431.8	1	1
# 198	2	431.8	1	2
# 203	3	431.8	1	3
# 206	2	431.8	1	2
# 207	1	431.8	1	0 1
# 210	2	431.8	1	2
# 212	2	431.8	1	2
# 213	3	431.8	1	3
# 215	1	431.8	1	1
# 216	3	431.8	1	2 1
# 223	4	431.8	1	4
# 224	1	431.8	1	1
# 225	1	431.8	1	1
# 226	2	431.8	1	1 1
# 228	1	431.8	1	1
# 233	4	431.8	1	2 2
# 242	4	431.8	1	4
# 246	1	431.8	1	0 1
# 247	38	431.8	1	27 11
# 248	21	431.8	1	0 21
# 250	14892	431.8	1	14889 3
#
#
# === First read: Adapter A1001_TCTGAC ===
#
# Sequence: TCTGAC; Type: regular 3'; Length: 6; Trimmed: 42503 times
#
# No. of allowed errors:
# 1-5 bp: 0; 6 bp: 1
#
# Bases preceding removed adapters:
#   A: 17.4%
#   C: 0.6%
#   G: 26.0%
#   T: 3.1%
#   none/other: 52.9%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 6	19	431.8	1	19
# 7	889	431.8	1	889
# 8	13	431.8	1	13
# 9	387	431.8	1	387
# 10	4806	431.8	1	4806
# 11	62	431.8	1	62
# 12	5	431.8	1	4 1
# 13	14	431.8	1	14
# 14	3	431.8	1	2 1
# 15	16	431.8	1	15 1
# 16	19	431.8	1	19
# 17	5	431.8	1	5
# 18	3	431.8	1	3
# 19	2	431.8	1	1 1
# 20	2	431.8	1	1 1
# 21	2	431.8	1	2
# 22	1	431.8	1	1
# 23	3	431.8	1	3
# 24	45	431.8	1	44 1
# 25	14	431.8	1	14
# 27	4	431.8	1	4
# 30	9	431.8	1	9
# 32	1	431.8	1	1
# 34	1	431.8	1	1
# 37	1	431.8	1	1
# 38	4	431.8	1	4
# 40	21	431.8	1	21
# 41	3	431.8	1	3
# 43	10	431.8	1	10
# 44	158	431.8	1	158
# 45	4	431.8	1	4
# 46	2	431.8	1	2
# 47	2	431.8	1	2
# 49	32	431.8	1	32
# 50	3	431.8	1	3
# 51	2	431.8	1	2
# 52	2	431.8	1	2
# 53	13	431.8	1	13
# 54	2	431.8	1	2
# 55	1	431.8	1	1
# 58	1	431.8	1	1
# 59	2	431.8	1	2
# 60	1	431.8	1	1
# 61	1	431.8	1	1
# 62	1	431.8	1	1
# 63	1	431.8	1	1
# 64	1	431.8	1	1
# 65	4	431.8	1	4
# 68	1	431.8	1	1
# 69	37	431.8	1	37
# 70	10	431.8	1	10
# 72	1	431.8	1	1
# 73	1	431.8	1	1
# 76	2	431.8	1	1 1
# 77	1	431.8	1	1
# 78	1	431.8	1	1
# 81	1	431.8	1	1
# 82	3	431.8	1	3
# 85	11	431.8	1	11
# 86	2	431.8	1	2
# 87	3	431.8	1	3
# 88	5	431.8	1	5
# 89	3	431.8	1	3
# 90	1	431.8	1	1
# 91	1	431.8	1	1
# 92	3	431.8	1	3
# 93	5	431.8	1	5
# 94	28	431.8	1	28
# 95	1	431.8	1	1
# 96	3	431.8	1	2 1
# 97	3	431.8	1	3
# 98	4	431.8	1	2 2
# 99	1	431.8	1	1
# 100	6	431.8	1	4 2
# 101	2	431.8	1	2
# 102	3	431.8	1	3
# 103	28	431.8	1	28
# 104	3	431.8	1	3
# 105	2	431.8	1	2
# 106	3	431.8	1	1 2
# 107	1	431.8	1	1
# 109	1	431.8	1	1
# 111	3	431.8	1	3
# 112	645	431.8	1	644 1
# 113	10	431.8	1	10
# 116	3	431.8	1	3
# 117	2	431.8	1	2
# 118	2	431.8	1	2
# 119	3	431.8	1	2 1
# 120	21	431.8	1	21
# 121	2	431.8	1	2
# 122	4	431.8	1	4
# 123	2	431.8	1	2
# 124	1	431.8	1	1
# 126	1	431.8	1	1
# 127	1	431.8	1	1
# 128	3	431.8	1	1 2
# 129	6	431.8	1	6
# 130	1	431.8	1	1
# 131	139	431.8	1	126 13
# 132	13	431.8	1	6 7
# 133	7930	431.8	1	7930
# 134	123	431.8	1	123
# 135	12	431.8	1	11 1
# 136	2	431.8	1	1 1
# 137	1	431.8	1	1
# 139	4	431.8	1	2 2
# 140	3	431.8	1	3
# 141	39	431.8	1	38 1
# 142	1	431.8	1	1
# 143	1	431.8	1	1
# 144	2	431.8	1	1 1
# 145	3	431.8	1	3
# 146	47	431.8	1	12 35
# 147	9	431.8	1	1 8
# 148	4	431.8	1	3 1
# 149	1	431.8	1	0 1
# 150	2	431.8	1	0 2
# 153	4	431.8	1	4
# 154	1	431.8	1	1
# 155	1	431.8	1	1
# 156	4	431.8	1	4
# 157	2	431.8	1	2
# 159	3	431.8	1	3
# 160	322	431.8	1	322
# 161	25	431.8	1	24 1
# 162	8	431.8	1	8
# 163	4	431.8	1	2 2
# 164	3	431.8	1	3
# 165	1	431.8	1	1
# 166	1	431.8	1	0 1
# 167	2	431.8	1	1 1
# 168	34	431.8	1	5 29
# 169	2702	431.8	1	882 1820
# 170	429	431.8	1	26 403
# 171	63	431.8	1	5 58
# 172	36	431.8	1	1 35
# 173	20	431.8	1	4 16
# 174	17	431.8	1	2 15
# 175	4	431.8	1	0 4
# 176	4	431.8	1	0 4
# 177	5	431.8	1	0 5
# 178	1	431.8	1	1
# 180	3	431.8	1	1 2
# 183	4	431.8	1	2 2
# 184	40	431.8	1	11 29
# 185	6	431.8	1	2 4
# 186	1	431.8	1	1
# 187	5	431.8	1	3 2
# 188	5	431.8	1	0 5
# 189	1	431.8	1	0 1
# 190	2	431.8	1	2
# 193	1	431.8	1	1
# 195	3	431.8	1	1 2
# 198	18	431.8	1	0 18
# 199	2	431.8	1	1 1
# 200	4	431.8	1	4
# 201	1	431.8	1	0 1
# 202	1	431.8	1	1
# 203	2	431.8	1	2
# 204	4	431.8	1	2 2
# 206	207	431.8	1	207
# 207	122	431.8	1	120 2
# 208	5	431.8	1	4 1
# 210	39	431.8	1	2 37
# 211	6	431.8	1	3 3
# 212	1	431.8	1	0 1
# 213	2	431.8	1	0 2
# 214	2	431.8	1	1 1
# 215	5	431.8	1	2 3
# 216	1	431.8	1	1
# 217	2	431.8	1	0 2
# 218	12	431.8	1	0 12
# 219	1	431.8	1	0 1
# 220	1	431.8	1	1
# 221	2	431.8	1	0 2
# 222	1	431.8	1	1
# 226	1	431.8	1	1
# 228	2	431.8	1	2
# 230	1	431.8	1	1
# 240	1	431.8	1	1
# 250	22466	431.8	1	22458 8
#
#
# === First read: Adapter A1002_AAGCGG ===
#
# Sequence: AAGCGG; Type: regular 3'; Length: 6; Trimmed: 118591 times
#
# No. of allowed errors:
# 1-5 bp: 0; 6 bp: 1
#
# Bases preceding removed adapters:
#   A: 59.9%
#   C: 5.8%
#   G: 8.1%
#   T: 13.4%
#   none/other: 12.9%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 6	1	431.8	1	1
# 7	3	431.8	1	3
# 8	4	431.8	1	4
# 9	6	431.8	1	6
# 10	2	431.8	1	2
# 11	2	431.8	1	2
# 12	1	431.8	1	1
# 13	1	431.8	1	1
# 15	4	431.8	1	4
# 17	40	431.8	1	39 1
# 18	1	431.8	1	1
# 19	2	431.8	1	2
# 20	2	431.8	1	2
# 21	4	431.8	1	4
# 22	3	431.8	1	3
# 23	5	431.8	1	5
# 24	4	431.8	1	4
# 25	3	431.8	1	3
# 27	3	431.8	1	3
# 28	40	431.8	1	40
# 29	1934	431.8	1	1934
# 30	10496	431.8	1	10496
# 31	108	431.8	1	108
# 32	7	431.8	1	7
# 33	7	431.8	1	7
# 34	6	431.8	1	6
# 35	4	431.8	1	4
# 37	5	431.8	1	5
# 38	4	431.8	1	4
# 39	3	431.8	1	3
# 40	1	431.8	1	1
# 42	2	431.8	1	2
# 43	11	431.8	1	11
# 44	6	431.8	1	6
# 45	5	431.8	1	4 1
# 46	1	431.8	1	1
# 47	2	431.8	1	1 1
# 48	2	431.8	1	2
# 51	1	431.8	1	0 1
# 52	8	431.8	1	8
# 55	1	431.8	1	1
# 56	2	431.8	1	2
# 57	3	431.8	1	3
# 58	23	431.8	1	22 1
# 60	43	431.8	1	43
# 61	2	431.8	1	2
# 62	6	431.8	1	6
# 63	13	431.8	1	13
# 64	29	431.8	1	29
# 65	4	431.8	1	4
# 66	1	431.8	1	1
# 67	1	431.8	1	1
# 68	8	431.8	1	7 1
# 69	4	431.8	1	4
# 70	1	431.8	1	1
# 71	4	431.8	1	4
# 72	266	431.8	1	266
# 73	40	431.8	1	40
# 74	3	431.8	1	3
# 75	1	431.8	1	1
# 76	1	431.8	1	1
# 77	3	431.8	1	3
# 78	3	431.8	1	3
# 79	2	431.8	1	2
# 80	14	431.8	1	14
# 81	41	431.8	1	41
# 82	168	431.8	1	168
# 83	535	431.8	1	535
# 84	16	431.8	1	16
# 85	7	431.8	1	7
# 86	20	431.8	1	19 1
# 87	7	431.8	1	7
# 88	257	431.8	1	257
# 89	19449	431.8	1	19449
# 90	46302	431.8	1	46301 1
# 91	469	431.8	1	468 1
# 92	30	431.8	1	30
# 93	3547	431.8	1	3547
# 94	48	431.8	1	48
# 95	817	431.8	1	817
# 96	34	431.8	1	34
# 97	26	431.8	1	26
# 98	39	431.8	1	39
# 99	31	431.8	1	31
# 100	15	431.8	1	14 1
# 101	2	431.8	1	1 1
# 102	9	431.8	1	9
# 103	3	431.8	1	3
# 104	3	431.8	1	3
# 106	3	431.8	1	3
# 107	4	431.8	1	4
# 108	2	431.8	1	2
# 109	7	431.8	1	7
# 110	2	431.8	1	2
# 111	6	431.8	1	6
# 112	1	431.8	1	1
# 113	2	431.8	1	2
# 115	5	431.8	1	5
# 116	2	431.8	1	2
# 117	23	431.8	1	22 1
# 118	34	431.8	1	33 1
# 119	277	431.8	1	277
# 120	741	431.8	1	738 3
# 121	1503	431.8	1	1502 1
# 122	65	431.8	1	65
# 123	7	431.8	1	7
# 124	6	431.8	1	6
# 125	2	431.8	1	1 1
# 126	1	431.8	1	1
# 128	3	431.8	1	3
# 129	2	431.8	1	1 1
# 130	27	431.8	1	25 2
# 131	8	431.8	1	8
# 132	13	431.8	1	13
# 133	3	431.8	1	3
# 134	6	431.8	1	6
# 135	11	431.8	1	11
# 136	28	431.8	1	28
# 137	12	431.8	1	12
# 138	4	431.8	1	4
# 139	12	431.8	1	12
# 140	28	431.8	1	25 3
# 141	6	431.8	1	6
# 142	6	431.8	1	6
# 144	3	431.8	1	3
# 145	8	431.8	1	8
# 146	14	431.8	1	14
# 147	3	431.8	1	3
# 148	12	431.8	1	11 1
# 149	280	431.8	1	280
# 150	2696	431.8	1	2696
# 151	34	431.8	1	34
# 152	8	431.8	1	8
# 153	4	431.8	1	4
# 154	2	431.8	1	2
# 155	8	431.8	1	8
# 156	12	431.8	1	12
# 158	12	431.8	1	12
# 159	11	431.8	1	11
# 160	5	431.8	1	5
# 161	3	431.8	1	3
# 162	5	431.8	1	5
# 163	3072	431.8	1	3072
# 164	33	431.8	1	33
# 165	23	431.8	1	23
# 166	14	431.8	1	14
# 167	7	431.8	1	7
# 168	4	431.8	1	4
# 169	7	431.8	1	7
# 170	1	431.8	1	1
# 171	1	431.8	1	1
# 172	2	431.8	1	2
# 173	58	431.8	1	58
# 174	9	431.8	1	9
# 175	20	431.8	1	20
# 176	1	431.8	1	1
# 177	53	431.8	1	53
# 178	2	431.8	1	2
# 179	8	431.8	1	8
# 181	2	431.8	1	2
# 182	2	431.8	1	1 1
# 183	56	431.8	1	56
# 184	1	431.8	1	1
# 185	17	431.8	1	14 3
# 186	23	431.8	1	23
# 189	17	431.8	1	15 2
# 190	1	431.8	1	1
# 191	1	431.8	1	1
# 193	3	431.8	1	3
# 194	9	431.8	1	9
# 196	6	431.8	1	6
# 198	19	431.8	1	19
# 200	8	431.8	1	8
# 201	3	431.8	1	3
# 202	3	431.8	1	3
# 203	2	431.8	1	2
# 204	4362	431.8	1	4360 2
# 205	637	431.8	1	637
# 206	10	431.8	1	9 1
# 207	5	431.8	1	5
# 208	2	431.8	1	2
# 209	1	431.8	1	1
# 210	1	431.8	1	1
# 211	4	431.8	1	4
# 212	727	431.8	1	727
# 213	22	431.8	1	22
# 214	34	431.8	1	34
# 215	4	431.8	1	4
# 216	2	431.8	1	2
# 217	8	431.8	1	8
# 219	2	431.8	1	2
# 220	75	431.8	1	74 1
# 222	6	431.8	1	6
# 223	5	431.8	1	4 1
# 224	3	431.8	1	3
# 225	5	431.8	1	5
# 226	5	431.8	1	5
# 227	2790	431.8	1	2751 39
# 228	32	431.8	1	29 3
# 229	2	431.8	1	2
# 233	6	431.8	1	6
# 235	1	431.8	1	0 1
# 236	1	431.8	1	1
# 239	2	431.8	1	0 2
# 246	1	431.8	1	1
# 247	1	431.8	1	1
# 249	3	431.8	1	3
# 250	15265	431.8	1	15265
#
#
# === First read: Adapter A1003_AAGCTA ===
#
# Sequence: AAGCTA; Type: regular 3'; Length: 6; Trimmed: 33830 times
#
# No. of allowed errors:
# 1-5 bp: 0; 6 bp: 1
#
# Bases preceding removed adapters:
#   A: 67.8%
#   C: 1.5%
#   G: 0.7%
#   T: 2.2%
#   none/other: 27.8%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 6	5	431.8	1	5
# 7	1	431.8	1	0 1
# 8	3	431.8	1	3
# 9	1	431.8	1	1
# 10	3	431.8	1	2 1
# 11	4	431.8	1	4
# 12	2	431.8	1	1 1
# 13	1	431.8	1	1
# 14	1	431.8	1	1
# 15	4	431.8	1	4
# 16	16	431.8	1	16
# 17	6	431.8	1	5 1
# 18	41	431.8	1	39 2
# 19	4	431.8	1	3 1
# 20	1	431.8	1	1
# 21	11	431.8	1	11
# 22	4	431.8	1	4
# 23	1	431.8	1	1
# 25	2	431.8	1	2
# 26	3	431.8	1	3
# 27	30	431.8	1	30
# 28	4	431.8	1	4
# 29	3	431.8	1	3
# 30	8	431.8	1	8
# 31	1	431.8	1	1
# 32	2	431.8	1	2
# 34	3	431.8	1	3
# 35	11	431.8	1	11
# 36	3	431.8	1	3
# 38	1	431.8	1	0 1
# 39	7	431.8	1	7
# 40	5	431.8	1	5
# 41	1	431.8	1	1
# 42	4	431.8	1	2 2
# 43	4	431.8	1	4
# 44	3	431.8	1	3
# 45	1	431.8	1	1
# 46	5	431.8	1	5
# 47	2	431.8	1	2
# 48	2	431.8	1	2
# 50	2	431.8	1	2
# 51	2	431.8	1	2
# 54	1	431.8	1	1
# 55	9	431.8	1	9
# 57	5	431.8	1	5
# 59	1	431.8	1	1
# 60	24	431.8	1	23 1
# 61	3	431.8	1	3
# 62	26	431.8	1	24 2
# 63	8	431.8	1	8
# 64	13	431.8	1	11 2
# 65	2	431.8	1	2
# 67	1	431.8	1	0 1
# 69	1	431.8	1	0 1
# 70	1	431.8	1	0 1
# 71	1	431.8	1	1
# 72	11	431.8	1	11
# 73	2	431.8	1	2
# 74	4	431.8	1	3 1
# 75	1	431.8	1	1
# 77	1	431.8	1	0 1
# 81	2	431.8	1	1 1
# 82	4	431.8	1	4
# 86	8	431.8	1	7 1
# 87	1	431.8	1	1
# 88	4	431.8	1	4
# 89	5	431.8	1	3 2
# 90	23	431.8	1	22 1
# 91	16	431.8	1	16
# 92	3	431.8	1	3
# 93	10	431.8	1	10
# 94	4	431.8	1	3 1
# 95	1	431.8	1	1
# 96	1	431.8	1	0 1
# 97	5	431.8	1	5
# 98	1	431.8	1	0 1
# 100	4	431.8	1	3 1
# 102	65	431.8	1	65
# 103	4	431.8	1	4
# 105	1	431.8	1	1
# 107	6	431.8	1	5 1
# 108	2	431.8	1	2
# 109	3	431.8	1	3
# 110	711	431.8	1	711
# 111	126	431.8	1	126
# 112	2	431.8	1	2
# 113	1	431.8	1	1
# 114	3	431.8	1	3
# 116	61	431.8	1	61
# 117	1	431.8	1	1
# 118	6	431.8	1	6
# 119	26	431.8	1	26
# 120	11	431.8	1	11
# 121	5	431.8	1	5
# 122	3	431.8	1	2 1
# 123	1	431.8	1	1
# 124	2	431.8	1	2
# 125	5	431.8	1	4 1
# 126	4	431.8	1	4
# 127	7	431.8	1	5 2
# 128	26	431.8	1	25 1
# 129	3	431.8	1	2 1
# 130	39	431.8	1	38 1
# 131	8	431.8	1	8
# 132	2	431.8	1	2
# 133	3	431.8	1	3
# 134	2	431.8	1	2
# 135	1	431.8	1	1
# 136	5	431.8	1	5
# 137	3	431.8	1	2 1
# 138	2	431.8	1	2
# 139	2	431.8	1	0 2
# 140	3	431.8	1	3
# 143	8	431.8	1	6 2
# 144	12	431.8	1	12
# 145	3	431.8	1	3
# 146	2	431.8	1	1 1
# 147	1	431.8	1	1
# 148	9	431.8	1	9
# 149	15	431.8	1	14 1
# 150	99	431.8	1	99
# 151	2	431.8	1	2
# 152	2	431.8	1	2
# 153	1	431.8	1	1
# 154	1	431.8	1	1
# 156	1	431.8	1	1
# 158	14	431.8	1	14
# 159	1	431.8	1	1
# 160	1	431.8	1	1
# 161	1	431.8	1	1
# 162	1	431.8	1	1
# 163	12	431.8	1	11 1
# 164	2	431.8	1	2
# 165	1	431.8	1	1
# 168	4	431.8	1	4
# 169	30	431.8	1	30
# 170	2	431.8	1	2
# 171	1	431.8	1	1
# 172	3	431.8	1	3
# 173	10	431.8	1	10
# 174	1	431.8	1	1
# 175	9	431.8	1	9
# 176	1	431.8	1	1
# 177	9	431.8	1	8 1
# 178	3	431.8	1	3
# 179	6	431.8	1	6
# 180	4	431.8	1	4
# 181	4	431.8	1	3 1
# 184	2	431.8	1	1 1
# 185	99	431.8	1	98 1
# 186	2	431.8	1	2
# 187	3	431.8	1	3
# 188	1	431.8	1	1
# 189	17	431.8	1	17
# 193	5	431.8	1	5
# 194	9	431.8	1	8 1
# 197	1	431.8	1	1
# 198	2	431.8	1	1 1
# 199	1	431.8	1	1
# 200	14	431.8	1	14
# 201	1	431.8	1	1
# 202	3	431.8	1	3
# 203	2	431.8	1	2
# 204	5	431.8	1	5
# 205	2	431.8	1	2
# 206	3	431.8	1	2 1
# 207	3	431.8	1	3
# 209	3	431.8	1	3
# 210	4	431.8	1	4
# 211	2	431.8	1	2
# 212	14	431.8	1	13 1
# 213	8	431.8	1	8
# 214	5	431.8	1	5
# 215	2	431.8	1	2
# 216	2	431.8	1	2
# 217	11	431.8	1	11
# 218	8	431.8	1	8
# 219	5	431.8	1	5
# 220	4	431.8	1	4
# 221	17	431.8	1	17
# 222	5	431.8	1	5
# 223	5	431.8	1	4 1
# 226	15	431.8	1	15
# 227	22023	431.8	1	22023
# 228	202	431.8	1	201 1
# 229	3	431.8	1	3
# 230	8	431.8	1	8
# 231	9	431.8	1	7 2
# 232	3	431.8	1	3
# 233	22	431.8	1	22
# 235	2	431.8	1	2
# 242	2	431.8	1	2
# 243	3	431.8	1	0 3
# 244	11	431.8	1	9 2
# 247	2	431.8	1	1 1
# 249	2	431.8	1	1 1
# 250	9397	431.8	1	9397
#
#
# === First read: Adapter A1004_AAGGAT ===
#
# Sequence: AAGGAT; Type: regular 3'; Length: 6; Trimmed: 22615 times
#
# No. of allowed errors:
# 1-5 bp: 0; 6 bp: 1
#
# Bases preceding removed adapters:
#   A: 2.9%
#   C: 1.1%
#   G: 1.5%
#   T: 7.0%
#   none/other: 87.4%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 6	3	431.8	1	3
# 7	2	431.8	1	2
# 8	1	431.8	1	1
# 9	3	431.8	1	3
# 10	4	431.8	1	4
# 11	3	431.8	1	3
# 12	5	431.8	1	5
# 13	4	431.8	1	4
# 14	1	431.8	1	1
# 15	2	431.8	1	2
# 16	6	431.8	1	6
# 17	6	431.8	1	6
# 18	5	431.8	1	5
# 19	19	431.8	1	18 1
# 20	40	431.8	1	40
# 21	24	431.8	1	24
# 22	8	431.8	1	8
# 23	16	431.8	1	16
# 24	5	431.8	1	5
# 25	3	431.8	1	3
# 26	5	431.8	1	5
# 27	6	431.8	1	5 1
# 28	12	431.8	1	12
# 29	2	431.8	1	2
# 30	8	431.8	1	8
# 31	19	431.8	1	19
# 32	9	431.8	1	9
# 33	4	431.8	1	4
# 34	2	431.8	1	2
# 35	2	431.8	1	2
# 36	31	431.8	1	31
# 37	11	431.8	1	11
# 38	4	431.8	1	3 1
# 39	4	431.8	1	4
# 41	2	431.8	1	2
# 42	9	431.8	1	8 1
# 43	2	431.8	1	2
# 44	5	431.8	1	5
# 46	2	431.8	1	2
# 48	8	431.8	1	8
# 49	2	431.8	1	2
# 50	6	431.8	1	6
# 51	4	431.8	1	4
# 52	28	431.8	1	28
# 53	6	431.8	1	6
# 54	3	431.8	1	3
# 55	2	431.8	1	1 1
# 56	1	431.8	1	1
# 58	1	431.8	1	1
# 59	3	431.8	1	3
# 60	4	431.8	1	4
# 61	3	431.8	1	3
# 62	1	431.8	1	0 1
# 64	4	431.8	1	4
# 66	7	431.8	1	7
# 69	13	431.8	1	13
# 70	3	431.8	1	3
# 71	1	431.8	1	1
# 72	6	431.8	1	6
# 73	2	431.8	1	2
# 75	1	431.8	1	1
# 76	3	431.8	1	2 1
# 77	1	431.8	1	1
# 78	1	431.8	1	0 1
# 79	13	431.8	1	13
# 80	1	431.8	1	1
# 82	5	431.8	1	5
# 83	7	431.8	1	7
# 84	5	431.8	1	5
# 85	14	431.8	1	14
# 86	88	431.8	1	88
# 88	7	431.8	1	7
# 89	2	431.8	1	2
# 90	3	431.8	1	3
# 91	4	431.8	1	2 2
# 92	21	431.8	1	21
# 93	4	431.8	1	4
# 94	1291	431.8	1	1291
# 95	96	431.8	1	96
# 96	3	431.8	1	3
# 97	2	431.8	1	2
# 98	4	431.8	1	4
# 99	5	431.8	1	4 1
# 100	3	431.8	1	3
# 101	6	431.8	1	6
# 102	3	431.8	1	3
# 103	10	431.8	1	10
# 104	1	431.8	1	1
# 105	2	431.8	1	2
# 106	8	431.8	1	8
# 107	6	431.8	1	6
# 108	2	431.8	1	2
# 109	1	431.8	1	1
# 111	6	431.8	1	6
# 112	1	431.8	1	1
# 114	3	431.8	1	3
# 116	1	431.8	1	1
# 117	1	431.8	1	1
# 118	5	431.8	1	5
# 119	5	431.8	1	5
# 120	26	431.8	1	22 4
# 121	18	431.8	1	17 1
# 122	6	431.8	1	6
# 125	2	431.8	1	2
# 126	2	431.8	1	2
# 127	4	431.8	1	4
# 128	1	431.8	1	1
# 129	2	431.8	1	1 1
# 130	162	431.8	1	162
# 131	3	431.8	1	2 1
# 132	3	431.8	1	2 1
# 133	1	431.8	1	1
# 134	4	431.8	1	3 1
# 135	3	431.8	1	3
# 136	5	431.8	1	5
# 137	15	431.8	1	13 2
# 138	2	431.8	1	1 1
# 139	2	431.8	1	2
# 140	13	431.8	1	13
# 141	1	431.8	1	1
# 142	2	431.8	1	1 1
# 143	1	431.8	1	0 1
# 144	12	431.8	1	12
# 145	3	431.8	1	3
# 146	2	431.8	1	2
# 148	7	431.8	1	7
# 150	2	431.8	1	2
# 151	1	431.8	1	1
# 152	1	431.8	1	1
# 153	3	431.8	1	3
# 154	3	431.8	1	3
# 156	4	431.8	1	4
# 157	4	431.8	1	4
# 158	2	431.8	1	2
# 159	2	431.8	1	1 1
# 160	7	431.8	1	7
# 161	1	431.8	1	1
# 162	1	431.8	1	1
# 163	1	431.8	1	1
# 166	2	431.8	1	2
# 168	1	431.8	1	1
# 169	8	431.8	1	8
# 170	11	431.8	1	11
# 171	5	431.8	1	5
# 172	1	431.8	1	1
# 173	71	431.8	1	71
# 174	17	431.8	1	17
# 175	3	431.8	1	3
# 176	8	431.8	1	8
# 177	4	431.8	1	4
# 178	6	431.8	1	6
# 179	3	431.8	1	3
# 182	2	431.8	1	2
# 184	2	431.8	1	1 1
# 185	9	431.8	1	6 3
# 186	2	431.8	1	2
# 187	18	431.8	1	18
# 188	8	431.8	1	8
# 189	1	431.8	1	1
# 190	27	431.8	1	27
# 191	2	431.8	1	1 1
# 192	1	431.8	1	1
# 193	2	431.8	1	2
# 195	2	431.8	1	2
# 196	1	431.8	1	1
# 197	1	431.8	1	1
# 199	2	431.8	1	2
# 200	1	431.8	1	1
# 201	4	431.8	1	4
# 202	3	431.8	1	3
# 203	14	431.8	1	14
# 207	5	431.8	1	4 1
# 208	3	431.8	1	3
# 209	11	431.8	1	11
# 210	2	431.8	1	2
# 211	114	431.8	1	114
# 212	4	431.8	1	1 3
# 216	4	431.8	1	3 1
# 217	6	431.8	1	4 2
# 219	3	431.8	1	3
# 220	3	431.8	1	3
# 221	1	431.8	1	1
# 222	1	431.8	1	1
# 223	8	431.8	1	8
# 224	1	431.8	1	1
# 225	13	431.8	1	13
# 226	1	431.8	1	1
# 227	3	431.8	1	3
# 228	11	431.8	1	11
# 230	1	431.8	1	1
# 231	2	431.8	1	2
# 236	13	431.8	1	13
# 239	1	431.8	1	1
# 242	2	431.8	1	2
# 243	1	431.8	1	1
# 244	1	431.8	1	0 1
# 246	6	431.8	1	0 6
# 249	3	431.8	1	3
# 250	19763	431.8	1	19762 1
#
#
# === First read: Adapter A1005_AAGGCA ===
#
# Sequence: AAGGCA; Type: regular 3'; Length: 6; Trimmed: 118076 times
#
# No. of allowed errors:
# 1-5 bp: 0; 6 bp: 1
#
# Bases preceding removed adapters:
#   A: 1.3%
#   C: 0.7%
#   G: 96.2%
#   T: 0.3%
#   none/other: 1.5%
# WARNING:
#     The adapter is preceded by "G" extremely often.
#     The provided adapter sequence could be incomplete at its 5' end.
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 6	1	431.8	1	1
# 7	1	431.8	1	1
# 8	3	431.8	1	3
# 9	1	431.8	1	1
# 13	1	431.8	1	1
# 15	1	431.8	1	1
# 16	1	431.8	1	1
# 17	1	431.8	1	1
# 18	1	431.8	1	1
# 19	2	431.8	1	2
# 22	4	431.8	1	4
# 23	15	431.8	1	14 1
# 24	3	431.8	1	1 2
# 25	1	431.8	1	1
# 26	1	431.8	1	1
# 27	3	431.8	1	3
# 28	4	431.8	1	4
# 29	268	431.8	1	268
# 30	77131	431.8	1	77131
# 31	2743	431.8	1	2743
# 32	127	431.8	1	127
# 33	24	431.8	1	24
# 34	21	431.8	1	20 1
# 35	44	431.8	1	44
# 36	5	431.8	1	5
# 37	2	431.8	1	2
# 38	3	431.8	1	3
# 39	4	431.8	1	4
# 40	1	431.8	1	1
# 41	10	431.8	1	10
# 43	1	431.8	1	1
# 45	1	431.8	1	1
# 46	2	431.8	1	2
# 49	2	431.8	1	2
# 50	3	431.8	1	3
# 52	1	431.8	1	1
# 53	9	431.8	1	9
# 54	2	431.8	1	2
# 55	4	431.8	1	4
# 56	4	431.8	1	4
# 57	1	431.8	1	1
# 58	3	431.8	1	3
# 59	1	431.8	1	1
# 60	45	431.8	1	45
# 61	15	431.8	1	15
# 63	3	431.8	1	3
# 64	3	431.8	1	3
# 65	1	431.8	1	1
# 68	2	431.8	1	2
# 69	2	431.8	1	2
# 70	3	431.8	1	2 1
# 73	1	431.8	1	1
# 74	4	431.8	1	4
# 75	31	431.8	1	31
# 76	5	431.8	1	5
# 77	20	431.8	1	19 1
# 80	1	431.8	1	1
# 81	5	431.8	1	5
# 82	3	431.8	1	3
# 83	1	431.8	1	1
# 84	1	431.8	1	1
# 87	2	431.8	1	2
# 90	40	431.8	1	40
# 91	18	431.8	1	18
# 92	3	431.8	1	3
# 93	6	431.8	1	6
# 94	65	431.8	1	65
# 95	67	431.8	1	67
# 96	4	431.8	1	4
# 97	7	431.8	1	7
# 98	1	431.8	1	1
# 99	1	431.8	1	1
# 103	1	431.8	1	1
# 106	6	431.8	1	6
# 107	2	431.8	1	2
# 108	1	431.8	1	1
# 111	2	431.8	1	1 1
# 112	2	431.8	1	2
# 114	1	431.8	1	1
# 115	1	431.8	1	1
# 117	1	431.8	1	1
# 119	7	431.8	1	7
# 120	9	431.8	1	9
# 121	6	431.8	1	6
# 122	5	431.8	1	5
# 123	1	431.8	1	1
# 124	2	431.8	1	2
# 127	1	431.8	1	1
# 128	2	431.8	1	2
# 129	10	431.8	1	10
# 130	5	431.8	1	5
# 131	23	431.8	1	22 1
# 132	1	431.8	1	1
# 133	4	431.8	1	4
# 134	2	431.8	1	2
# 135	2	431.8	1	1 1
# 136	10	431.8	1	9 1
# 137	8	431.8	1	8
# 139	4	431.8	1	4
# 140	61	431.8	1	59 2
# 141	17476	431.8	1	17476
# 142	227	431.8	1	225 2
# ...
# 16	4	431.8	1	4
# 18	6	431.8	1	6
# 19	3	431.8	1	3
# 20	2	431.8	1	2
# 21	1	431.8	1	1
# 23	1	431.8	1	1
# 25	1	431.8	1	1
# 30	1	431.8	1	1
# 32	1	431.8	1	1
# 33	1	431.8	1	1
# 34	1	431.8	1	1
# 36	1	431.8	1	1
# 40	4	431.8	1	4
# 41	1	431.8	1	0 1
# 44	2	431.8	1	2
# 45	7	431.8	1	7
# 46	3	431.8	1	3
# 50	1	431.8	1	1
# 51	1	431.8	1	1
# 52	4	431.8	1	4
# 53	1	431.8	1	1
# 54	2	431.8	1	2
# 57	3	431.8	1	3
# 58	1	431.8	1	1
# 59	1	431.8	1	1
# 61	1	431.8	1	1
# 64	1	431.8	1	1
# 65	1	431.8	1	1
# 66	3	431.8	1	3
# 67	1	431.8	1	1
# 73	1	431.8	1	1
# 74	3	431.8	1	3
# 76	1	431.8	1	0 1
# 78	3	431.8	1	3
# 79	1	431.8	1	1
# 80	2	431.8	1	2
# 82	4	431.8	1	3 1
# 83	2	431.8	1	2
# 84	2	431.8	1	2
# 85	8	431.8	1	8
# 86	2	431.8	1	2
# 87	3	431.8	1	3
# 89	6	431.8	1	6
# 90	1	431.8	1	1
# 91	2	431.8	1	2
# 92	2	431.8	1	1 1
# 97	1	431.8	1	1
# 98	2	431.8	1	2
# 100	6	431.8	1	6
# 101	4	431.8	1	4
# 102	1	431.8	1	1
# 103	2	431.8	1	2
# 104	3	431.8	1	3
# 107	1	431.8	1	1
# 108	1	431.8	1	1
# 110	1	431.8	1	1
# 111	15	431.8	1	15
# 112	2	431.8	1	2
# 115	1	431.8	1	1
# 118	1	431.8	1	1
# 119	3	431.8	1	3
# 120	3	431.8	1	3
# 121	1	431.8	1	1
# 122	11	431.8	1	11
# 123	2	431.8	1	2
# 124	3	431.8	1	3
# 127	1	431.8	1	0 1
# 130	1	431.8	1	1
# 131	4	431.8	1	4
# 132	8	431.8	1	8
# 133	2	431.8	1	2
# 135	2	431.8	1	2
# 136	1	431.8	1	1
# 138	3	431.8	1	3
# 139	10	431.8	1	10
# 142	1	431.8	1	1
# 144	1	431.8	1	1
# 145	5	431.8	1	5
# 146	1	431.8	1	1
# 147	4	431.8	1	4
# 149	4	431.8	1	4
# 150	101	431.8	1	101
# 151	2	431.8	1	2
# 154	1	431.8	1	1
# 155	1	431.8	1	1
# 156	2	431.8	1	2
# 157	1	431.8	1	1
# 158	1	431.8	1	1
# 160	1	431.8	1	1
# 163	3	431.8	1	3
# 165	11	431.8	1	11
# 166	1	431.8	1	1
# 167	10	431.8	1	10
# 168	3	431.8	1	2 1
# 170	3	431.8	1	3
# 171	2	431.8	1	2
# 172	2	431.8	1	2
# 173	2	431.8	1	2
# 175	1	431.8	1	1
# 178	6	431.8	1	6
# 179	1	431.8	1	1
# 182	4	431.8	1	4
# 187	5	431.8	1	4 1
# 188	2	431.8	1	2
# 193	1	431.8	1	1
# 194	1	431.8	1	1
# 195	1	431.8	1	1
# 197	1	431.8	1	1
# 198	780	431.8	1	780
# 199	15	431.8	1	15
# 202	7	431.8	1	7
# 204	1	431.8	1	1
# 206	1	431.8	1	1
# 208	3	431.8	1	3
# 209	2	431.8	1	2
# 210	125	431.8	1	125
# 211	2	431.8	1	2
# 212	1	431.8	1	1
# 216	1	431.8	1	1
# 217	1	431.8	1	1
# 219	1	431.8	1	1
# 220	5	431.8	1	5
# 221	2	431.8	1	2
# 222	4	431.8	1	3 1
# 225	122	431.8	1	122
# 226	2	431.8	1	2
# 228	1	431.8	1	1
# 231	1	431.8	1	1
# 232	1	431.8	1	1
# 238	7	431.8	1	7
# 246	6	431.8	1	6
# 249	1	431.8	1	1
# 250	17090	431.8	1	17090
#
#
# === First read: Adapter A1030_ATAGAC ===
#
# Sequence: ATAGAC; Type: regular 3'; Length: 6; Trimmed: 17595 times
#
# No. of allowed errors:
# 1-5 bp: 0; 6 bp: 1
#
# Bases preceding removed adapters:
#   A: 0.3%
#   C: 0.5%
#   G: 0.1%
#   T: 0.1%
#   none/other: 99.0%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 9	3	431.8	1	3
# 12	2	431.8	1	2
# 13	2	431.8	1	2
# 19	1	431.8	1	1
# 20	1	431.8	1	1
# 22	1	431.8	1	1
# 24	1	431.8	1	1
# 34	1	431.8	1	1
# 36	3	431.8	1	3
# 40	1	431.8	1	1
# 51	1	431.8	1	1
# 52	1	431.8	1	1
# 56	1	431.8	1	1
# 59	2	431.8	1	2
# 68	2	431.8	1	2
# 70	1	431.8	1	1
# 79	5	431.8	1	5
# 88	3	431.8	1	3
# 92	2	431.8	1	2
# 97	1	431.8	1	1
# 98	1	431.8	1	1
# 99	1	431.8	1	1
# 103	1	431.8	1	1
# 105	1	431.8	1	1
# 107	1	431.8	1	1
# 108	1	431.8	1	1
# 112	1	431.8	1	1
# 113	2	431.8	1	2
# 115	1	431.8	1	1
# 116	1	431.8	1	1
# 119	1	431.8	1	1
# 120	1	431.8	1	1
# 121	4	431.8	1	4
# 122	3	431.8	1	3
# 131	1	431.8	1	1
# 132	53	431.8	1	53
# 134	1	431.8	1	1
# 140	2	431.8	1	2
# 141	1	431.8	1	1
# 148	3	431.8	1	3
# 152	2	431.8	1	2
# 155	1	431.8	1	1
# 157	1	431.8	1	1
# 158	1	431.8	1	1
# 159	1	431.8	1	1
# 160	2	431.8	1	2
# 167	1	431.8	1	1
# 170	1	431.8	1	1
# 171	1	431.8	1	1
# 174	1	431.8	1	1
# 179	2	431.8	1	0 2
# 180	1	431.8	1	0 1
# 184	3	431.8	1	2 1
# 188	2	431.8	1	2
# 194	1	431.8	1	1
# 195	1	431.8	1	1
# 198	1	431.8	1	1
# 199	11	431.8	1	11
# 206	3	431.8	1	3
# 208	4	431.8	1	4
# 209	1	431.8	1	0 1
# 211	1	431.8	1	1
# 212	3	431.8	1	3
# 214	1	431.8	1	1
# 223	1	431.8	1	1
# 227	1	431.8	1	1
# 234	2	431.8	1	2
# 249	3	431.8	1	3
# 250	17425	431.8	1	17425
#
#
# === First read: Adapter A1031_ATATTG ===
#
# Sequence: ATATTG; Type: regular 3'; Length: 6; Trimmed: 8792 times
#
# No. of allowed errors:
# 1-5 bp: 0; 6 bp: 1
#
# Bases preceding removed adapters:
#   A: 1.1%
#   C: 1.3%
#   G: 3.2%
#   T: 0.8%
#   none/other: 93.6%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 10	71	431.8	1	71
# 11	17	431.8	1	17
# 12	12	431.8	1	12
# 22	2	431.8	1	2
# 38	1	431.8	1	1
# 52	34	431.8	1	34
# 53	28	431.8	1	28
# 54	108	431.8	1	108
# 55	26	431.8	1	26
# 65	70	431.8	1	70
# 66	1	431.8	1	1
# 68	1	431.8	1	1
# 72	10	431.8	1	10
# 73	1	431.8	1	1
# 74	2	431.8	1	2
# 76	2	431.8	1	2
# 78	2	431.8	1	2
# 79	3	431.8	1	3
# 82	2	431.8	1	2
# 83	1	431.8	1	1
# 84	3	431.8	1	3
# 88	1	431.8	1	1
# 90	4	431.8	1	4
# 91	1	431.8	1	1
# 94	3	431.8	1	3
# 96	1	431.8	1	1
# 99	1	431.8	1	1
# 109	3	431.8	1	3
# 110	2	431.8	1	2
# 113	2	431.8	1	2
# 117	1	431.8	1	1
# 118	2	431.8	1	2
# 119	3	431.8	1	3
# 120	5	431.8	1	5
# 121	4	431.8	1	4
# 122	19	431.8	1	19
# 123	3	431.8	1	3
# 124	1	431.8	1	1
# 129	11	431.8	1	11
# 130	2	431.8	1	2
# 132	26	431.8	1	26
# 133	2	431.8	1	2
# 134	2	431.8	1	2
# 135	2	431.8	1	2
# 138	1	431.8	1	1
# 139	1	431.8	1	1
# 145	1	431.8	1	1
# 146	3	431.8	1	3
# 149	1	431.8	1	1
# 155	2	431.8	1	2
# 159	2	431.8	1	2
# 162	1	431.8	1	1
# 165	3	431.8	1	3
# 168	1	431.8	1	1
# 170	1	431.8	1	1
# 172	1	431.8	1	1
# 176	2	431.8	1	2
# 190	2	431.8	1	2
# 197	7	431.8	1	7
# 198	3	431.8	1	1 2
# 200	1	431.8	1	1
# 201	1	431.8	1	1
# 204	1	431.8	1	1
# 209	3	431.8	1	3
# 221	22	431.8	1	22
# 225	1	431.8	1	1
# 226	2	431.8	1	2
# 227	1	431.8	1	1
# 233	1	431.8	1	1
# 240	1	431.8	1	1
# 249	1	431.8	1	1
# 250	8227	431.8	1	8227
#
#
# === First read: Adapter A1032_CAAGAG ===
#
# Sequence: CAAGAG; Type: regular 3'; Length: 6; Trimmed: 6464 times
#
# No. of allowed errors:
# 1-5 bp: 0; 6 bp: 1
#
# Bases preceding removed adapters:
#   A: 1.4%
#   C: 0.5%
#   G: 0.7%
#   T: 0.8%
#   none/other: 96.6%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 9	1	431.8	1	1
# 11	1	431.8	1	1
# 13	1	431.8	1	1
# 16	1	431.8	1	1
# 28	2	431.8	1	2
# 29	1	431.8	1	1
# 38	1	431.8	1	1
# 39	10	431.8	1	10
# 40	2	431.8	1	2
# 50	1	431.8	1	1
# 58	1	431.8	1	1
# 63	2	431.8	1	2
# 65	1	431.8	1	1
# 76	1	431.8	1	1
# 78	5	431.8	1	5
# 79	5	431.8	1	5
# 87	1	431.8	1	1
# 88	12	431.8	1	11 1
# 89	1	431.8	1	1
# 90	1	431.8	1	1
# 92	1	431.8	1	1
# 94	2	431.8	1	2
# 95	1	431.8	1	1
# 97	2	431.8	1	2
# 98	2	431.8	1	2
# 99	3	431.8	1	3
# 100	2	431.8	1	2
# 107	8	431.8	1	8
# 109	2	431.8	1	2
# 115	4	431.8	1	4
# 116	1	431.8	1	1
# 117	1	431.8	1	1
# 118	1	431.8	1	1
# 120	2	431.8	1	2
# 121	8	431.8	1	8
# 122	22	431.8	1	22
# 123	4	431.8	1	4
# 125	1	431.8	1	1
# 126	5	431.8	1	5
# 130	1	431.8	1	1
# 131	1	431.8	1	1
# 133	8	431.8	1	8
# 134	3	431.8	1	3
# 138	1	431.8	1	1
# 141	1	431.8	1	1
# 143	4	431.8	1	4
# 149	5	431.8	1	5
# 157	1	431.8	1	1
# 160	1	431.8	1	1
# 161	1	431.8	1	1
# 170	2	431.8	1	2
# 173	1	431.8	1	1
# 176	1	431.8	1	1
# 177	1	431.8	1	1
# 178	3	431.8	1	3
# 181	12	431.8	1	12
# 183	2	431.8	1	2
# 189	1	431.8	1	1
# 190	1	431.8	1	1
# 195	1	431.8	1	1
# 200	1	431.8	1	1
# 203	1	431.8	1	1
# 209	1	431.8	1	1
# 212	7	431.8	1	7
# 213	17	431.8	1	17
# 215	2	431.8	1	2
# 218	2	431.8	1	2
# 224	1	431.8	1	1
# 236	1	431.8	1	1
# 240	1	431.8	1	0 1
# 244	9	431.8	1	9
# 245	2	431.8	1	2
# 250	6244	431.8	1	6244
#
#
# === First read: Adapter A1033_CAATTC ===
#
# Sequence: CAATTC; Type: regular 3'; Length: 6; Trimmed: 15295 times
#
# No. of allowed errors:
# 1-5 bp: 0; 6 bp: 1
#
# Bases preceding removed adapters:
#   A: 0.3%
#   C: 0.6%
#   G: 0.2%
#   T: 0.2%
#   none/other: 98.8%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 8	1	431.8	1	1
# 11	3	431.8	1	3
# 22	1	431.8	1	1
# 25	1	431.8	1	1
# 26	1	431.8	1	1
# 28	1	431.8	1	1
# 32	1	431.8	1	1
# 33	1	431.8	1	1
# 34	1	431.8	1	1
# 38	4	431.8	1	4
# 42	1	431.8	1	0 1
# 48	1	431.8	1	1
# 51	1	431.8	1	1
# 52	1	431.8	1	1
# 64	1	431.8	1	1
# 71	8	431.8	1	8
# 72	1	431.8	1	1
# 78	2	431.8	1	2
# 80	1	431.8	1	1
# 85	2	431.8	1	2
# 88	4	431.8	1	4
# 90	1	431.8	1	1
# 91	2	431.8	1	2
# 95	2	431.8	1	2
# 97	2	431.8	1	2
# 98	1	431.8	1	1
# 104	1	431.8	1	1
# 110	1	431.8	1	1
# 113	1	431.8	1	1
# 117	1	431.8	1	1
# 121	1	431.8	1	1
# 122	1	431.8	1	1
# 124	2	431.8	1	2
# 125	1	431.8	1	1
# 127	1	431.8	1	1
# 132	1	431.8	1	1
# 135	7	431.8	1	7
# 136	6	431.8	1	6
# 137	1	431.8	1	1
# 142	1	431.8	1	1
# 145	2	431.8	1	2
# 147	2	431.8	1	2
# 149	3	431.8	1	2 1
# 152	1	431.8	1	1
# 156	2	431.8	1	2
# 160	1	431.8	1	0 1
# 161	5	431.8	1	5
# 164	1	431.8	1	1
# 166	2	431.8	1	2
# 171	1	431.8	1	1
# 173	4	431.8	1	4
# 178	1	431.8	1	1
# 180	1	431.8	1	1
# 184	1	431.8	1	1
# 189	1	431.8	1	1
# 190	6	431.8	1	6
# 192	5	431.8	1	5
# 194	1	431.8	1	1
# 195	1	431.8	1	1
# 196	1	431.8	1	1
# 199	1	431.8	1	1
# 201	2	431.8	1	2
# 211	2	431.8	1	2
# 219	1	431.8	1	1
# 220	2	431.8	1	2
# 222	3	431.8	1	3
# 223	2	431.8	1	2
# 224	1	431.8	1	1
# 237	3	431.8	1	3
# 238	1	431.8	1	1
# 244	2	431.8	1	2
# 245	1	431.8	1	1
# 249	53	431.8	1	53
# 250	15107	431.8	1	15107
#
#
# === First read: Adapter A1034_CAGGCC ===
#
# Sequence: CAGGCC; Type: regular 3'; Length: 6; Trimmed: 13156 times
#
# No. of allowed errors:
# 1-5 bp: 0; 6 bp: 1
#
# Bases preceding removed adapters:
#   A: 0.1%
#   C: 0.6%
#   G: 0.2%
#   T: 0.1%
#   none/other: 99.0%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 14	1	431.8	1	1
# 18	43	431.8	1	43
# 19	3	431.8	1	3
# 20	2	431.8	1	2
# 21	1	431.8	1	1
# 30	1	431.8	1	1
# 31	2	431.8	1	2
# 32	1	431.8	1	1
# 40	1	431.8	1	1
# 41	1	431.8	1	1
# 45	2	431.8	1	2
# 62	1	431.8	1	1
# 63	1	431.8	1	1
# 66	1	431.8	1	1
# 71	1	431.8	1	1
# 83	1	431.8	1	1
# 89	1	431.8	1	1
# 92	2	431.8	1	2
# 111	1	431.8	1	0 1
# 116	1	431.8	1	1
# 119	1	431.8	1	1
# 127	1	431.8	1	1
# 130	1	431.8	1	1
# 133	1	431.8	1	1
# 144	1	431.8	1	1
# 150	1	431.8	1	1
# 151	2	431.8	1	2
# 160	1	431.8	1	1
# 166	1	431.8	1	1
# 173	2	431.8	1	2
# 175	1	431.8	1	1
# 176	6	431.8	1	6
# 177	1	431.8	1	1
# 183	1	431.8	1	0 1
# 184	1	431.8	1	1
# 185	3	431.8	1	3
# 187	2	431.8	1	2
# 191	4	431.8	1	4
# 193	1	431.8	1	1
# 195	1	431.8	1	1
# 202	4	431.8	1	4
# 205	1	431.8	1	1
# 210	1	431.8	1	1
# 213	1	431.8	1	1
# 219	3	431.8	1	3
# 220	1	431.8	1	1
# 225	1	431.8	1	1
# 236	12	431.8	1	6 6
# 244	1	431.8	1	0 1
# 249	1	431.8	1	1
# 250	13029	431.8	1	13029
#
#
# === First read: Adapter A1035_CCAACG ===
#
# Sequence: CCAACG; Type: regular 3'; Length: 6; Trimmed: 164 times
#
# No. of allowed errors:
# 1-5 bp: 0; 6 bp: 1
#
# Bases preceding removed adapters:
#   A: 6.1%
#   C: 4.9%
#   G: 26.8%
#   T: 3.7%
#   none/other: 58.5%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 11	1	431.8	1	1
# 23	1	431.8	1	1
# 38	1	431.8	1	1
# 51	1	431.8	1	1
# 60	1	431.8	1	1
# 78	1	431.8	1	1
# 89	1	431.8	1	1
# 90	1	431.8	1	1
# 122	1	431.8	1	1
# 124	1	431.8	1	1
# 130	2	431.8	1	2
# 132	1	431.8	1	1
# 134	1	431.8	1	1
# 137	1	431.8	1	1
# 139	1	431.8	1	1
# 146	1	431.8	1	1
# 147	35	431.8	1	35
# 149	1	431.8	1	1
# 152	1	431.8	1	1
# 163	3	431.8	1	3
# 172	1	431.8	1	1
# 175	1	431.8	1	1
# 176	2	431.8	1	0 2
# 188	1	431.8	1	1
# 213	1	431.8	1	1
# 215	1	431.8	1	1
# 224	2	431.8	1	2
# 246	2	431.8	1	2
# 250	96	431.8	1	96
#
#
# === First read: Adapter A1036_GTTCCG ===
#
# Sequence: GTTCCG; Type: regular 3'; Length: 6; Trimmed: 12710 times
#
# No. of allowed errors:
# 1-5 bp: 0; 6 bp: 1
#
# Bases preceding removed adapters:
#   A: 0.2%
#   C: 0.1%
#   G: 0.3%
#   T: 0.5%
#   none/other: 98.9%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 9	1	431.8	1	1
# 10	1	431.8	1	1
# 29	1	431.8	1	1
# 39	1	431.8	1	1
# 40	1	431.8	1	1
# 41	1	431.8	1	1
# 44	1	431.8	1	1
# 53	1	431.8	1	1
# 57	1	431.8	1	1
# 69	3	431.8	1	3
# 70	1	431.8	1	1
# 73	1	431.8	1	1
# 77	1	431.8	1	1
# 81	7	431.8	1	7
# 82	2	431.8	1	2
# 90	2	431.8	1	2
# 96	1	431.8	1	1
# 99	1	431.8	1	1
# 100	1	431.8	1	1
# 102	3	431.8	1	3
# 115	2	431.8	1	2
# 117	8	431.8	1	8
# 122	1	431.8	1	1
# 123	1	431.8	1	1
# 124	1	431.8	1	1
# 128	3	431.8	1	3
# 132	1	431.8	1	1
# 133	1	431.8	1	1
# 138	1	431.8	1	1
# 140	66	431.8	1	66
# 142	1	431.8	1	1
# 143	4	431.8	1	4
# 145	1	431.8	1	1
# 148	1	431.8	1	1
# 150	1	431.8	1	1
# 151	1	431.8	1	1
# 155	4	431.8	1	4
# 156	1	431.8	1	1
# 159	1	431.8	1	1
# 180	1	431.8	1	1
# 187	1	431.8	1	1
# 188	2	431.8	1	2
# 194	2	431.8	1	2
# 199	5	431.8	1	5
# 204	2	431.8	1	2
# 224	1	431.8	1	1
# 250	12564	431.8	1	12564
#
#
# === First read: Adapter A1037_TACGGT ===
#
# Sequence: TACGGT; Type: regular 3'; Length: 6; Trimmed: 10202 times
#
# No. of allowed errors:
# 1-5 bp: 0; 6 bp: 1
#
# Bases preceding removed adapters:
#   A: 0.1%
#   C: 0.0%
#   G: 2.0%
#   T: 0.2%
#   none/other: 97.7%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 12	1	431.8	1	1
# 21	1	431.8	1	1
# 32	1	431.8	1	1
# 40	1	431.8	1	1
# 65	2	431.8	1	2
# 69	1	431.8	1	1
# 85	1	431.8	1	1
# 101	42	431.8	1	42
# 102	142	431.8	1	142
# 103	3	431.8	1	3
# 104	1	431.8	1	1
# 111	1	431.8	1	1
# 117	1	431.8	1	1
# 118	2	431.8	1	2
# 130	2	431.8	1	2
# 131	10	431.8	1	10
# 134	1	431.8	1	1
# 136	1	431.8	1	1
# 138	3	431.8	1	3
# 139	2	431.8	1	2
# 147	1	431.8	1	1
# 151	3	431.8	1	3
# 158	1	431.8	1	1
# 160	1	431.8	1	1
# 174	1	431.8	1	1
# 185	1	431.8	1	1
# 186	1	431.8	1	1
# 198	1	431.8	1	1
# 223	1	431.8	1	1
# 224	2	431.8	1	2
# 246	1	431.8	1	1
# 249	1	431.8	1	1
# 250	9968	431.8	1	9968
#
#
# === First read: Adapter A1038_TACTTG ===
#
# Sequence: TACTTG; Type: regular 3'; Length: 6; Trimmed: 9244 times
#
# No. of allowed errors:
# 1-5 bp: 0; 6 bp: 1
#
# Bases preceding removed adapters:
#   A: 0.2%
#   C: 0.1%
#   G: 0.1%
#   T: 0.2%
#   none/other: 99.4%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 9	1	431.8	1	1
# 21	2	431.8	1	2
# 35	3	431.8	1	3
# 43	1	431.8	1	1
# 65	1	431.8	1	1
# 68	1	431.8	1	1
# 70	1	431.8	1	1
# 89	3	431.8	1	3
# 91	2	431.8	1	2
# 94	1	431.8	1	1
# 100	1	431.8	1	1
# 106	1	431.8	1	1
# 109	6	431.8	1	6
# 110	4	431.8	1	4
# 117	4	431.8	1	4
# 123	3	431.8	1	3
# 125	1	431.8	1	1
# 129	2	431.8	1	2
# 131	1	431.8	1	1
# 134	1	431.8	1	1
# 145	1	431.8	1	1
# 147	1	431.8	1	1
# 159	1	431.8	1	1
# 196	2	431.8	1	2
# 200	1	431.8	1	1
# 203	1	431.8	1	1
# 210	2	431.8	1	2
# 212	1	431.8	1	1
# 226	1	431.8	1	1
# 240	2	431.8	1	2
# 250	9191	431.8	1	9191
#
#
# === First read: Adapter A1039_TATCTC ===
#
# Sequence: TATCTC; Type: regular 3'; Length: 6; Trimmed: 3836 times
#
# No. of allowed errors:
# 1-5 bp: 0; 6 bp: 1
#
# Bases preceding removed adapters:
#   A: 0.5%
#   C: 0.2%
#   G: 0.2%
#   T: 0.2%
#   none/other: 99.0%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 8	1	431.8	1	1
# 21	1	431.8	1	1
# 22	1	431.8	1	1
# 24	1	431.8	1	1
# 25	1	431.8	1	1
# 31	2	431.8	1	2
# 38	2	431.8	1	2
# 41	1	431.8	1	1
# 44	1	431.8	1	1
# 67	1	431.8	1	1
# 72	1	431.8	1	1
# 73	1	431.8	1	1
# 80	1	431.8	1	1
# 89	1	431.8	1	1
# 91	1	431.8	1	1
# 100	1	431.8	1	1
# 102	1	431.8	1	1
# 103	1	431.8	1	1
# 110	2	431.8	1	2
# 112	2	431.8	1	2
# 125	1	431.8	1	1
# 144	1	431.8	1	0 1
# 146	1	431.8	1	1
# 148	3	431.8	1	3
# 150	1	431.8	1	0 1
# 157	1	431.8	1	1
# 164	1	431.8	1	1
# 179	1	431.8	1	1
# 213	2	431.8	1	2
# 219	1	431.8	1	1
# 249	1	431.8	1	1
# 250	3798	431.8	1	3798
#
#
# === First read: Adapter A1040_TCATAA ===
#
# Sequence: TCATAA; Type: regular 3'; Length: 6; Trimmed: 6619 times
#
# No. of allowed errors:
# 1-5 bp: 0; 6 bp: 1
#
# Bases preceding removed adapters:
#   A: 1.2%
#   C: 0.8%
#   G: 0.3%
#   T: 0.6%
#   none/other: 97.2%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 7	1	431.8	1	1
# 8	1	431.8	1	1
# 11	1	431.8	1	1
# 13	1	431.8	1	1
# 15	1	431.8	1	1
# 16	3	431.8	1	3
# 20	3	431.8	1	3
# 21	2	431.8	1	2
# 23	1	431.8	1	1
# 24	1	431.8	1	1
# 27	1	431.8	1	1
# 29	2	431.8	1	2
# 38	1	431.8	1	1
# 40	1	431.8	1	1
# 41	1	431.8	1	1
# 45	1	431.8	1	1
# 47	3	431.8	1	3
# 54	1	431.8	1	1
# 56	1	431.8	1	1
# 57	1	431.8	1	1
# 60	3	431.8	1	3
# 61	1	431.8	1	1
# 62	1	431.8	1	1
# 63	1	431.8	1	1
# 68	2	431.8	1	2
# 69	2	431.8	1	2
# 70	1	431.8	1	1
# 72	2	431.8	1	2
# 78	1	431.8	1	1
# 80	1	431.8	1	1
# 89	1	431.8	1	1
# 91	1	431.8	1	1
# 96	3	431.8	1	3
# 99	1	431.8	1	1
# 100	2	431.8	1	2
# 101	1	431.8	1	1
# 102	1	431.8	1	1
# 105	1	431.8	1	1
# 108	2	431.8	1	2
# 112	5	431.8	1	5
# 123	1	431.8	1	1
# 125	1	431.8	1	1
# 126	1	431.8	1	1
# 128	1	431.8	1	1
# 129	1	431.8	1	0 1
# 130	1	431.8	1	1
# 131	1	431.8	1	1
# 132	2	431.8	1	1 1
# 134	27	431.8	1	27
# 135	1	431.8	1	1
# 136	1	431.8	1	1
# 141	1	431.8	1	1
# 142	1	431.8	1	1
# 150	1	431.8	1	1
# 155	3	431.8	1	3
# 156	1	431.8	1	1
# 158	2	431.8	1	1 1
# 160	2	431.8	1	2
# 161	2	431.8	1	2
# 162	3	431.8	1	2 1
# 167	3	431.8	1	3
# 169	4	431.8	1	4
# 170	2	431.8	1	2
# 171	2	431.8	1	2
# 174	1	431.8	1	1
# 176	1	431.8	1	1
# 177	1	431.8	1	1
# 180	7	431.8	1	7
# 181	1	431.8	1	1
# 184	1	431.8	1	1
# 185	1	431.8	1	1
# 186	3	431.8	1	3
# 189	1	431.8	1	1
# 192	1	431.8	1	1
# 193	1	431.8	1	1
# 196	1	431.8	1	1
# 198	1	431.8	1	1
# 201	1	431.8	1	1
# 204	10	431.8	1	10
# 211	1	431.8	1	1
# 214	3	431.8	1	3
# 216	1	431.8	1	1
# 219	2	431.8	1	2
# 223	3	431.8	1	3
# 225	1	431.8	1	1
# 226	2	431.8	1	2
# 227	1	431.8	1	1
# 229	2	431.8	1	2
# 237	4	431.8	1	4
# 240	4	431.8	1	4
# 241	1	431.8	1	1
# 245	1	431.8	1	1
# 246	1	431.8	1	1
# 248	1	431.8	1	1
# 250	6433	431.8	1	6433
#
#
# === First read: Adapter A1041_TCCGAG ===
#
# Sequence: TCCGAG; Type: regular 3'; Length: 6; Trimmed: 7307 times
#
# No. of allowed errors:
# 1-5 bp: 0; 6 bp: 1
#
# Bases preceding removed adapters:
#   A: 0.1%
#   C: 0.1%
#   G: 0.2%
#   T: 0.1%
#   none/other: 99.6%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 20	1	431.8	1	1
# 40	1	431.8	1	1
# 81	2	431.8	1	2
# 86	1	431.8	1	1
# 90	14	431.8	1	14
# 109	1	431.8	1	1
# 118	1	431.8	1	1
# 119	1	431.8	1	1
# 138	2	431.8	1	2
# 147	1	431.8	1	1
# 164	1	431.8	1	1
# 209	1	431.8	1	1
# 214	1	431.8	1	1
# 215	4	431.8	1	4
# 250	7275	431.8	1	7275
#
#
# WARNING:
#     One or more of your adapter sequences may be incomplete.
#     Please see the detailed output above.

# %%
conda install -y -c bioconda sabre
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/meco/anaconda3/envs/qiime2-2021.2
#
#   added / updated specs:
#     - sabre
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2021.5.30          |   py36h06a4308_0         139 KB
#     sabre-1.000                |       h5bf99c6_2          18 KB  bioconda
#     ------------------------------------------------------------
#                                            Total:         157 KB
#
# The following NEW packages will be INSTALLED:
#
#   sabre              bioconda/linux-64::sabre-1.000-h5bf99c6_2
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            conda-forge::certifi-2021.5.30-py36h5~ --> pkgs/main::certifi-2021.5.30-py36h06a4308_0
#
#
#
# Downloading and Extracting Packages
# sabre-1.000          | 18 KB     | ##################################### | 100%
# certifi-2021.5.30    | 139 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

met = pd.read_csv('metadata.tsv', sep='\t', index_col='#SampleID', \
                  usecols=['#SampleID','BarcodeSequence','Run_index'])
for ri in set(met.Run_index):
  if ri != 'r2_i4': continue
  subdir = 'Data/Demux_'+ri
  # !mkdir -p $subdir
  meta = met.loc[met.Run_index == ri].copy()
  meta['r1'] = meta.index +'_'+ meta.BarcodeSequence +'_L001_R1_001.fq'
  meta['r2'] = meta.index +'_'+ meta.BarcodeSequence +'_L001_R2_001.fq'
  meta.set_index('BarcodeSequence', inplace=True)
  meta.drop('Run_index',axis=1,inplace=True)
  meta.to_csv('Data/bc_%s.txt'%ri, sep='\t',header=False)
  bc = 'Data/bc_%s.txt'%ri
  f = 'raw_data/LH_diet_2_%s/forward.fastq.gz'%ri
  r = 'raw_data/LH_diet_2_%s/reverse.fastq.gz'%ri
  # !sabre pe -m 0 -f $f -r $r -b $bc -u no_bc_match_R1.fq -w no_bc_match_R2.fq
  # !rm $bc
  # !mv *.fq $subdir
  # !gzip $subdir/*.fq
# Out:
# Total FastQ records: 3537464 (1768732 pairs)
#
# FastQ records for barcode TCCGAG: 72792 (36396 pairs)
# FastQ records for barcode TCATAA: 67914 (33957 pairs)
# FastQ records for barcode TATCTC: 50570 (25285 pairs)
# FastQ records for barcode TACTTG: 71280 (35640 pairs)
# FastQ records for barcode TACGGT: 73836 (36918 pairs)
# FastQ records for barcode GTTCCG: 92262 (46131 pairs)
# FastQ records for barcode CCAACG: 99412 (49706 pairs)
# FastQ records for barcode CAGGCC: 89064 (44532 pairs)
# FastQ records for barcode CAATTC: 107932 (53966 pairs)
# FastQ records for barcode CAAGAG: 53646 (26823 pairs)
# FastQ records for barcode ATATTG: 67726 (33863 pairs)
# FastQ records for barcode ATAGAC: 106478 (53239 pairs)
# FastQ records for barcode ATAACT: 108588 (54294 pairs)
# FastQ records for barcode AGTTGG: 116088 (58044 pairs)
# FastQ records for barcode AACTGC: 103570 (51785 pairs)
# FastQ records for barcode AACGCA: 100600 (50300 pairs)
# FastQ records for barcode GGTTAT: 79944 (39972 pairs)
# FastQ records for barcode GCTCCA: 73490 (36745 pairs)
# FastQ records for barcode CGCATA: 77888 (38944 pairs)
# FastQ records for barcode CGAGAG: 86072 (43036 pairs)
# FastQ records for barcode CCTAAC: 74502 (37251 pairs)
# FastQ records for barcode CAGTAA: 79532 (39766 pairs)
# FastQ records for barcode CAACTT: 91864 (45932 pairs)
# FastQ records for barcode AGTCTC: 94364 (47182 pairs)
# FastQ records for barcode ACGTTG: 91700 (45850 pairs)
# FastQ records for barcode AATGGA: 84888 (42444 pairs)
# FastQ records for barcode AAGACC: 91122 (45561 pairs)
# FastQ records for barcode AACCAG: 131732 (65866 pairs)
# FastQ records for barcode AAGTCG: 76218 (38109 pairs)
# FastQ records for barcode AAGTAA: 79718 (39859 pairs)
# FastQ records for barcode AAGGCA: 85988 (42994 pairs)
# FastQ records for barcode AAGGAT: 83730 (41865 pairs)
# FastQ records for barcode AAGCTA: 39558 (19779 pairs)
# FastQ records for barcode AAGCGG: 74536 (37268 pairs)
# FastQ records for barcode TCTGAC: 79284 (39642 pairs)
# FastQ records for barcode TCGCAT: 73978 (36989 pairs)
# FastQ records for barcode GTACGT: 55898 (27949 pairs)
# FastQ records for barcode GTAATC: 51938 (25969 pairs)
# FastQ records for barcode GGTACC: 51866 (25933 pairs)
# FastQ records for barcode GGCTTC: 49968 (24984 pairs)
# FastQ records for barcode GGCCAA: 58036 (29018 pairs)
# FastQ records for barcode GCTCAT: 56930 (28465 pairs)
# FastQ records for barcode GCGACT: 60576 (30288 pairs)
# FastQ records for barcode GCCAGC: 56722 (28361 pairs)
#
# FastQ records with no barcode match: 63664 (31832 pairs)
#
# Number of mismatches allowed: 0

# %%
conda install -y -c bioconda gbsx
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/meco-guest/anaconda3/envs/qiime2-2021.2
#
#   added / updated specs:
#     - gbsx
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     gbsx-1.3                   |       hdfd78af_1          89 KB  bioconda
#     ------------------------------------------------------------
#                                            Total:          89 KB
#
# The following NEW packages will be INSTALLED:
#
#   gbsx               bioconda/noarch::gbsx-1.3-hdfd78af_1
#
#
#
# Downloading and Extracting Packages
# gbsx-1.3             | 89 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

met = pd.read_csv('metadata.tsv', sep='\t', index_col='#SampleID', \
                  usecols=['#SampleID','BarcodeSequence','Run_index'])
for ri in set(met.Run_index):
  if ri != 'r2_i4': continue
  subdir = 'Data/Demux_'+ri
  # !mkdir -p $subdir
  meta = met.loc[met.Run_index == ri].copy()
  #meta['r1'] = meta.index +'_'+ meta.BarcodeSequence +'_L001_R1_001.fq'
  #meta['r2'] = meta.index +'_'+ meta.BarcodeSequence +'_L001_R2_001.fq'
  #meta.set_index('BarcodeSequence', inplace=True)
  meta.drop('Run_index',axis=1,inplace=True)
  meta['Enzyme'] = 'NAN'
  meta.to_csv('Data/bc_%s.txt'%ri, sep='\t',header=False)
  bc = 'Data/bc_%s.txt'%ri
  f = 'raw_data/LH_diet_2_%s/forward.fastq.gz'%ri
  r = 'raw_data/LH_diet_2_%s/reverse.fastq.gz'%ri
  # !gbsx --Demultiplexer -f1 $f -f2 $r -i $bc -o $subdir -mb 1 -s 20 -t 6 -gzip true -rad true 
  # !rm $bc
# Out:
# Start the demultiplexing.
# USE DUAL BARCODING: false
# 100000 reads demultiplexed
# 200000 reads demultiplexed
# 300000 reads demultiplexed
# 400000 reads demultiplexed
# 500000 reads demultiplexed
# 600000 reads demultiplexed
# 700000 reads demultiplexed
# 800000 reads demultiplexed
# 900000 reads demultiplexed
# 1000000 reads demultiplexed
# 1100000 reads demultiplexed
# 1200000 reads demultiplexed
# 1300000 reads demultiplexed
# 1400000 reads demultiplexed
# 1500000 reads demultiplexed
# 1600000 reads demultiplexed
# 1700000 reads demultiplexed
# 1768732 reads demultiplexed
# Demultiplexing ended.

# %%
import pandas as pd
import os

met = pd.read_csv('metadata.tsv', sep='\t', index_col='#SampleID')
for ri in set(met.Run_index):
  #if ri != 'r2_i4': continue
  subdir = 'Data/Demux_'+ri
  for f in os.listdir(subdir):
    if f[0] == 'B':
      # !mkdir -p rstc_2019_bac/Data/Demux/$ri
      # !mv $subdir/$f rstc_2019_bac/Data/Demux/$ri
    if f[0] == 'A':
      # !mkdir -p rstc_2019_arc/Data/Demux/$ri
      # !mv $subdir/$f rstc_2019_arc/Data/Demux/$ri

# %%
# !cutadapt -a CAACTT -o out.1.fastq -p out.2.fastq \
raw_data/LH_diet_2_r2_i4/forward.fastq.gz raw_data/LH_diet_2_r2_i4/reverse.fastq.gz \
--pair-filter=any --discard-untrimmed
# Out:
# This is cutadapt 3.1 with Python 3.6.12
# Command line parameters: -a CAACTT -A CAACTT -o out.1.fastq -p out.2.fastq raw_data/LH_diet_2_r2_i4/forward.fastq.gz raw_data/LH_diet_2_r2_i4/reverse.fastq.gz --pair-filter=any --discard-untrimmed
# Processing reads on 1 core in paired-end mode ...
# [---------->8] 00:00:23     1,768,732 reads  @     13.5 µs/read;   4.46 M reads/minute
# Finished in 23.80 s (13 us/read; 4.46 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:          1,768,732
#   Read 1 with adapter:                 125,689 (7.1%)
#   Read 2 with adapter:                  18,970 (1.1%)
# Pairs written (passing filters):           838 (0.0%)
#
# Total basepairs processed:   884,366,000 bp
#   Read 1:   442,183,000 bp
#   Read 2:   442,183,000 bp
# Total written (filtered):        200,261 bp (0.0%)
#   Read 1:        45,879 bp
#   Read 2:       154,382 bp
#
# === First read: Adapter 1 ===
#
# Sequence: CAACTT; Type: regular 3'; Length: 6; Trimmed: 125689 times
#
# No. of allowed errors:
# 1-6 bp: 0
#
# Bases preceding removed adapters:
#   A: 4.2%
#   C: 0.8%
#   G: 2.4%
#   T: 56.1%
#   none/other: 36.5%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	1595	27636.4	0	1595
# 4	30	6909.1	0	30
# 5	41	1727.3	0	41
# 6	1	431.8	0	1
# 7	1	431.8	0	1
# 8	10	431.8	0	10
# 9	1	431.8	0	1
# 10	2	431.8	0	2
# 11	211	431.8	0	211
# 12	10433	431.8	0	10433
# 13	57708	431.8	0	57708
# 14	795	431.8	0	795
# 15	43	431.8	0	43
# 16	14	431.8	0	14
# 17	129	431.8	0	129
# 18	13	431.8	0	13
# 19	4	431.8	0	4
# 20	1	431.8	0	1
# 21	1	431.8	0	1
# 22	8	431.8	0	8
# 23	1	431.8	0	1
# 24	3	431.8	0	3
# 25	2	431.8	0	2
# 26	8	431.8	0	8
# 27	6	431.8	0	6
# 29	2	431.8	0	2
# 31	21	431.8	0	21
# 32	5	431.8	0	5
# 33	1	431.8	0	1
# 34	2	431.8	0	2
# 35	1	431.8	0	1
# 36	4	431.8	0	4
# 37	2	431.8	0	2
# 38	9	431.8	0	9
# 39	15	431.8	0	15
# 40	7	431.8	0	7
# 41	4	431.8	0	4
# 42	3	431.8	0	3
# 43	4	431.8	0	4
# 44	4	431.8	0	4
# 45	1	431.8	0	1
# 46	4	431.8	0	4
# 48	1	431.8	0	1
# 49	2	431.8	0	2
# 50	1	431.8	0	1
# 51	7	431.8	0	7
# 52	8	431.8	0	8
# 53	2	431.8	0	2
# 54	2	431.8	0	2
# 55	2	431.8	0	2
# 56	23	431.8	0	23
# 57	3	431.8	0	3
# 58	1	431.8	0	1
# 59	1	431.8	0	1
# 60	3	431.8	0	3
# 61	1	431.8	0	1
# 62	1	431.8	0	1
# 63	3	431.8	0	3
# 64	118	431.8	0	118
# 65	6	431.8	0	6
# 66	304	431.8	0	304
# 67	9	431.8	0	9
# 68	11	431.8	0	11
# 69	3	431.8	0	3
# 70	243	431.8	0	243
# 71	8	431.8	0	8
# 72	1	431.8	0	1
# 73	7	431.8	0	7
# 74	5	431.8	0	5
# 75	1	431.8	0	1
# 76	3	431.8	0	3
# 77	3	431.8	0	3
# 78	40	431.8	0	40
# 79	8	431.8	0	8
# 80	4	431.8	0	4
# 81	1	431.8	0	1
# 82	586	431.8	0	586
# 83	10	431.8	0	10
# 84	6	431.8	0	6
# 85	24	431.8	0	24
# 86	5	431.8	0	5
# 88	79	431.8	0	79
# 89	58	431.8	0	58
# 90	7	431.8	0	7
# 91	3	431.8	0	3
# 92	8	431.8	0	8
# 93	1	431.8	0	1
# 94	1	431.8	0	1
# 95	44	431.8	0	44
# 96	1	431.8	0	1
# 97	4	431.8	0	4
# 98	7	431.8	0	7
# 99	13	431.8	0	13
# 100	6	431.8	0	6
# 101	2	431.8	0	2
# 102	6	431.8	0	6
# 103	3	431.8	0	3
# 104	7	431.8	0	7
# 105	2	431.8	0	2
# 106	2336	431.8	0	2336
# 107	48	431.8	0	48
# 108	9	431.8	0	9
# 109	5	431.8	0	5
# 110	9	431.8	0	9
# 111	26	431.8	0	26
# 112	5	431.8	0	5
# 113	1	431.8	0	1
# 114	1	431.8	0	1
# 116	2	431.8	0	2
# 117	46	431.8	0	46
# 118	4	431.8	0	4
# 119	10	431.8	0	10
# 120	1	431.8	0	1
# 121	37	431.8	0	37
# 122	26	431.8	0	26
# 123	1419	431.8	0	1419
# 124	24	431.8	0	24
# 125	448	431.8	0	448
# 126	10	431.8	0	10
# 127	11	431.8	0	11
# 128	7	431.8	0	7
# 129	82	431.8	0	82
# 130	20	431.8	0	20
# 131	50	431.8	0	50
# 132	6	431.8	0	6
# 133	35	431.8	0	35
# 134	5	431.8	0	5
# 135	4	431.8	0	4
# 136	14	431.8	0	14
# 137	22	431.8	0	22
# 138	1022	431.8	0	1022
# 139	34	431.8	0	34
# 140	2	431.8	0	2
# 141	1	431.8	0	1
# 142	4	431.8	0	4
# 143	4	431.8	0	4
# 144	1	431.8	0	1
# 145	6	431.8	0	6
# 146	4	431.8	0	4
# 148	4	431.8	0	4
# 149	285	431.8	0	285
# 150	12	431.8	0	12
# 151	3	431.8	0	3
# 152	13	431.8	0	13
# 153	8	431.8	0	8
# 154	6	431.8	0	6
# 155	2	431.8	0	2
# 156	1	431.8	0	1
# 157	2	431.8	0	2
# 158	6	431.8	0	6
# 159	109	431.8	0	109
# 160	2	431.8	0	2
# 161	2	431.8	0	2
# 162	21	431.8	0	21
# 163	5	431.8	0	5
# 164	10	431.8	0	10
# 165	3	431.8	0	3
# 166	7	431.8	0	7
# 167	2	431.8	0	2
# 169	3	431.8	0	3
# 170	1	431.8	0	1
# 171	5	431.8	0	5
# 172	2	431.8	0	2
# 173	6	431.8	0	6
# 174	9	431.8	0	9
# 175	1	431.8	0	1
# 177	2	431.8	0	2
# 178	312	431.8	0	312
# 179	6	431.8	0	6
# 180	1	431.8	0	1
# 181	1	431.8	0	1
# 182	4	431.8	0	4
# 183	1	431.8	0	1
# 184	9	431.8	0	9
# 185	5	431.8	0	5
# 186	4	431.8	0	4
# 187	2	431.8	0	2
# 189	1	431.8	0	1
# 190	13	431.8	0	13
# 191	5	431.8	0	5
# 192	2	431.8	0	2
# 193	1	431.8	0	1
# 194	3	431.8	0	3
# 195	1	431.8	0	1
# 196	1	431.8	0	1
# 198	3	431.8	0	3
# 199	2	431.8	0	2
# 200	1	431.8	0	1
# 201	5	431.8	0	5
# 203	2	431.8	0	2
# 204	2	431.8	0	2
# 205	1	431.8	0	1
# 206	2	431.8	0	2
# 207	1	431.8	0	1
# 208	1	431.8	0	1
# 209	47	431.8	0	47
# 210	4	431.8	0	4
# 211	6	431.8	0	6
# 212	4	431.8	0	4
# 213	1	431.8	0	1
# 214	1	431.8	0	1
# 215	1	431.8	0	1
# 216	3	431.8	0	3
# 217	14	431.8	0	14
# 220	5	431.8	0	5
# 221	3	431.8	0	3
# 224	5	431.8	0	5
# 225	3	431.8	0	3
# 226	1	431.8	0	1
# 227	30	431.8	0	30
# 228	1	431.8	0	1
# 229	2	431.8	0	2
# 232	2	431.8	0	2
# 235	1	431.8	0	1
# 239	1	431.8	0	1
# 241	1	431.8	0	1
# 242	1	431.8	0	1
# 244	4	431.8	0	4
# 245	18	431.8	0	18
# 248	1	431.8	0	1
# 249	3	431.8	0	3
# 250	45932	431.8	0	45932
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CAACTT; Type: regular 3'; Length: 6; Trimmed: 18970 times
#
# No. of allowed errors:
# 1-6 bp: 0
#
# Bases preceding removed adapters:
#   A: 20.6%
#   C: 63.5%
#   G: 3.4%
#   T: 12.5%
#   none/other: 0.0%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	1487	27636.4	0	1487
# 4	315	6909.1	0	315
# 5	65	1727.3	0	65
# 8	9	431.8	0	9
# 9	5	431.8	0	5
# 10	3	431.8	0	3
# 11	7	431.8	0	7
# 12	6	431.8	0	6
# 13	6	431.8	0	6
# 15	2	431.8	0	2
# 16	5	431.8	0	5
# 17	3	431.8	0	3
# 19	4	431.8	0	4
# 21	7	431.8	0	7
# 22	4	431.8	0	4
# 23	4	431.8	0	4
# 24	8	431.8	0	8
# 25	11	431.8	0	11
# 26	2	431.8	0	2
# 27	23	431.8	0	23
# 28	10	431.8	0	10
# 29	3	431.8	0	3
# 30	3	431.8	0	3
# 31	9	431.8	0	9
# 32	33	431.8	0	33
# 33	108	431.8	0	108
# 34	5	431.8	0	5
# 35	2	431.8	0	2
# 36	1	431.8	0	1
# 37	9	431.8	0	9
# 38	13	431.8	0	13
# 39	2	431.8	0	2
# 40	5	431.8	0	5
# 41	2	431.8	0	2
# 42	1	431.8	0	1
# 43	134	431.8	0	134
# 44	7500	431.8	0	7500
# 45	342	431.8	0	342
# 46	5	431.8	0	5
# 47	6	431.8	0	6
# 48	37	431.8	0	37
# 49	5	431.8	0	5
# 50	39	431.8	0	39
# 51	13	431.8	0	13
# 52	24	431.8	0	24
# 53	9	431.8	0	9
# 54	7	431.8	0	7
# 55	11	431.8	0	11
# 56	2188	431.8	0	2188
# 57	43	431.8	0	43
# 58	155	431.8	0	155
# 59	7	431.8	0	7
# 60	6	431.8	0	6
# 61	581	431.8	0	581
# 62	9	431.8	0	9
# 63	2	431.8	0	2
# 64	7	431.8	0	7
# 65	4	431.8	0	4
# 66	1	431.8	0	1
# 68	6	431.8	0	6
# 69	4	431.8	0	4
# 70	861	431.8	0	861
# 71	14	431.8	0	14
# 72	16	431.8	0	16
# 73	2	431.8	0	2
# 74	11	431.8	0	11
# 75	25	431.8	0	25
# 76	2	431.8	0	2
# 77	77	431.8	0	77
# 78	12	431.8	0	12
# 79	15	431.8	0	15
# 80	1	431.8	0	1
# 81	1	431.8	0	1
# 82	15	431.8	0	15
# 83	35	431.8	0	35
# 84	6	431.8	0	6
# 85	2	431.8	0	2
# 86	43	431.8	0	43
# 87	3	431.8	0	3
# 88	5	431.8	0	5
# 89	8	431.8	0	8
# 90	10	431.8	0	10
# 91	1	431.8	0	1
# 92	4	431.8	0	4
# 93	12	431.8	0	12
# 94	12	431.8	0	12
# 95	20	431.8	0	20
# 96	2	431.8	0	2
# 97	4	431.8	0	4
# 98	952	431.8	0	952
# 99	17	431.8	0	17
# 100	393	431.8	0	393
# 101	32	431.8	0	32
# 102	5	431.8	0	5
# 103	26	431.8	0	26
# 104	291	431.8	0	291
# 105	5	431.8	0	5
# 106	4	431.8	0	4
# 107	36	431.8	0	36
# 108	38	431.8	0	38
# 109	2	431.8	0	2
# 110	3	431.8	0	3
# 111	62	431.8	0	62
# 112	5	431.8	0	5
# 113	6	431.8	0	6
# 114	1552	431.8	0	1552
# 115	13	431.8	0	13
# 117	8	431.8	0	8
# 118	159	431.8	0	159
# 119	3	431.8	0	3
# 121	3	431.8	0	3
# 123	16	431.8	0	16
# 124	74	431.8	0	74
# 125	1	431.8	0	1
# 126	1	431.8	0	1
# 127	1	431.8	0	1
# 128	2	431.8	0	2
# 129	22	431.8	0	22
# 130	4	431.8	0	4
# 131	1	431.8	0	1
# 132	1	431.8	0	1
# 133	5	431.8	0	5
# 134	1	431.8	0	1
# 136	1	431.8	0	1
# 137	5	431.8	0	5
# 138	1	431.8	0	1
# 139	1	431.8	0	1
# 141	4	431.8	0	4
# 142	1	431.8	0	1
# 143	4	431.8	0	4
# 144	3	431.8	0	3
# 145	2	431.8	0	2
# 146	3	431.8	0	3
# 148	59	431.8	0	59
# 149	1	431.8	0	1
# 150	4	431.8	0	4
# 151	2	431.8	0	2
# 152	5	431.8	0	5
# 154	1	431.8	0	1
# 155	6	431.8	0	6
# 157	2	431.8	0	2
# 158	4	431.8	0	4
# 160	2	431.8	0	2
# 161	8	431.8	0	8
# 162	3	431.8	0	3
# 164	4	431.8	0	4
# 166	7	431.8	0	7
# 167	2	431.8	0	2
# 168	16	431.8	0	16
# 169	38	431.8	0	38
# 170	2	431.8	0	2
# 171	2	431.8	0	2
# 172	14	431.8	0	14
# 174	1	431.8	0	1
# 175	2	431.8	0	2
# 177	15	431.8	0	15
# 178	6	431.8	0	6
# 181	2	431.8	0	2
# 183	9	431.8	0	9
# 184	2	431.8	0	2
# 186	25	431.8	0	25
# 187	2	431.8	0	2
# 188	1	431.8	0	1
# 189	3	431.8	0	3
# 192	8	431.8	0	8
# 193	7	431.8	0	7
# 194	1	431.8	0	1
# 196	2	431.8	0	2
# 197	1	431.8	0	1
# 198	1	431.8	0	1
# 199	9	431.8	0	9
# 201	2	431.8	0	2
# 202	135	431.8	0	135
# 203	1	431.8	0	1
# 204	3	431.8	0	3
# 205	2	431.8	0	2
# 206	1	431.8	0	1
# 207	4	431.8	0	4
# 208	4	431.8	0	4
# 209	1	431.8	0	1
# 211	2	431.8	0	2
# 212	4	431.8	0	4
# 213	6	431.8	0	6
# 215	25	431.8	0	25
# 216	111	431.8	0	111
# 217	8	431.8	0	8
# 218	2	431.8	0	2
# 219	3	431.8	0	3
# 220	11	431.8	0	11
# 221	1	431.8	0	1
# 225	1	431.8	0	1
# 227	1	431.8	0	1
# 228	2	431.8	0	2
# 229	2	431.8	0	2
# 230	14	431.8	0	14
# 232	2	431.8	0	2
# 235	1	431.8	0	1
# 236	2	431.8	0	2
# 238	2	431.8	0	2
# 243	1	431.8	0	1
# 244	3	431.8	0	3
# 246	1	431.8	0	1
# 247	16	431.8	0	16
# 249	1	431.8	0	1
# 250	1	431.8	0	1

# %%
from Bio import SeqIO
from Bio.Seq import Seq
import gzip
file = gzip.open("raw_data/LH_diet_2_r2_i4/forward.fastq.gz","rt")
fq = SeqIO.parse(file, "fastq")
count = 0
for i,record in enumerate(fq):
  #if i> 100: break
  if 'CCAACG' in record.seq[:6]:
    count += 1
count
# Out:
# 49706

# %% [markdown]
# # Separate bacterial and archaea samples

# %%
import pandas as pd
import os

met = pd.read_csv('metadata.tsv', sep='\t', index_col='#SampleID')
for ri in set(met.Run_index):
  demux = 'Data/Demuliplexed/%s-demux.qza'%ri
  a = !unzip $demux
  digest = a[1].split('/')[0].replace('  inflating: ','')
  
  for f in os.listdir(digest+'/data'):
    if f[0] == 'B':
      # !mkdir -p rstc_2019_bac/Data/Demux/$ri
      # !mv $digest/data/$f rstc_2019_bac/Data/Demux/$ri
    if f[0] == 'A':
      # !mkdir -p rstc_2019_arc/Data/Demux/$ri
      # !mv $digest/data/$f rstc_2019_arc/Data/Demux/$ri
      
  # !rm -r $digest
# !rm Data # remove processed intermediate files to save some space

# %% [markdown]
# # Additional metadata manipulations

# %%
import pandas as pd

met = pd.read_csv('metadata.tsv', sep='\t', index_col='#SampleID')
met.drop(['Domain','Nr reads_0','Subsample'], axis=1, inplace=True)

met.to_csv('metadata.tsv', sep='\t')

# %%
import pandas as pd
  
met = pd.read_csv('metadata.tsv', sep='\t', index_col='#SampleID')
met['BS'] = met['BodySite'].map(lambda a: ''.join([x[0].upper() for x in a.split(' ')])) # BodySite abbr.
for ind in met.loc[met.BS=='L'].index:
  met.loc[ind,'BS'] = 'SAM'

dates = sorted(list(set(met['Date of Sampling'].tolist())),key=lambda d:tuple(map(int, d.split('/'))))
tpdict = dict((j,i) for i,j in enumerate(dates))

met['rstc_run'] = ''
met['Day'] = ''
met['Day_hour'] = ''
met['Treatment'] = ''
met['Source'] = ''
for smpl in set(met['Sample Name']):
  for index, row in met.loc[met['Sample Name']==smpl].copy().iterrows(): 
    for r in ['Run1','Run2']:                      # separate rstc run
      if r in smpl:
        met.loc[index,'rstc_run'] = 'rstc_' + r
    for d in ['d0','d7','d13']:                    # separate day
      if d in smpl:
        met.loc[index,'Day'] = d               
        if '48h' in smpl:                          # separate day and hours
          met.loc[index,'Day_hour'] = d+'h48'
        elif '24h' in smpl:
          met.loc[index,'Day_hour'] = d+'h24'
        else:
          met.loc[index,'Day_hour'] = 'not_appl'
    for t in range(1,6):                           # separate treatment
      if 'Trt' not in smpl:
        met.loc[index,'Treatment'] = 'not_appl'
      if 'Trt'+str(t) in smpl:
        met.loc[index,'Treatment'] = 'Trt'+str(t)        
    for s in ['HP1','HP2','C1','C2','C3','mixed']: # source (heat pump, cow, pooled)
      if s in smpl:
        if s == 'mixed':
          met.loc[index,'Source'] = 'mixC'
        else:
          met.loc[index,'Source'] = s
met['Day_num'] = met.Day.str[1:].astype(int)

# adding groups
import itertools as it

met['Src_rstcRun'] = met.Source + '_' + met.rstc_run
cols = {'BS':'BS','Day':'Day','Day_hour':'Dh','Treatment':'Trt','Source':'Src'}
groups = []
for i,c in enumerate(cols):
  if i != 0:
    groups += list(it.combinations(cols,i+1))
groups = [t for t in groups if len([x for x in t if 'Day' in x]) < 2 and 'BS' in t]

for g in groups:
  col = '_'.join([cols[c] for c in g])
  met[col] = ''
  for index,row in met.copy().iterrows():
    met.loc[index,col] = '_'.join([met.at[index,c] for c in g])


met.to_csv('metadata.tsv', sep='\t')

# %%
import pandas as pd

met = pd.read_csv('metadata.tsv', sep='\t', index_col='#SampleID')
domains = {'A':'arc','B':'bac'}
for d in domains:
  met_d = met.loc[met.index.str[0] == d].copy()
  met_d.to_csv('rstc_2019_%s/metadata.tsv'%domains[d], sep='\t')  # separate and save a metadata files
