# %%
# !git init -b main
# Out:
# Initialized empty Git repository in /home/meco/Nextcloud/Projects/RUSITEC/Rusitec_amplicon_2019/.git/

# %%
# !git add .

# %%
# !git commit -m 'First commit'
# Out:
# [main (root-commit) 53caae7] First commit
#  809 files changed, 147951 insertions(+)
#  create mode 100644 .ipynb_checkpoints/Git-checkpoint.ipynb
#  create mode 100644 Classifier.ipynb
#  create mode 100644 Classifier/ITS-ssu-nr99-classifier.qza
#  create mode 100644 Classifier/V1-V2-ssu-nr99-classifier.qza
#  create mode 100644 Classifier/silva-138_1-ssu-nr99-seqs-V1-V2-uniq.qza
#  create mode 100644 Classifier/silva-138_1-ssu-nr99-seqs-V1-V2.qza
#  create mode 100644 Classifier/silva-138_1-ssu-nr99-seqs-cleaned.qza
#  create mode 100644 Classifier/silva-138_1-ssu-nr99-seqs-derep-uniq.qza
#  create mode 100644 Classifier/silva-138_1-ssu-nr99-seqs-discard.qza
#  create mode 100644 Classifier/silva-138_1-ssu-nr99-seqs-filt.qza
#  create mode 100644 Classifier/silva-138_1-ssu-nr99-seqs-its-uniq.qza
#  create mode 100644 Classifier/silva-138_1-ssu-nr99-seqs-its.qza
#  create mode 100644 Classifier/silva-138_1-ssu-nr99-seqs.qza
# ...

# %%
# !git remote add origin git@github.com:timyerg/Kunzel_rstc_2019.git
# !git remote -v
# Out:
# origin	git@github.com:timyerg/Kunzel_rstc_2019.git (fetch)
# origin	git@github.com:timyerg/Kunzel_rstc_2019.git (push)

# %%
# !git push origin main
# Out:
# Enumerating objects: 844, done.
# Counting objects: 100% (844/844), done.
# Delta compression using up to 12 threads
# Compressing objects: 100% (833/833), done.
# Writing objects: 100% (844/844), 1021.71 MiB | 5.83 MiB/s, done.
# Total 844 (delta 314), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (314/314), done.
# remote: warning: File Classifier/V1-V2-ssu-nr99-classifier.qza is 73.06 MB; this is larger than GitHub's recommended maximum file size of 50.00 MB
# remote: error: Trace: 02da3de0e859b6da0bd5116bb28a612a16adf1c558aa88b5cc1783e25c3a4f09
# remote: error: See http://git.io/iEPt8g for more information.
# remote: error: File Classifier/silva-138_1-ssu-nr99-seqs-cleaned.qza is 159.41 MB; this exceeds GitHub's file size limit of 100.00 MB
# remote: error: File Classifier/silva-138_1-ssu-nr99-seqs-derep-uniq.qza is 145.84 MB; this exceeds GitHub's file size limit of 100.00 MB
# ...
